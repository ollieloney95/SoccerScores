# %%
import pandas as pd
import requests
import threading
from datetime import datetime, timedelta
import numpy as np
import ast
from flask import config

# %%
class DiskConnection:
    """
    manages the disk read and writes and inital setup from disk
    """

    def __init__(self, lock, config):
        self.lock = lock
        self.config = config
        self.leagues_db = pd.DataFrame(columns=['country_id', 'country_name', 'league_id', 'league_name']).astype({'country_id': 'int32', 'league_id':'int32'})
        self.events_db = pd.DataFrame()
        self.league_db_standings = {}
        self.setup_all_league_standings_from_disk()

    def get_dbs(self):
        return(self.leagues_db, self.events_db, self.league_db_standings)

    def write_db_to_disk(self, path, db):
        """
        write pandas df to a csv
        """
        logging.info('writing db to fisk at {}'.format(path))
        try:
            with self.lock:
                db.to_csv(path, index=False)
            return True
        except Exception as e:
            logging.error('error in write_db_to_disk {}'.format(e))
        return False

    def read_db_from_disk(self, path, index=None):
        """
        return df from disk via path
        """
        logging.info('getting db at {} from disk'.format(path))
        try:
            with self.lock:
                df = pd.read_csv(path, index_col=index, keep_default_na=False)
            return df
        except Exception as e:
            logging.error('error in getting db at {} error is {}'.format(path, e))
            return pd.DataFrame()

    def setup_all_league_standings_from_disk(self):
        if self.setup_leagues_db_from_disk() and self.setup_events_db_from_disk():
            for league_id in self.leagues_db.league_id:
                self.setup_league_standings_db_from_disk(league_id)
            return True
        return False

    def setup_leagues_db_from_disk(self):
        df = self.read_db_from_disk(self.config.path_leagues_db, index=None)
        if df.empty:
            return False
        self.leagues_db = df.astype({'country_id': 'int32', 'league_id':'int32'})
        return True

    def setup_events_db_from_disk(self):
        df = self.read_db_from_disk(self.config.path_events_db, index=None)
        if df.empty:
            return False
        df = df.astype({'match_id': 'int32', 'country_id': 'int32', 'league_id':'int32'}).set_index('match_id', drop=False)
        df['match_id'] = df['match_id'].astype('int64')
        df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
        self.events_db = df
        return True

    def setup_league_standings_db_from_disk(self, league_id):
        path = self.config.path_league_standings_stem + str(league_id) + ".csv"
        df = self.read_db_from_disk(path, index=None)
        if df.empty:
            return False
        self.league_db_standings[league_id] = df
        return True




class HostConnection:
    """
    manages the fetches from host
    """

    def __init__(self, config, disk_connection):
        self.config = config
        self.last_refresh_times = {}
        self.disk_connection = disk_connection


    def refresh_all_leagues_from_fetch(self, leagues_db, league_db_standings):
        for league_id in leagues_db.league_id:
            league_db_standings[league_id] = self.update_league_db_standings_from_fetch(league_id, league_db_standings)
        return league_db_standings


    def update_last_refresh_times(self, id):
        self.last_refresh_times[id] = datetime.now()


    def is_data_fresh(self, id):
        if not id in self.last_refresh_times:
            return False
        time_since_update_mins = (datetime.now() - self.last_refresh_times[id]).seconds / 60
        if time_since_update_mins > self.config.refresh_time_mins:
            return False
        return True


    def update_leagues_db_from_fetch(self, leagues_db):
        # check if data is already fresh
        if self.is_data_fresh(0):
            logging.info('in update_leagues_db_from_fetch and data is fresh')
            return leagues_db
        logging.info('in update_leagues_db_from_fetch data is stale')

        # fetch data from webservice
        path = self.config.apifootball_host + '/?action=get_leagues&APIkey=' + self.config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            leagues_db = df.combine_first(leagues_db)
            self.disk_connection.write_db_to_disk(self.config.path_leagues_db, leagues_db)
            self.update_last_refresh_times(0)
            leagues_db = leagues_db.astype({'country_id': 'int32', 'league_id':'int32'})
            return leagues_db
        except Exception as e:
            logging.error('error in update_leagues_db_from_fetch {}'.format(e))
        return leagues_db


    def update_events_from_fetch(self, date_from, date_to, events_db):
        # check if data is already fresh
        if self.is_data_fresh(1):
            logging.info('in update_events_from_fetch and data is fresh')
            return True
        logging.info('in update_events_from_fetch data is stale')

        # fetch data from webservice
        date_from = self._date_to_string(date_from)
        date_to = self._date_to_string(date_to)
        path = self.config.apifootball_host + '/?action=get_events&from=' + date_from + '&to=' + date_to + '&APIkey=' + self.config.apifootball_key
        try:
            logging.info('fetch for {}'.format(path))
            response = requests.get(path)
            df = pd.DataFrame(response.json()).astype({'match_id': 'int32', 'country_id': 'int32', 'league_id':'int32'}).set_index('match_id', drop=False)
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
            events_db = df.combine_first(events_db)

            self.disk_connection.write_db_to_disk(self.config.path_events_db, events_db)
            self.update_last_refresh_times(1)
        except Exception as e:
            logging.error('error in update_events_from_fetch {}'.format(e))
        return events_db


    def update_league_db_standings_from_fetch(self, league_id, league_db_standings):
        # check if data is already fresh
        logging.info('updating league {} from fetch'.format(league_id))
        if self.is_data_fresh(league_id):
            logging.info('in update_league_db_standings_from_fetch and data is fresh')
            return league_db_standings[league_id]
        logging.info('in update_league_db_standings_from_fetch data is stale')

        # fetch data from webservice
        path = self.config.apifootball_host + '/?action=get_standings&league_id=' + str(
            league_id) + '&APIkey=' + self.config.apifootball_key
        logging.info('fetching from path: {}'.format(path))
        try:
            response = requests.get(path)
            res = response.json()
            league_db_standings[league_id] = pd.DataFrame(res)
            logging.info('changed league_db_standings from the fetch for {}'.format(league_id))
            self.disk_connection.write_db_to_disk(self.config.path_league_standings_stem + str(league_id) + '.csv', league_db_standings[league_id])
            self.update_last_refresh_times(league_id)
        except Exception as e:
            logging.error('error in update_league_db_standings_from_fetch {}'.format(e))
        return league_db_standings[league_id]

    def _date_to_string(self, date):
        yyyy = str(date.year)
        mm = str(date.month)
        dd = str(date.day)
        if len(mm) == 1:
            mm = '0' + mm
        if len(dd) == 1:
            dd = '0' + dd
        return yyyy + '-' + mm + '-' + dd



class DatabaseConnection:
    """
    uses DiskConnection to setup dbs and write update
    uses HostConnection to refresh the dbs
    """

    def __init__(self, config):
        self.config = config
        self.lock = threading.Lock()
        self.disk_connection = DiskConnection(self.lock, self.config)
        self.leagues_db, self.events_db, self.league_db_standings = self.disk_connection.get_dbs()
        self.host_connection = HostConnection(self.config, self.disk_connection)

        # inital updates
        date_from = datetime.now() - timedelta(days=14)
        date_to = datetime.now() + timedelta(days=14)
        self.events_db = self.host_connection.update_events_from_fetch(date_from, date_to, self.events_db)
        self.leagues_db = self.host_connection.update_leagues_db_from_fetch(self.leagues_db)
        self.league_db_standings = self.host_connection.refresh_all_leagues_from_fetch(self.leagues_db, self.league_db_standings)


    def get_events(self, league_id=None, date_from=None, date_to=None, match_id=None, team_name=None):
        df = self.events_db.copy()
        trues = np.array([True]*len(df))

        # apply filters
        match_id_filter = df.index == match_id if match_id else trues
        team_name_filter = ((df['match_hometeam_name'] == team_name) | (df['match_awayteam_name'] == team_name)) if team_name else trues
        league_id_filter = df['league_id'] == league_id if league_id else trues
        date_from_filter = df['match_date'] > date_from.replace(hour=0, minute=0, second=0) if date_from else trues
        date_to_filter = df['match_date'] < date_to.replace(hour=23, minute=59, second=0) if date_to else trues

        # format the dataframe correctly
        df = df.replace(np.nan, '', regex=True)
        df = df.loc[match_id_filter & league_id_filter & date_from_filter & date_to_filter & team_name_filter]
        df['match_date'] = [d.timestamp() for d in df['match_date']]

        return df.to_dict('index')


    def df_to_strings(self, df):
        for col in df.columns:
            df[col] = df[col].astype(str)
        return df


    def get_league_db(self):
        self.leagues_db = self.host_connection.update_leagues_db_from_fetch(self.leagues_db)
        return self.leagues_db.astype({'country_id': 'int32', 'league_id':'int32'})


    def get_league_db_standings(self, league_id):
        self.league_db_standings[league_id] = self.host_connection.update_league_db_standings_from_fetch(league_id, self.league_db_standings)
        return self.league_db_standings.get(league_id, pd.DataFrame())


    def get_leagues(self):
        """
        returns the league and country info in a dictionary form
        """
        logging.info('inside get_leagues')
        df = self.df_to_strings(self.get_league_db())
        leagues_dict = {}
        cids = list(set(df['country_id']))
        df = df.set_index('country_id')
        for cid in cids:
            if sum(df.index == cid) > 1:
                league_names = list(df.loc[cid]['league_name'])
                league_ids = list(df.loc[cid]['league_id'])
                country_name = list(df.loc[cid]['country_name'])[0]
            else:
                league_names = [df.loc[cid]['league_name']]
                league_ids = [df.loc[cid]['league_id']]
                country_name = df.loc[cid]['country_name']
            leagues_dict[cid] = {
                'country_name': country_name,
                'leagues': {
                    'league_ids': league_ids,
                    'country_name': country_name,
                    'league_names': league_names
                }
            }
        return leagues_dict

#@app.route('/')
def check_server():
    return "connected to middle layer server"


#@app.route('/get_leagues_db/', methods=['GET'])
def get_leagues_db():
    logging.info("get_leagues_db")
    df = db_con.get_league_db()
    return (df.to_dict('index'))


#@app.route('/get_sidebar_info/', methods=['GET'])
def get_sidebar_info():
    return (db_con.get_leagues())


#@app.route('/get_league_standings_db/<league_id>', methods=['GET'])
def get_league_standings_db(league_id):
    league_id = int(league_id)
    df = db_con.get_league_db_standings(league_id)
    if df.empty:
        return ('league_id not recognised')
    return (df.to_dict('index'))


#@app.route('/get_fixtures/<league_id>', methods=['GET'])
def get_fixtures(league_id):
    league_id = int(league_id)
    date_from = datetime.now()
    date_to = datetime.now() + timedelta(days=14)
    return (db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_results/<league_id>', methods=['GET'])
def get_results(league_id):
    league_id = int(league_id)
    date_from = datetime.now() - timedelta(days=14)
    date_to = datetime.now()
    return (db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_match/<match_id>', methods=['GET'])
def get_match(match_id):
    match_id = int(match_id)
    match_info = db_con.get_events(match_id=match_id)[match_id]
    return (match_info)

def get_last_matches_for_team(team_name):
    matches = db_con.get_events(team_name=team_name)

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

global db_con
db_con = DatabaseConnection(config)  # or whatever you need to do
# Out:
# INFO:root:getting db at /Users/ollieloney/SoccerScores/databases/leagues_db.csv from disk
# INFO:root:getting db at /Users/ollieloney/SoccerScores/databases/events_db.csv from disk
# INFO:root:getting db at /Users/ollieloney/SoccerScores/databases/league_standings_149.csv from disk
# INFO:root:getting db at /Users/ollieloney/SoccerScores/databases/league_standings_177.csv from disk
# INFO:root:in update_events_from_fetch data is stale
# INFO:root:fetch for https://apiv2.apifootball.com/?action=get_events&from=2019-11-12&to=2019-12-10&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apiv2.apifootball.com:443
# ERROR:root:error in update_events_from_fetch HTTPSConnectionPool(host='apiv2.apifootball.com', port=443): Max retries exceeded with url: /?action=get_events&from=2019-11-12&to=2019-12-10&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x10d505590>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# INFO:root:in update_leagues_db_from_fetch data is stale
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apiv2.apifootball.com:443
# ERROR:root:error in update_leagues_db_from_fetch HTTPSConnectionPool(host='apiv2.apifootball.com', port=443): Max retries exceeded with url: /?action=get_leagues&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x10cdb0e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# INFO:root:updating league 149 from fetch
# INFO:root:in update_league_db_standings_from_fetch data is stale
# INFO:root:fetching from path: https://apiv2.apifootball.com/?action=get_standings&league_id=149&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apiv2.apifootball.com:443
# ERROR:root:error in update_league_db_standings_from_fetch HTTPSConnectionPool(host='apiv2.apifootball.com', port=443): Max retries exceeded with url: /?action=get_standings&league_id=149&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x10d4a9350>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# INFO:root:updating league 177 from fetch
# INFO:root:in update_league_db_standings_from_fetch data is stale
# INFO:root:fetching from path: https://apiv2.apifootball.com/?action=get_standings&league_id=177&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apiv2.apifootball.com:443
# ERROR:root:error in update_league_db_standings_from_fetch HTTPSConnectionPool(host='apiv2.apifootball.com', port=443): Max retries exceeded with url: /?action=get_standings&league_id=177&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x10d452850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
db_con.events_db
# Out:
#                                                       cards  country_id  \
# match_id
# 242310    [{'away_fault': '', 'home_fault': 'Bryan J.', ...          41
# 242974    [{'away_fault': "N'Simba V.", 'home_fault': ''...          46
# 242975    [{'away_fault': '', 'home_fault': 'Oniangue P....          46
# 242976    [{'away_fault': 'Lemoine F.', 'home_fault': ''...          46
# 242977    [{'away_fault': '', 'home_fault': 'Monfray A.'...          46
# 242980    [{'away_fault': 'Ouammou N.', 'home_fault': ''...          46
# 242981    [{'away_fault': 'Hein G.', 'home_fault': '', '...          46
# 242982    [{'away_fault': '', 'home_fault': 'Kikonda M.'...          46
# 242983    [{'away_fault': '', 'home_fault': 'Pintor L.',...          46
# 242305    [{'away_fault': 'Brown J.', 'home_fault': '', ...          41
# 242306    [{'away_fault': 'Yiadom A.', 'home_fault': '',...          41
# 242307    [{'away_fault': 'Ameobi S.', 'home_fault': '',...          41
# 242308    [{'away_fault': 'Madine G.', 'home_fault': '',...          41
# 242309    [{'away_fault': 'Fisher D.', 'home_fault': '',...          41
# 242311    [{'away_fault': '', 'home_fault': 'Hogg J.', '...          41
# 242312    [{'away_fault': 'Ayling L.', 'home_fault': '',...          41
# 242314    [{'away_fault': '', 'home_fault': 'McClean J.'...          41
# 242315    [{'away_fault': '', 'home_fault': 'van der Hoo...          41
# 242316    [{'away_fault': 'Lee K.', 'home_fault': '', 't...          41
# 242979    [{'away_fault': 'Rocchia C.', 'home_fault': ''...          46
# 242313    [{'away_fault': '', 'home_fault': 'Johnson M.'...          41
# 242978    [{'away_fault': '', 'home_fault': 'Coulibaly Y...          46
# 242317                                                   []          41
# 242318                                                   []          41
# 242319                                                   []          41
# 242320                                                   []          41
# 242321                                                   []          41
# 242322                                                   []          41
# 242323                                                   []          41
# 242324                                                   []          41
# ...                                                     ...         ...
# 242992                                                   []          46
# 242337                                                   []          41
# 242995                                                   []          46
# 242994                                                   []          46
# 242996                                                   []          46
# 242997                                                   []          46
# 242998                                                   []          46
# 242999                                                   []          46
# 243000                                                   []          46
# 243001                                                   []          46
# 243002                                                   []          46
# 243003                                                   []          46
# 242341                                                   []          41
# 242342                                                   []          41
# 242343                                                   []          41
# 242344                                                   []          41
# 242345                                                   []          41
# 242346                                                   []          41
# 242347                                                   []          41
# 242348                                                   []          41
# 242349                                                   []          41
# 242350                                                   []          41
# 242351                                                   []          41
# 242352                                                   []          41
# 242353                                                   []          41
# 242354                                                   []          41
# 242355                                                   []          41
# 242356                                                   []          41
# 242357                                                   []          41
# 242358                                                   []          41
#
#          country_name                                         goalscorer  \
# match_id
# 242310        England  [{'home_scorer': '', 'time': '4', 'score': '0 ...
# 242974         France  [{'home_scorer': 'Choplin J.', 'time': '32', '...
# 242975         France  [{'home_scorer': '', 'time': '18', 'score': '0...
# 242976         France  [{'home_scorer': 'Grange R.', 'time': '40', 's...
# 242977         France  [{'home_scorer': 'Djitte M. K.', 'time': '57',...
# 242980         France  [{'home_scorer': 'Sissoko I.', 'time': '57', '...
# 242981         France  [{'home_scorer': '', 'time': '28', 'score': '0...
# 242982         France  [{'home_scorer': 'Armand R.', 'time': '61', 's...
# 242983         France  [{'home_scorer': '', 'time': '15', 'score': '0...
# 242305        England  [{'home_scorer': 'Dack B.', 'time': '24', 'sco...
# 242306        England  [{'home_scorer': 'Watkins O.', 'time': '62', '...
# 242307        England                                                 []
# 242308        England  [{'home_scorer': 'Gallagher C.', 'time': '13',...
# 242309        England  [{'home_scorer': 'Waghorn M.', 'time': '33', '...
# 242311        England  [{'home_scorer': 'Campbell F.', 'time': '55', ...
# 242312        England  [{'home_scorer': '', 'time': '51', 'score': '0...
# 242314        England  [{'home_scorer': '', 'time': '39', 'score': '0...
# 242315        England  [{'home_scorer': '', 'time': '65', 'score': '0...
# 242316        England  [{'home_scorer': 'Robson-Kanu H.', 'time': '10...
# 242979         France  [{'home_scorer': 'Banza S. B.', 'time': '16', ...
# 242313        England  [{'home_scorer': 'Tavernier M.', 'time': '7', ...
# 242978         France  [{'home_scorer': 'Dina E.', 'time': '54', 'sco...
# 242317        England                                                 []
# 242318        England                                                 []
# 242319        England                                                 []
# 242320        England                                                 []
# 242321        England                                                 []
# 242322        England                                                 []
# 242323        England                                                 []
# 242324        England                                                 []
# ...               ...                                                ...
# 242992         France                                                 []
# 242337        England                                                 []
# 242995         France                                                 []
# 242994         France                                                 []
# 242996         France                                                 []
# 242997         France                                                 []
# 242998         France                                                 []
# 242999         France                                                 []
# 243000         France                                                 []
# 243001         France                                                 []
# 243002         France                                                 []
# 243003         France                                                 []
# 242341        England                                                 []
# 242342        England                                                 []
# 242343        England                                                 []
# 242344        England                                                 []
# 242345        England                                                 []
# 242346        England                                                 []
# 242347        England                                                 []
# 242348        England                                                 []
# 242349        England                                                 []
# 242350        England                                                 []
# 242351        England                                                 []
# 242352        England                                                 []
# 242353        England                                                 []
# 242354        England                                                 []
# 242355        England                                                 []
# 242356        England                                                 []
# 242357        England                                                 []
# 242358        England                                                 []
#
#           league_id   league_name  \
# match_id
# 242310          149  Championship
# 242974          177       Ligue 2
# 242975          177       Ligue 2
# 242976          177       Ligue 2
# 242977          177       Ligue 2
# 242980          177       Ligue 2
# 242981          177       Ligue 2
# 242982          177       Ligue 2
# 242983          177       Ligue 2
# 242305          149  Championship
# 242306          149  Championship
# 242307          149  Championship
# 242308          149  Championship
# 242309          149  Championship
# 242311          149  Championship
# 242312          149  Championship
# 242314          149  Championship
# 242315          149  Championship
# 242316          149  Championship
# 242979          177       Ligue 2
# 242313          149  Championship
# 242978          177       Ligue 2
# 242317          149  Championship
# 242318          149  Championship
# 242319          149  Championship
# 242320          149  Championship
# 242321          149  Championship
# 242322          149  Championship
# 242323          149  Championship
# 242324          149  Championship
# ...             ...           ...
# 242992          177       Ligue 2
# 242337          149  Championship
# 242995          177       Ligue 2
# 242994          177       Ligue 2
# 242996          177       Ligue 2
# 242997          177       Ligue 2
# 242998          177       Ligue 2
# 242999          177       Ligue 2
# 243000          177       Ligue 2
# 243001          177       Ligue 2
# 243002          177       Ligue 2
# 243003          177       Ligue 2
# 242341          149  Championship
# 242342          149  Championship
# 242343          149  Championship
# 242344          149  Championship
# 242345          149  Championship
# 242346          149  Championship
# 242347          149  Championship
# 242348          149  Championship
# 242349          149  Championship
# 242350          149  Championship
# 242351          149  Championship
# 242352          149  Championship
# 242353          149  Championship
# 242354          149  Championship
# 242355          149  Championship
# 242356          149  Championship
# 242357          149  Championship
# 242358          149  Championship
#
#                                                      lineup  \
# match_id
# 242310    {'away': {'coach': [{'lineup_position': '', 'l...
# 242974    {'away': {'coach': [], 'missing_players': [], ...
# 242975    {'away': {'coach': [{'lineup_position': '', 'l...
# 242976    {'away': {'coach': [{'lineup_position': '', 'l...
# 242977    {'away': {'coach': [{'lineup_position': '', 'l...
# 242980    {'away': {'coach': [{'lineup_position': '', 'l...
# 242981    {'away': {'coach': [{'lineup_position': '', 'l...
# 242982    {'away': {'coach': [{'lineup_position': '', 'l...
# 242983    {'away': {'coach': [{'lineup_position': '', 'l...
# 242305    {'away': {'coach': [{'lineup_position': '', 'l...
# 242306    {'away': {'coach': [{'lineup_position': '', 'l...
# 242307    {'away': {'coach': [{'lineup_position': '', 'l...
# 242308    {'away': {'coach': [{'lineup_position': '', 'l...
# 242309    {'away': {'coach': [{'lineup_position': '', 'l...
# 242311    {'away': {'coach': [{'lineup_position': '', 'l...
# 242312    {'away': {'coach': [{'lineup_position': '', 'l...
# 242314    {'away': {'coach': [{'lineup_position': '', 'l...
# 242315    {'away': {'coach': [{'lineup_position': '', 'l...
# 242316    {'away': {'coach': [{'lineup_position': '', 'l...
# 242979    {'away': {'coach': [{'lineup_position': '', 'l...
# 242313    {'away': {'coach': [{'lineup_position': '', 'l...
# 242978    {'away': {'coach': [{'lineup_position': '', 'l...
# 242317    {'away': {'coach': [], 'missing_players': [], ...
# 242318    {'away': {'coach': [], 'missing_players': [], ...
# 242319    {'away': {'coach': [], 'missing_players': [], ...
# 242320    {'away': {'coach': [], 'missing_players': [], ...
# 242321    {'away': {'coach': [], 'missing_players': [], ...
# 242322    {'away': {'coach': [], 'missing_players': [], ...
# 242323    {'away': {'coach': [], 'missing_players': [], ...
# 242324    {'away': {'coach': [], 'missing_players': [], ...
# ...                                                     ...
# 242992    {'away': {'coach': [], 'missing_players': [], ...
# 242337    {'away': {'coach': [], 'missing_players': [], ...
# 242995    {'away': {'coach': [], 'missing_players': [], ...
# 242994    {'away': {'coach': [], 'missing_players': [], ...
# 242996    {'away': {'coach': [], 'missing_players': [], ...
# 242997    {'away': {'coach': [], 'missing_players': [], ...
# 242998    {'away': {'coach': [], 'missing_players': [], ...
# 242999    {'away': {'coach': [], 'missing_players': [], ...
# 243000    {'away': {'coach': [], 'missing_players': [], ...
# 243001    {'away': {'coach': [], 'missing_players': [], ...
# 243002    {'away': {'coach': [], 'missing_players': [], ...
# 243003    {'away': {'coach': [], 'missing_players': [], ...
# 242341    {'away': {'coach': [], 'missing_players': [], ...
# 242342    {'away': {'coach': [], 'missing_players': [], ...
# 242343    {'away': {'coach': [], 'missing_players': [], ...
# 242344    {'away': {'coach': [], 'missing_players': [], ...
# 242345    {'away': {'coach': [], 'missing_players': [], ...
# 242346    {'away': {'coach': [], 'missing_players': [], ...
# 242347    {'away': {'coach': [], 'missing_players': [], ...
# 242348    {'away': {'coach': [], 'missing_players': [], ...
# 242349    {'away': {'coach': [], 'missing_players': [], ...
# 242350    {'away': {'coach': [], 'missing_players': [], ...
# 242351    {'away': {'coach': [], 'missing_players': [], ...
# 242352    {'away': {'coach': [], 'missing_players': [], ...
# 242353    {'away': {'coach': [], 'missing_players': [], ...
# 242354    {'away': {'coach': [], 'missing_players': [], ...
# 242355    {'away': {'coach': [], 'missing_players': [], ...
# 242356    {'away': {'coach': [], 'missing_players': [], ...
# 242357    {'away': {'coach': [], 'missing_players': [], ...
# 242358    {'away': {'coach': [], 'missing_players': [], ...
#
#          match_awayteam_extra_score match_awayteam_halftime_score  \
# match_id
# 242310                            1                             1
# 242974                            0                             0
# 242975                            1                             1
# 242976                            0                             0
# 242977                            0                             0
# 242980                            0                             0
# 242981                            1                             1
# 242982                            0                             0
# 242983                            2                             2
# 242305                            0                             0
# 242306                            0                             0
# 242307                            0                             0
# 242308                            0                             0
# 242309                            0                             0
# 242311                            0                             0
# 242312                            0                             0
# 242314                            1                             1
# 242315                            0                             0
# 242316                            0                             0
# 242979                            0                             0
# 242313                            0                             0
# 242978                            0                             0
# 242317
# 242318
# 242319
# 242320
# 242321
# 242322
# 242323
# 242324
# ...                             ...                           ...
# 242992
# 242337
# 242995
# 242994
# 242996
# 242997
# 242998
# 242999
# 243000
# 243001
# 243002
# 243003
# 242341
# 242342
# 242343
# 242344
# 242345
# 242346
# 242347
# 242348
# 242349
# 242350
# 242351
# 242352
# 242353
# 242354
# 242355
# 242356
# 242357
# 242358
#
#           match_awayteam_id  ... match_hometeam_name  \
# match_id                     ...
# 242310                 2645  ...              Fulham
# 242974                 3042  ...          AC Ajaccio
# 242975                 3133  ...                Caen
# 242976                 3044  ...         Chateauroux
# 242977                 3047  ...            Grenoble
# 242980                 3065  ...               Niort
# 242981                 3048  ...             Orleans
# 242982                 3051  ...            Paris FC
# 242983                 3071  ...              Troyes
# 242305                 2652  ...           Blackburn
# 242306                 2647  ...           Brentford
# 242307                 2634  ...        Bristol City
# 242308                 2637  ...            Charlton
# 242309                 2643  ...               Derby
# 242311                 2631  ...        Huddersfield
# 242312                 2653  ...               Luton
# 242314                 2679  ...               Stoke
# 242315                 2638  ...             Swansea
# 242316                 2651  ...           West Brom
# 242979                 3058  ...                Lens
# 242313                 2633  ...       Middlesbrough
# 242978                 3032  ...            Le Havre
# 242317                 2624  ...             Cardiff
# 242318                 2642  ...              Fulham
# 242319                 2618  ...        Huddersfield
# 242320                 2663  ...               Luton
# 242321                 2679  ...            Millwall
# 242322                 2653  ...             Reading
# 242323                 2644  ...           Blackburn
# 242324                 2643  ...                Hull
# ...                     ...  ...                 ...
# 242992                 3029  ...             Sochaux
# 242337                 2625  ...             Preston
# 242995                 3047  ...                Caen
# 242994                 3048  ...             Auxerre
# 242996                 3058  ...         Chateauroux
# 242997                 3042  ...            Grenoble
# 242998                 3133  ...            Le Havre
# 242999                 3071  ...                Lens
# 243000                 3043  ...               Niort
# 243001                 3044  ...             Orleans
# 243002                 3032  ...            Paris FC
# 243003                 3065  ...              Troyes
# 242341                 2642  ...           Blackburn
# 242342                 2652  ...             Cardiff
# 242343                 2650  ...              Fulham
# 242344                 2653  ...        Huddersfield
# 242345                 2624  ...                Hull
# 242346                 2679  ...               Luton
# 242347                 2663  ...       Middlesbrough
# 242348                 2634  ...            Millwall
# 242349                 2643  ...                 QPR
# 242350                 2631  ...             Reading
# 242351                 2644  ...       Sheffield Wed
# 242352                 2618  ...           West Brom
# 242353                 2638  ...        Bristol City
# 242354                 2622  ...            Charlton
# 242355                 2633  ...               Leeds
# 242356                 2648  ...          Nottingham
# 242357                 2639  ...             Preston
# 242358                 2695  ...               Stoke
#
#          match_hometeam_penalty_score match_hometeam_score  \
# match_id
# 242310                                                   2
# 242974                                                   1
# 242975                                                   3
# 242976                                                   1
# 242977                                                   1
# 242980                                                   2
# 242981                                                   0
# 242982                                                   2
# 242983                                                   0
# 242305                                                   3
# 242306                                                   1
# 242307                                                   0
# 242308                                                   2
# 242309                                                   1
# 242311                                                   1
# 242312                                                   1
# 242314                                                   2
# 242315                                                   0
# 242316                                                   2
# 242979                                                   4
# 242313                                                   2
# 242978                                                   4
# 242317
# 242318
# 242319
# 242320
# 242321
# 242322
# 242323
# 242324
# ...                               ...                  ...
# 242992
# 242337
# 242995
# 242994
# 242996
# 242997
# 242998
# 242999
# 243000
# 243001
# 243002
# 243003
# 242341
# 242342
# 242343
# 242344
# 242345
# 242346
# 242347
# 242348
# 242349
# 242350
# 242351
# 242352
# 242353
# 242354
# 242355
# 242356
# 242357
# 242358
#
#          match_hometeam_system match_id match_live match_status  match_time  \
# match_id
# 242310               4 - 3 - 3   242310          0     Finished       20:45
# 242974               4 - 4 - 2   242974          0     Finished       20:00
# 242975           4 - 2 - 3 - 1   242975          0     Finished       20:00
# 242976               4 - 3 - 3   242976          0     Finished       20:00
# 242977           4 - 2 - 3 - 1   242977          0     Finished       20:00
# 242980               4 - 3 - 3   242980          0     Finished       20:00
# 242981               4 - 5 - 1   242981          0     Finished       20:00
# 242982           3 - 4 - 1 - 2   242982          0     Finished       20:00
# 242983           4 - 1 - 2 - 3   242983          0     Finished       20:00
# 242305           4 - 2 - 3 - 1   242305          0     Finished       16:00
# 242306               4 - 3 - 3   242306          0     Finished       16:00
# 242307               3 - 5 - 2   242307          0     Finished       16:00
# 242308       4 - 1 - 2 - 1 - 2   242308          0     Finished       13:30
# 242309           4 - 2 - 3 - 1   242309          0     Finished       16:00
# 242311           4 - 2 - 3 - 1   242311          0     Finished       16:00
# 242312       4 - 1 - 2 - 1 - 2   242312          0     Finished       16:00
# 242314               4 - 3 - 3   242314          0     Finished       16:00
# 242315           4 - 2 - 3 - 1   242315          0     Finished       16:00
# 242316           4 - 2 - 3 - 1   242316          0     Finished       16:00
# 242979           3 - 4 - 2 - 1   242979          0     Finished       15:00
# 242313               3 - 5 - 2   242313          0     Finished       13:00
# 242978           4 - 2 - 3 - 1   242978          0     Finished       20:45
# 242317                           242317          0                    20:45
# 242318                           242318          0                    20:45
# 242319                           242319          0                    20:45
# 242320                           242320          0                    20:45
# 242321                           242321          0                    20:45
# 242322                           242322          0                    21:00
# 242323                           242323          0                    20:45
# 242324                           242324          0                    20:45
# ...                        ...      ...        ...          ...         ...
# 242992                           242992          0                    14:30
# 242337                           242337          0                    20:45
# 242995                           242995          0                    20:45
# 242994                           242994          0                    21:00
# 242996                           242996          0                    21:00
# 242997                           242997          0                    21:00
# 242998                           242998          0                    21:00
# 242999                           242999          0                    21:00
# 243000                           243000          0                    21:00
# 243001                           243001          0                    21:00
# 243002                           243002          0                    21:00
# 243003                           243003          0                    21:00
# 242341                           242341          0                    16:00
# 242342                           242342          0                    16:00
# 242343                           242343          0                    16:00
# 242344                           242344          0                    13:30
# 242345                           242345          0                    16:00
# 242346                           242346          0                    16:00
# 242347                           242347          0                    16:00
# 242348                           242348          0                    20:45
# 242349                           242349          0                    16:00
# 242350                           242350          0                    16:00
# 242351                           242351          0                    16:00
# 242352                           242352          0                    13:00
# 242353                           242353          0                    20:45
# 242354                           242354          0                    20:45
# 242355                           242355          0                    20:45
# 242356                           242356          0                    20:45
# 242357                           242357          0                    20:45
# 242358                           242358          0                    21:00
#
#                                                  statistics  \
# match_id
# 242310    [{'type': 'Ball Possession', 'away': '50%', 'h...
# 242974    [{'type': 'Ball Possession', 'away': '47%', 'h...
# 242975    [{'type': 'Ball Possession', 'away': '55%', 'h...
# 242976    [{'type': 'Ball Possession', 'away': '53%', 'h...
# 242977    [{'type': 'Ball Possession', 'away': '54%', 'h...
# 242980    [{'type': 'Ball Possession', 'away': '47%', 'h...
# 242981    [{'type': 'Ball Possession', 'away': '34%', 'h...
# 242982    [{'type': 'Ball Possession', 'away': '55%', 'h...
# 242983    [{'type': 'Ball Possession', 'away': '38%', 'h...
# 242305    [{'type': 'Ball Possession', 'away': '61%', 'h...
# 242306    [{'type': 'Ball Possession', 'away': '43%', 'h...
# 242307    [{'type': 'Ball Possession', 'away': '39%', 'h...
# 242308    [{'type': 'Ball Possession', 'away': '43%', 'h...
# 242309    [{'type': 'Ball Possession', 'away': '55%', 'h...
# 242311    [{'type': 'Ball Possession', 'away': '53%', 'h...
# 242312    [{'type': 'Ball Possession', 'away': '75%', 'h...
# 242314    [{'type': 'Ball Possession', 'away': '40%', 'h...
# 242315    [{'type': 'Ball Possession', 'away': '33%', 'h...
# 242316    [{'type': 'Ball Possession', 'away': '44%', 'h...
# 242979    [{'type': 'Ball Possession', 'away': '40%', 'h...
# 242313    [{'type': 'Ball Possession', 'away': '63%', 'h...
# 242978    [{'type': 'Ball Possession', 'away': '50%', 'h...
# 242317                                                   []
# 242318                                                   []
# 242319                                                   []
# 242320                                                   []
# 242321                                                   []
# 242322                                                   []
# 242323                                                   []
# 242324                                                   []
# ...                                                     ...
# 242992                                                   []
# 242337                                                   []
# 242995                                                   []
# 242994                                                   []
# 242996                                                   []
# 242997                                                   []
# 242998                                                   []
# 242999                                                   []
# 243000                                                   []
# 243001                                                   []
# 243002                                                   []
# 243003                                                   []
# 242341                                                   []
# 242342                                                   []
# 242343                                                   []
# 242344                                                   []
# 242345                                                   []
# 242346                                                   []
# 242347                                                   []
# 242348                                                   []
# 242349                                                   []
# 242350                                                   []
# 242351                                                   []
# 242352                                                   []
# 242353                                                   []
# 242354                                                   []
# 242355                                                   []
# 242356                                                   []
# 242357                                                   []
# 242358                                                   []
#
#                                               substitutions
# match_id
# 242310    {'away': [{'substitution': 'Amos L. | Chair I....
# 242974    {'away': [{'substitution': 'Gomis D. | Allevin...
# 242975    {'away': [{'substitution': 'Hafidi H. | Kante ...
# 242976    {'away': [{'substitution': 'Delaplace J. | Her...
# 242977    {'away': [{'substitution': 'Rocha Santos K. | ...
# 242980    {'away': [{'substitution': 'Ouammou N. | Terte...
# 242981    {'away': [{'substitution': 'Diliberto N. | Cab...
# 242982    {'away': [{'substitution': 'Carlens A. | Van B...
# 242983    {'away': [{'substitution': 'David F. | Popelar...
# 242305    {'away': [{'substitution': 'Schmidt P. | Chapl...
# 242306    {'away': [{'substitution': 'Baldock S. | Meite...
# 242307    {'away': [{'substitution': 'Ameobi S. | Adomah...
# 242308    {'away': [{'substitution': 'Madine G. | Bogle ...
# 242309    {'away': [{'substitution': 'Fisher D. | Gallag...
# 242311    {'away': [{'substitution': 'Maghoma J. | Monte...
# 242312    {'away': [{'substitution': 'Berardi G. | Coope...
# 242314    {'away': [{'substitution': 'MacLeod L. | Moore...
# 242315    {'away': [{'substitution': 'Mahoney C. | Smith...
# 242316    {'away': [{'substitution': 'Harris K. | Reach ...
# 242979    {'away': [{'substitution': 'Weissbeck G. | Tei...
# 242313    {'away': [{'substitution': 'Lopes L. | Batty D...
# 242978    {'away': [{'substitution': "Valdivia P. | N'Gb...
# 242317                             {'away': [], 'home': []}
# 242318                             {'away': [], 'home': []}
# 242319                             {'away': [], 'home': []}
# 242320                             {'away': [], 'home': []}
# 242321                             {'away': [], 'home': []}
# 242322                             {'away': [], 'home': []}
# 242323                             {'away': [], 'home': []}
# 242324                             {'away': [], 'home': []}
# ...                                                     ...
# 242992                             {'away': [], 'home': []}
# 242337                             {'away': [], 'home': []}
# 242995                             {'away': [], 'home': []}
# 242994                             {'away': [], 'home': []}
# 242996                             {'away': [], 'home': []}
# 242997                             {'away': [], 'home': []}
# 242998                             {'away': [], 'home': []}
# 242999                             {'away': [], 'home': []}
# 243000                             {'away': [], 'home': []}
# 243001                             {'away': [], 'home': []}
# 243002                             {'away': [], 'home': []}
# 243003                             {'away': [], 'home': []}
# 242341                             {'away': [], 'home': []}
# 242342                             {'away': [], 'home': []}
# 242343                             {'away': [], 'home': []}
# 242344                             {'away': [], 'home': []}
# 242345                             {'away': [], 'home': []}
# 242346                             {'away': [], 'home': []}
# 242347                             {'away': [], 'home': []}
# 242348                             {'away': [], 'home': []}
# 242349                             {'away': [], 'home': []}
# 242350                             {'away': [], 'home': []}
# 242351                             {'away': [], 'home': []}
# 242352                             {'away': [], 'home': []}
# 242353                             {'away': [], 'home': []}
# 242354                             {'away': [], 'home': []}
# 242355                             {'away': [], 'home': []}
# 242356                             {'away': [], 'home': []}
# 242357                             {'away': [], 'home': []}
# 242358                             {'away': [], 'home': []}
#
# [84 rows x 28 columns]

# %%
get_match(242310)
# Out:
# {'cards': "[{'away_fault': '', 'home_fault': 'Bryan J.', 'time': '61', 'card': 'yellow card'}]",
#  'country_id': 41,
#  'country_name': 'England',
#  'goalscorer': "[{'home_scorer': '', 'time': '4', 'score': '0 - 1', 'away_scorer': 'Hugill J.'}, {'home_scorer': 'Kamara A.', 'time': '27', 'score': '1 - 1', 'away_scorer': ''}, {'home_scorer': 'Kamara A.', 'time': '65', 'score': '2 - 1', 'away_scorer': ''}]",
#  'league_id': 149,
#  'league_name': 'Championship',
#  'lineup': '{\'away\': {\'coach\': [{\'lineup_position\': \'\', \'lineup_player\': \'Warburton M.\', \'lineup_number\': \'-1\'}], \'missing_players\': [{\'lineup_position\': \'\', \'lineup_player\': \'Barbet Y.\', \'lineup_number\': \'-1\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Cameron G.\', \'lineup_number\': \'-1\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Owens C.\', \'lineup_number\': \'-1\'}], \'starting_lineups\': [{\'lineup_position\': \'9\', \'lineup_player\': \'Amos L.\', \'lineup_number\': \'8\'}, {\'lineup_position\': \'8\', \'lineup_player\': \'Ball D.\', \'lineup_number\': \'12\'}, {\'lineup_position\': \'7\', \'lineup_player\': \'Eze E.\', \'lineup_number\': \'10\'}, {\'lineup_position\': \'3\', \'lineup_player\': \'Hall G. (C)\', \'lineup_number\': \'4\'}, {\'lineup_position\': \'10\', \'lineup_player\': \'Hugill J.\', \'lineup_number\': \'9\'}, {\'lineup_position\': \'2\', \'lineup_player\': \'Kane T.\', \'lineup_number\': \'2\'}, {\'lineup_position\': \'4\', \'lineup_player\': \'Leistner T.\', \'lineup_number\': \'37\'}, {\'lineup_position\': \'1\', \'lineup_player\': \'Lumley J. (G)\', \'lineup_number\': \'1\'}, {\'lineup_position\': \'6\', \'lineup_player\': \'Manning R.\', \'lineup_number\': \'14\'}, {\'lineup_position\': \'5\', \'lineup_player\': \'Wallace L.\', \'lineup_number\': \'3\'}, {\'lineup_position\': \'11\', \'lineup_player\': \'Wells N.\', \'lineup_number\': \'21\'}], \'substitutes\': [{\'lineup_position\': \'\', \'lineup_player\': \'Barnes D. (G)\', \'lineup_number\': \'33\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Chair I.\', \'lineup_number\': \'19\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Mlakar J.\', \'lineup_number\': \'16\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Osayi-Samuel B.\', \'lineup_number\': \'20\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Pugh M.\', \'lineup_number\': \'7\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Scowen J.\', \'lineup_number\': \'11\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Smith M.\', \'lineup_number\': \'6\'}]}, \'home\': {\'coach\': [{\'lineup_position\': \'\', \'lineup_player\': \'Parker S.\', \'lineup_number\': \'-1\'}], \'missing_players\': [{\'lineup_position\': \'\', \'lineup_player\': \'Arter H.\', \'lineup_number\': \'-1\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Le Marchand M.\', \'lineup_number\': \'-1\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Mitrovic A.\', \'lineup_number\': \'-1\'}], \'starting_lineups\': [{\'lineup_position\': \'5\', \'lineup_player\': \'Bryan J.\', \'lineup_number\': \'23\'}, {\'lineup_position\': \'8\', \'lineup_player\': \'Cairney T. (C)\', \'lineup_number\': \'10\'}, {\'lineup_position\': \'11\', \'lineup_player\': \'Cavaleiro I.\', \'lineup_number\': \'19\'}, {\'lineup_position\': \'6\', \'lineup_player\': \'Johansen S.\', \'lineup_number\': \'8\'}, {\'lineup_position\': \'10\', \'lineup_player\': \'Kamara A.\', \'lineup_number\': \'47\'}, {\'lineup_position\': \'9\', \'lineup_player\': \'Knockaert A.\', \'lineup_number\': \'24\'}, {\'lineup_position\': \'3\', \'lineup_player\': \'Mawson A.\', \'lineup_number\': \'5\'}, {\'lineup_position\': \'2\', \'lineup_player\': \'Odoi D.\', \'lineup_number\': \'4\'}, {\'lineup_position\': \'4\', \'lineup_player\': \'Ream T.\', \'lineup_number\': \'13\'}, {\'lineup_position\': \'7\', \'lineup_player\': \'Reed H.\', \'lineup_number\': \'21\'}, {\'lineup_position\': \'1\', \'lineup_player\': \'Rodak M. (G)\', \'lineup_number\': \'12\'}], \'substitutes\': [{\'lineup_position\': \'\', \'lineup_player\': \'Bettinelli M. (G)\', \'lineup_number\': \'1\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Christie C.\', \'lineup_number\': \'22\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Kebano N.\', \'lineup_number\': \'7\'}, {\'lineup_position\': \'\', \'lineup_player\': \'McDonald K.\', \'lineup_number\': \'6\'}, {\'lineup_position\': \'\', \'lineup_player\': \'Onomah J.\', \'lineu ...
#  'match_awayteam_extra_score': '1',
#  'match_awayteam_halftime_score': '1',
#  'match_awayteam_id': 2645,
#  'match_awayteam_name': 'QPR',
#  'match_awayteam_penalty_score': '',
#  'match_awayteam_score': '1',
#  'match_awayteam_system': '5 - 3 - 2',
#  'match_date': 1574380800.0,
#  'match_hometeam_extra_score': '1',
#  'match_hometeam_halftime_score': '1',
#  'match_hometeam_id': 2639,
#  'match_hometeam_name': 'Fulham',
#  'match_hometeam_penalty_score': '',
#  'match_hometeam_score': '2',
#  'match_hometeam_system': '4 - 3 - 3',
#  'match_id': 242310,
#  'match_live': 0,
#  'match_status': 'Finished',
#  'match_time': '20:45',
#  'statistics': "[{'type': 'Ball Possession', 'away': '50%', 'home': '50%'}, {'type': 'Goal Attempts', 'away': '19', 'home': '12'}, {'type': 'Shots on Goal', 'away': '7', 'home': '4'}, {'type': 'Shots off Goal', 'away': '5', 'home': '7'}, {'type': 'Blocked Shots', 'away': '7', 'home': '1'}, {'type': 'Corner Kicks', 'away': '11', 'home': '4'}, {'type': 'Offsides', 'away': '2', 'home': '1'}, {'type': 'Goalkeeper Saves', 'away': '2', 'home': '6'}, {'type': 'Fouls', 'away': '15', 'home': '13'}, {'type': 'Yellow Cards', 'away': '0', 'home': '1'}, {'type': 'Attacks', 'away': '102', 'home': '98'}, {'type': 'Dangerous Attacks', 'away': '54', 'home': '42'}]",
#  'substitutions': "{'away': [{'substitution': 'Amos L. | Chair I.', 'time': '65'}, {'substitution': 'Wells N. | Scowen J.', 'time': '66'}, {'substitution': 'Ball D. | Mlakar J.', 'time': '81'}], 'home': [{'substitution': 'Reed H. | Reid B.', 'time': '55'}, {'substitution': 'Knockaert A. | Christie C.', 'time': '75'}, {'substitution': 'Cavaleiro I. | McDonald K.', 'time': '90+1'}]}"}

# %%
len(db_con.get_events(team_name='West Brom'))
# Out:
# 5

# %%
matches = db_con.get_events(team_name='West Brom')

# %%
matches[242296]
# Out:
# {'cards': "[{'away_fault': 'Livermore J.', 'home_fault': '', 'time': '16', 'card': 'yellow card'}, {'away_fault': '', 'home_fault': 'Eaves T.', 'time': '69', 'card': 'yellow card'}, {'away_fault': '', 'home_fault': 'de Wijs J.', 'time': '87', 'card': 'yellow card'}, {'away_fault': 'Sawyers R.', 'home_fault': '', 'time': '90', 'card': 'yellow card'}, {'away_fault': 'Johnstone S.', 'home_fault': '', 'time': '90+1', 'card': 'yellow card'}, {'away_fault': '', 'home_fault': 'Lichaj E.', 'time': '90+3', 'card': 'yellow card'}]",
#  'country_id': 41.0,
#  'country_name': 'England',
#  'goalscorer': "[{'score': '0 - 1', 'home_scorer': '', 'time': '28', 'away_scorer': 'Livermore J.'}]",
#  'league_id': 149.0,
#  'league_name': 'Championship',
#  'lineup': "{'home': {'coach': [{'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'McCann G.'}], 'substitutes': [{'lineup_position': '', 'lineup_number': '8', 'lineup_player': 'Batty D.'}, {'lineup_position': '', 'lineup_number': '9', 'lineup_player': 'Eaves T.'}, {'lineup_position': '', 'lineup_number': '18', 'lineup_player': 'Honeyman G.'}, {'lineup_position': '', 'lineup_number': '13', 'lineup_player': 'Ingram M. (G)'}, {'lineup_position': '', 'lineup_number': '31', 'lineup_player': 'Lewis-Potter K.'}, {'lineup_position': '', 'lineup_number': '25', 'lineup_player': 'Pennington M.'}, {'lineup_position': '', 'lineup_number': '3', 'lineup_player': 'Tafazolli R.'}], 'missing_players': [{'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'Balogh N.'}, {'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'MacDonald A.'}, {'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'Magennis J.'}, {'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'Toral J.'}], 'starting_lineups': [{'lineup_position': '11', 'lineup_number': '20', 'lineup_player': 'Bowen J.'}, {'lineup_position': '8', 'lineup_number': '19', 'lineup_player': 'Bowler J.'}, {'lineup_position': '3', 'lineup_number': '5', 'lineup_player': 'Burke R.'}, {'lineup_position': '4', 'lineup_number': '4', 'lineup_player': 'de Wijs J.'}, {'lineup_position': '5', 'lineup_number': '26', 'lineup_player': 'Elder C.'}, {'lineup_position': '10', 'lineup_number': '11', 'lineup_player': 'Grosicki K.'}, {'lineup_position': '9', 'lineup_number': '36', 'lineup_player': 'Irvine J.'}, {'lineup_position': '2', 'lineup_number': '2', 'lineup_player': 'Lichaj E. (C)'}, {'lineup_position': '1', 'lineup_number': '1', 'lineup_player': 'Long G. (G)'}, {'lineup_position': '6', 'lineup_number': '37', 'lineup_player': 'Lopes L.'}, {'lineup_position': '7', 'lineup_number': '6', 'lineup_player': 'Stewart K.'}]}, 'away': {'coach': [{'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'Bilic S.'}], 'substitutes': [{'lineup_position': '', 'lineup_number': '15', 'lineup_player': 'Austin C.'}, {'lineup_position': '', 'lineup_number': '23', 'lineup_player': 'Bond J. (G)'}, {'lineup_position': '', 'lineup_number': '11', 'lineup_player': 'Brunt C.'}, {'lineup_position': '', 'lineup_number': '21', 'lineup_player': 'Edwards K.'}, {'lineup_position': '', 'lineup_number': '26', 'lineup_player': 'Hegazy A.'}, {'lineup_position': '', 'lineup_number': '7', 'lineup_player': 'Krovinovic F.'}, {'lineup_position': '', 'lineup_number': '9', 'lineup_player': 'Zohore K.'}], 'missing_players': [{'lineup_position': '', 'lineup_number': '-1', 'lineup_player': 'Gibbs K.'}], 'starting_lineups': [{'lineup_position': '3', 'lineup_number': '6', 'lineup_player': 'Ajayi S.'}, {'lineup_position': '4', 'lineup_number': '5', 'lineup_player': 'Bartley K.'}, {'lineup_position': '10', 'lineup_number': '29', 'lineup_player': 'Diangana G.'}, {'lineup_position': '2', 'lineup_number': '2', 'lineup_player': 'Furlong D.'}, {'lineup_position': '1', 'lineup_number': '1', 'lineup_player': 'Johnstone S. (G)'}, {'lineup_position': '6', 'lineup_number': '8', 'lineup_player': 'Livermore J. (C)'}, {'lineup_position': '9', 'lineup_number': '12', 'lineup_player': 'Pereira M.'}, {'lineup_position': '8', 'lineup_number': '10', 'lineup_player': 'Phillips M.'}, {'lineup_position': '11', 'lineup_number': '4', 'lineup_player': 'Robson-Kanu H.'}, {'lineup_position': '7', 'lineup_number': '19', 'lineup_player': 'Sawyers R.'}, {'lineup_position': '5', 'lineup_number': '14', 'lineup_player': 'Townsend C.'}]}}",
#  'match_awayteam_extra_score': '1',
#  'match_awayteam_halftime_score': '1',
#  'match_awayteam_id': '2625',
#  'match_awayteam_name': 'West Brom',
#  'match_awayteam_penalty_score': '',
#  'match_awayteam_score': '1',
#  'match_awayteam_system': '4 - 2 - 3 - 1',
#  'match_date': 1573257600.0,
#  'match_hometeam_extra_score': '0',
#  'match_hometeam_halftime_score': '0',
#  'match_hometeam_id': '2633',
#  'match_hometeam_name': 'Hull',
#  'match_hometeam_penalty_score': '',
#  'match_hometeam_score': '0',
#  'match_hometeam_system': '4 - 2 - 3 - 1',
#  'match_id': 242296.0,
#  'match_live': '0',
#  'match_status': 'Finished',
#  'match_time': '16:00',
#  'statistics': "[{'type': 'Ball Possession', 'home': '40%', 'away': '60%'}, {'type': 'Goal Attempts', 'home': '10', 'away': '9'}, {'type': 'Shots on Goal', 'home': '3', 'away': '2'}, {'type': 'Shots off Goal', 'home': '6', 'away': '7'}, {'type': 'Blocked Shots', 'home': '1', 'away': '0'}, {'type': 'Corner Kicks', 'home': '2', 'away': '4'}, {'type': 'Offsides', 'home': '3', 'away': '4'}, {'type': 'Goalkeeper Saves', 'home': '1', 'away': '3'}, {'type': 'Fouls', 'home': '11', 'away': '10'}, {'type': 'Yellow Cards', 'home': '3', 'away': '3'}, {'type': 'Attacks', 'home': '107', 'away': '137'}, {'type': 'Dangerous Attacks', 'home': '55', 'away': '70'}]",
#  'substitutions': "{'home': [{'substitution': 'Bowler J. | Eaves T.', 'time': '46'}, {'substitution': 'Stewart K. | Honeyman G.', 'time': '71'}, {'substitution': 'Lopes L. | Lewis-Potter K.', 'time': '89'}], 'away': [{'substitution': 'Phillips M. | Krovinovic F.', 'time': '63'}, {'substitution': 'Diangana G. | Edwards K.', 'time': '78'}, {'substitution': 'Robson-Kanu H. | Zohore K.', 'time': '90+3'}]}"}

# %%
# Out:
# INFO:root:updating league 149 from fetch
# INFO:root:in update_league_db_standings_from_fetch and data is fresh
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# INFO:root:updating league 177 from fetch
# INFO:root:in update_league_db_standings_from_fetch and data is fresh

# %%
team_list
# Out:
# [{'team_name': 'West Brom', 'team_id': '2625', 'league_id': 149},
#  {'team_name': 'Preston', 'team_id': '2643', 'league_id': 149},
#  {'team_name': 'Leeds', 'team_id': '2653', 'league_id': 149},
#  {'team_name': 'Swansea', 'team_id': '2618', 'league_id': 149},
#  {'team_name': 'Nottingham', 'team_id': '2634', 'league_id': 149},
#  {'team_name': 'Bristol City', 'team_id': '2650', 'league_id': 149},
#  {'team_name': 'Fulham', 'team_id': '2639', 'league_id': 149},
#  {'team_name': 'Sheffield Wed', 'team_id': '2651', 'league_id': 149},
#  {'team_name': 'Brentford', 'team_id': '2644', 'league_id': 149},
#  {'team_name': 'QPR', 'team_id': '2645', 'league_id': 149},
#  {'team_name': 'Charlton', 'team_id': '2663', 'league_id': 149},
#  {'team_name': 'Hull', 'team_id': '2633', 'league_id': 149},
#  {'team_name': 'Birmingham', 'team_id': '2631', 'league_id': 149},
#  {'team_name': 'Cardiff', 'team_id': '2637', 'league_id': 149},
#  {'team_name': 'Millwall', 'team_id': '2638', 'league_id': 149},
#  {'team_name': 'Derby', 'team_id': '2642', 'league_id': 149},
#  {'team_name': 'Reading', 'team_id': '2647', 'league_id': 149},
#  {'team_name': 'Blackburn', 'team_id': '2680', 'league_id': 149},
#  {'team_name': 'Huddersfield', 'team_id': '2622', 'league_id': 149},
#  {'team_name': 'Wigan', 'team_id': '2679', 'league_id': 149},
#  {'team_name': 'Luton', 'team_id': '2695', 'league_id': 149},
#  {'team_name': 'Middlesbrough', 'team_id': '2648', 'league_id': 149},
#  {'team_name': 'Stoke', 'team_id': '2624', 'league_id': 149},
#  {'team_name': 'Barnsley', 'team_id': '2652', 'league_id': 149},
#  {'team_name': 'West Brom', 'team_id': '2625', 'league_id': 149},
#  {'team_name': 'Preston', 'team_id': '2643', 'league_id': 149},
#  {'team_name': 'Leeds', 'team_id': '2653', 'league_id': 149},
#  {'team_name': 'Swansea', 'team_id': '2618', 'league_id': 149},
#  {'team_name': 'Nottingham', 'team_id': '2634', 'league_id': 149},
#  {'team_name': 'Bristol City', 'team_id': '2650', 'league_id': 149},
#  {'team_name': 'Fulham', 'team_id': '2639', 'league_id': 149},
#  {'team_name': 'Sheffield Wed', 'team_id': '2651', 'league_id': 149},
#  {'team_name': 'Brentford', 'team_id': '2644', 'league_id': 149},
#  {'team_name': 'QPR', 'team_id': '2645', 'league_id': 149},
#  {'team_name': 'Charlton', 'team_id': '2663', 'league_id': 149},
#  {'team_name': 'Hull', 'team_id': '2633', 'league_id': 149},
#  {'team_name': 'Birmingham', 'team_id': '2631', 'league_id': 149},
#  {'team_name': 'Cardiff', 'team_id': '2637', 'league_id': 149},
#  {'team_name': 'Millwall', 'team_id': '2638', 'league_id': 149},
#  {'team_name': 'Derby', 'team_id': '2642', 'league_id': 149},
#  {'team_name': 'Reading', 'team_id': '2647', 'league_id': 149},
#  {'team_name': 'Blackburn', 'team_id': '2680', 'league_id': 149},
#  {'team_name': 'Huddersfield', 'team_id': '2622', 'league_id': 149},
#  {'team_name': 'Wigan', 'team_id': '2679', 'league_id': 149},
#  {'team_name': 'Luton', 'team_id': '2695', 'league_id': 149},
#  {'team_name': 'Middlesbrough', 'team_id': '2648', 'league_id': 149},
#  {'team_name': 'Stoke', 'team_id': '2624', 'league_id': 149},
#  {'team_name': 'Barnsley', 'team_id': '2652', 'league_id': 149}]

# %%
def get_all_teams():
    match_id = int(match_id)
    match_info = db_con.get_events(match_id=match_id)[match_id]
    return jsonify(match_info)
# Out:
#    country_id country_name  league_id   league_name league_season
# 0          41      England        149  Championship     2019/2020
# 1          46       France        177       Ligue 2     2019/2020
