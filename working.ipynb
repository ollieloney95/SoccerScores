# %%
import pandas as pd
import requests
import threading
from datetime import datetime, timedelta
import numpy as np
import ast
from flask import config


class DiskConnection:
    """
    manages the disk read and writes and inital setup from disk
    """

    def __init__(self, lock, config):
        self.lock = lock
        self.config = config
        self.leagues_db = pd.DataFrame(columns=['country_id', 'country_name', 'league_id', 'league_name'])
        self.events_db = pd.DataFrame()
        self.league_db_standings = {}
        self.setup_all_league_standings_from_disk()

    def get_dbs(self):
        return(self.leagues_db, self.events_db, self.league_db_standings)

    def write_db_to_disk(self, path, db):
        """
        write pandas df to a csv
        """
        logging.info('writing db to fisk at {}'.format(path))
        try:
            with self.lock:
                db.to_csv(path)
            return True
        except Exception as e:
            logging.error('error in write_db_to_disk {}'.format(e))
        return False

    def read_db_from_disk(self, path, index=True):
        """
        return df from disk via path
        """
        logging.info('getting db at {} from disk'.format(path))
        try:
            with self.lock:
                df = pd.read_csv(path, index=index)
            return df
        except Exception as e:
            logging.error('error in getting db at {} error is {}'.format(path,e))
            return pd.DataFrame()

    def setup_all_league_standings_from_disk(self):
        if self.setup_leagues_db_from_disk() and self.setup_events_db_from_disk():
            for league_id in self.leagues_db.league_id:
                self.setup_league_standings_db_from_disk(league_id)
            return True
        return False

    def setup_leagues_db_from_disk(self):
        df = self.read_db_from_disk(self.config.path_leagues_db, False)
        if df.empty:
            return False
        self.leagues_db = df
        return True

    def setup_events_db_from_disk(self):
        df = self.read_db_from_disk(self.config.path_events_db)
        if df.empty:
            return False
        df = df.astype({'match_id': 'int32', 'country_id': 'int32', 'league_id':'int32'}).set_index('match_id', drop=False)
        df['match_id'] = df['match_id'].astype('int64')
        df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
        self.events_db = df
        return True

    def setup_league_standings_db_from_disk(self, league_id):
        path = self.config.path_league_standings_stem + str(league_id) + ".csv"
        df = self.read_db_from_disk(path)
        if df.empty:
            return False
        self.league_db_standings[league_id] = df
        return True




class HostConnection:
    """
    manages the fetches from host
    """

    def __init__(self, config, disk_connection):
        self.config = config
        self.last_refresh_times = {}
        self.disk_connection = disk_connection


    def refresh_all_leagues_from_fetch(self, leagues_db, league_db_standings):
        for league_id in leagues_db.league_id:
            league_db_standings[league_id] = self.update_league_db_standings_from_fetch(league_id, league_db_standings)
        return league_db_standings


    def update_last_refresh_times(self, id):
        self.last_refresh_times[id] = datetime.now()


    def is_data_fresh(self, id):
        if not id in self.last_refresh_times:
            return False
        time_since_update_mins = (datetime.now() - self.last_refresh_times[id]).seconds / 60
        if time_since_update_mins > self.config.refresh_time_mins:
            return False
        return True


    def update_leagues_db_from_fetch(self, leagues_db):
        # check if data is already fresh
        if self.is_data_fresh(0):
            logging.info('in update_leagues_db_from_fetch and data is fresh')
            return leagues_db
        logging.info('in update_leagues_db_from_fetch data is stale')

        # fetch data from webservice
        path = self.config.apifootball_host + '/?action=get_leagues&APIkey=' + self.config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            leagues_db = df.combine_first(leagues_db)
            self.disk_connection.write_db_to_disk(self.config.path_leagues_db, leagues_db)
            self.update_last_refresh_times(0)
        except Exception as e:
            logging.error('error in update_leagues_db_from_fetch {}'.format(e))
        return leagues_db


    def update_events_from_fetch(self, date_from, date_to, events_db):
        # check if data is already fresh
        if self.is_data_fresh(1):
            logging.info('in update_events_from_fetch and data is fresh')
            return True
        logging.info('in update_events_from_fetch data is stale')

        # fetch data from webservice
        date_from = self._date_to_string(date_from)
        date_to = self._date_to_string(date_to)
        path = self.config.apifootball_host + '/?action=get_events&from=' + date_from + '&to=' + date_to + '&APIkey=' + self.config.apifootball_key
        try:
            logging.info('fetch for {}'.format(path))
            response = requests.get(path)
            df = pd.DataFrame(response.json()).astype({'match_id': 'int32', 'country_id': 'int32', 'league_id':'int32'}).set_index('match_id', drop=False)
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
            events_db = df.combine_first(events_db)

            self.disk_connection.write_db_to_disk(self.config.path_events_db, events_db)
            self.update_last_refresh_times(1)
        except Exception as e:
            logging.error('error in update_events_from_fetch {}'.format(e))
        return events_db


    def update_league_db_standings_from_fetch(self, league_id, league_db_standings):
        # check if data is already fresh
        if self.is_data_fresh(league_id):
            logging.info('in update_league_db_standings_from_fetch and data is fresh')
            return league_db_standings[league_id]
        logging.info('in update_league_db_standings_from_fetch data is stale')

        # fetch data from webservice
        path = self.config.apifootball_host + '/?action=get_standings&league_id=' + str(
            league_id) + '&APIkey=' + self.config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            logging.info('changed league_db_standings from the fetch for {}'.format(league_id))
            self.disk_connection.write_db_to_disk(self.config.path_league_standings_stem + str(league_id), df)
            self.update_last_refresh_times(league_id)
        except Exception as e:
            logging.error('error in update_league_db_standings_from_fetch {}'.format(e))
        return df

    def _date_to_string(self, date):
        yyyy = str(date.year)
        mm = str(date.month)
        dd = str(date.day)
        if len(mm) == 1:
            mm = '0' + mm
        if len(dd) == 1:
            dd = '0' + dd
        return yyyy + '-' + mm + '-' + dd



class DatabaseConnection:
    """
    uses DiskConnection to setup dbs and write update
    uses HostConnection to refresh the dbs
    """

    def __init__(self, config):
        self.config = config
        self.lock = threading.Lock()
        self.disk_connection = DiskConnection(self.lock, self.config)
        self.leagues_db, self.events_db, self.league_db_standings = self.disk_connection.get_dbs()
        self.host_connection = HostConnection(self.config, self.disk_connection)

        # inital updates
        date_from = datetime.now() - timedelta(days=14)
        date_to = datetime.now() + timedelta(days=14)
        self.events_db = self.host_connection.update_events_from_fetch(date_from, date_to, self.events_db)
        self.leagues_db = self.host_connection.update_leagues_db_from_fetch(self.leagues_db)
        self.league_db_standings = self.host_connection.refresh_all_leagues_from_fetch(self.leagues_db, self.league_db_standings)


    def get_events(self, league_id=None, date_from=None, date_to=None, match_id=None):
        df = self.events_db.copy()
        trues = np.array([True]*len(df))

        # apply filters
        match_id_filter = df.index == match_id if match_id else trues
        league_id_filter = df['league_id'] == league_id if league_id else trues
        date_from_filter = df['match_date'] > date_from.replace(hour=0, minute=0, second=0) if date_from else trues
        date_to_filter = df['match_date'] < date_to.replace(hour=23, minute=59, second=0) if date_to else trues

        # format the dataframe correctly
        df = df.replace(np.nan, '', regex=True)
        df = df.loc[match_id_filter & league_id_filter & date_from_filter & date_to_filter]
        df['match_date'] = [d.timestamp() for d in df['match_date']]
        #df['lineup'] = [ast.literal_eval(d) for d in df['lineup']]
        #df['cards'] = [ast.literal_eval(d) for d in df['cards']]
        #df['goalscorer'] = [ast.literal_eval(d) for d in df['goalscorer']]
        #df['statistics'] = [ast.literal_eval(d) for d in df['statistics']]

        return df.to_dict('index')


    def df_to_strings(self, df):
        for col in df.columns:
            df[col] = df[col].astype(str)
        return df


    def get_league_db(self):
        self.leagues_db = self.host_connection.update_leagues_db_from_fetch(self.leagues_db)
        return self.leagues_db


    def get_league_db_standings(self, league_id):
        self.league_db_standings[league_id] = self.host_connection.update_league_db_standings_from_fetch(league_id, self.league_db_standings)
        return self.league_db_standings.get(league_id, pd.DataFrame())


    def get_leagues(self):
        """
        returns the league and country info in a dictionary form
        """
        logging.info('inside get_leagues')
        df = self.df_to_strings(self.get_league_db())
        leagues_dict = {}
        cids = list(set(df['country_id']))
        df = df.set_index('country_id')
        for cid in cids:
            if sum(df.index == cid) > 1:
                league_names = list(df.loc[cid]['league_name'])
                league_ids = list(df.loc[cid]['league_id'])
                country_name = list(df.loc[cid]['country_name'])[0]
            else:
                league_names = [df.loc[cid]['league_name']]
                league_ids = [df.loc[cid]['league_id']]
                country_name = df.loc[cid]['country_name']
            leagues_dict[cid] = {
                'country_name': country_name,
                'leagues': {
                    'league_ids': league_ids,
                    'country_name': country_name,
                    'league_names': league_names
                }
            }
        return leagues_dict


#@app.route('/')
def check_server():
    return "connected to middle layer server"


#@app.route('/get_leagues_db/', methods=['GET'])
def get_leagues_db():
    logging.info("get_leagues_db")
    df = db_con.get_league_db()
    return (df.to_dict('index'))


#@app.route('/get_sidebar_info/', methods=['GET'])
def get_sidebar_info():
    return (db_con.get_leagues())


#@app.route('/get_league_standings_db/<league_id>', methods=['GET'])
def get_league_standings_db(league_id):
    league_id = int(league_id)
    df = db_con.get_league_db_standings(league_id)
    if df.empty:
        return ('league_id not recognised')
    return (df.to_dict('index'))


#@app.route('/get_fixtures/<league_id>', methods=['GET'])
def get_fixtures(league_id):
    league_id = int(league_id)
    date_from = datetime.now()
    date_to = datetime.now() + timedelta(days=14)
    return (db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_results/<league_id>', methods=['GET'])
def get_results(league_id):
    league_id = int(league_id)
    date_from = datetime.now() - timedelta(days=14)
    date_to = datetime.now()
    return (db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_match/<match_id>', methods=['GET'])
def get_match(match_id):
    match_id = int(match_id)
    match_info = db_con.get_events(match_id=match_id)[match_id]
    return (match_info)

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

global db_con
db_con = DatabaseConnection(config)  # or whatever you need to do
# Out:
# INFO:root:getting db at /Users/ollieloney/SoccerScores/databases/leagues_db.csv from disk
# ERROR:root:error in getting db at /Users/ollieloney/SoccerScores/databases/leagues_db.csv error is parser_f() got an unexpected keyword argument 'index'
# INFO:root:in update_events_from_fetch data is stale
# INFO:root:fetch for https://apifootball.com/api/?action=get_events&from=2019-10-15&to=2019-11-12&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_events&from=2019-10-15&to=2019-11-12&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/events_db.csv
# INFO:root:in update_leagues_db_from_fetch data is stale
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_leagues&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 180
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/leagues_db.csv
# INFO:root:in update_league_db_standings_from_fetch data is stale
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=63&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 63
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_63
# INFO:root:in update_league_db_standings_from_fetch data is stale
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=128&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 128
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_128

# %%
get_sidebar_info()
# Out:
# INFO:root:inside get_leagues
# INFO:root:in update_leagues_db_from_fetch and data is fresh
# {'173': {'country_name': 'France',
#   'leagues': {'league_ids': ['128'],
#    'country_name': 'France',
#    'league_names': ['Ligue 2']}},
#  '169': {'country_name': 'England',
#   'leagues': {'league_ids': ['63'],
#    'country_name': 'England',
#    'league_names': ['Championship']}}}

# %%
get_leagues_db()
# Out:
# INFO:root:get_leagues_db
# INFO:root:in update_leagues_db_from_fetch and data is fresh
# {0: {'country_id': '169',
#   'country_name': 'England',
#   'league_id': '63',
#   'league_name': 'Championship'},
#  1: {'country_id': '173',
#   'country_name': 'France',
#   'league_id': '128',
#   'league_name': 'Ligue 2'}}

# %%
get_results('63')
# Out:
# {455326: {'cards': [{'time': "38'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'S.  Sam Hutchinson'},
#    {'time': "64'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'L.  Liam Palmer'},
#    {'time': "90'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'M.  Morgan Fox'}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "19'",
#     'home_scorer': '',
#     'score': '0 - 1',
#     'away_scorer': 'J.  Julian Boerner'},
#    {'time': "87'",
#     'home_scorer': 'L.  Lee Tomlin',
#     'score': '1 - 1',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Neil Etheridge',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Lee Peltier',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Sean Morrison',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Aden Flint',
#       'lineup_number': '5',
#       'lineup_position': '4'},
#      {'lineup_player': 'Joseph Bennett',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Leandro Bacuna',
#       'lineup_number': '7',
#       'lineup_position': '6'},
#      {'lineup_player': 'Marlon Pack',
#       'lineup_number': '15',
#       'lineup_position': '7'},
#      {'lineup_player': 'Joe Ralls',
#       'lineup_number': '8',
#       'lineup_position': '8'},
#      {'lineup_player': 'Nathaniel Mendez-Laing',
#       'lineup_number': '19',
#       'lineup_position': '9'},
#      {'lineup_player': 'Robert Glatzel',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': 'Josh Murphy',
#       'lineup_number': '11',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Leandro Bacuna | Danny Ward',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Nathaniel Mendez-Laing | Gavin Whyte',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Robert Glatzel | Lee Tomlin',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Alex Smithies',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Callum Paterson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Curtis Nelson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Lee Tomlin',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Gavin Whyte',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Danny Ward',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Junior Hoilett',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Neil Warnock',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Steven Fletcher',
#       'lineup_number': '9',
#       'lineup_position': '11'},
#      {'lineup_player': 'Kadeem Harris',
#       'lineup_number': '7',
#       'lineup_position': '10'},
#      {'lineup_player': 'Barry Bannan',
#       'lineup_number': '10',
#       'lineup_position': '9'},
#      {'lineup_player': 'Massimo Luongo',
#       'lineup_number': '21',
#       'lineup_position': '8'},
#      {'lineup_player': 'Adam Reach',
#       'lineup_number': '20',
#       'lineup_position': '7'},
#      {'lineup_player': 'Sam Hutchinson',
#       'lineup_number': '23',
#       'lineup_position': '6'},
#      {'lineup_player': 'Morgan Fox',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Julian Boerner',
#       'lineup_number': '13',
#       'lineup_position': '4'},
#      {'lineup_player': 'Dominic Iorfa',
#       'lineup_number': '27',
#       'lineup_position': '3'},
#      {'lineup_player': 'Liam Palmer',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Cameron Dawson',
#       'lineup_number': '25',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Barry Bannan | Atdhe Nuhiu',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kadeem Harris | Jacob Murphy',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kieran Lee',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joey Pelupessy',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jordan Thorniley',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jacob Murphy',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Atdhe Nuhiu',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Moses Odubajo',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Fernando Martin Forestieri',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Garry Monk',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Sheffield Wednesday',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '1',
#   'match_awayteam_system': '4-1-4-1',
#   'match_date': 1571356800.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '0',
#   'match_hometeam_name': 'Cardiff City',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '1',
#   'match_hometeam_system': '4-3-3',
#   'match_id': 455326,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '18:45',
#   'statistics': [{'type': 'shots on target', 'home': '4', 'away': '5'},
#    {'type': 'shots off target', 'home': '10', 'away': '7'},
#    {'type': 'possession (%)', 'home': '48', 'away': '52'},
#    {'type': 'corners', 'home': '4', 'away': '4'},
#    {'type': 'offsides', 'home': '1', 'away': '0'},
#    {'type': 'fouls', 'home': '11', 'away': '22'},
#    {'type': 'yellow cards', 'home': '0', 'away': '3'}]},
#  456661: {'cards': [{'time': "45'",
#     'home_fault': 'L.  Lewis Travis',
#     'card': 'yellowcard',
#     'away_fault': ''},
#    {'time': "78'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'J.  Jonathan Hogg'},
#    {'time': "85'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'E.  Elias Kachunga'},
#    {'time': "88'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'F.  Fraizer Campbell'}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "13'",
#     'home_scorer': '',
#     'score': '0 - 1',
#     'away_scorer': 'K.  Karlan Grant'},
#    {'time': "20'",
#     'home_scorer': 'L.  Lewis Holtby',
#     'score': '1 - 1',
#     'away_scorer': ''},
#    {'time': "33'",
#     'home_scorer': 'B.  Bradley Dack',
#     'score': '2 - 1',
#     'away_scorer': ''},
#    {'time': "63'",
#     'home_scorer': '',
#     'score': '2 - 2',
#     'away_scorer': 'J.  Juninho Bacuna'}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Christian Walton',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Ryan Nyambe',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Tosin Adarabioyo',
#       'lineup_number': '24',
#       'lineup_position': '3'},
#      {'lineup_player': 'Derrick Williams',
#       'lineup_number': '3',
#       'lineup_position': '4'},
#      {'lineup_player': 'Elliott Bennett',
#       'lineup_number': '31',
#       'lineup_position': '5'},
#      {'lineup_player': 'Lewis Travis',
#       'lineup_number': '27',
#       'lineup_position': '6'},
#      {'lineup_player': 'Bradley Johnson',
#       'lineup_number': '4',
#       'lineup_position': '7'},
#      {'lineup_player': 'Stewart Downing',
#       'lineup_number': '19',
#       'lineup_position': '8'},
#      {'lineup_player': 'Lewis Holtby',
#       'lineup_number': '22',
#       'lineup_position': '9'},
#      {'lineup_player': 'Adam Armstrong',
#       'lineup_number': '7',
#       'lineup_position': '10'},
#      {'lineup_player': 'Bradley Dack',
#       'lineup_number': '23',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Lewis Travis | Joe Rothwell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Lewis Holtby | Sam Gallagher',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Stewart Downing | Corry Evans',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joe Rothwell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Sam Gallagher',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Daniel Graham',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jayson Leutwiler',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Corry Evans',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joe Rankin-Costello',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'John Buckley',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Tony Mowbray',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Karlan Grant',
#       'lineup_number': '16',
#       'lineup_position': '11'},
#      {'lineup_player': 'Elias Kachunga',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': "Lewis O'Brien",
#       'lineup_number': '39',
#       'lineup_position': '9'},
#      {'lineup_player': 'Adama Diakhaby',
#       'lineup_number': '11',
#       'lineup_position': '8'},
#      {'lineup_player': 'Jonathan Hogg',
#       'lineup_number': '6',
#       'lineup_position': '7'},
#      {'lineup_player': 'Trevoh Chalobah',
#       'lineup_number': '8',
#       'lineup_position': '6'},
#      {'lineup_player': 'Jaden Brown',
#       'lineup_number': '28',
#       'lineup_position': '5'},
#      {'lineup_player': 'Christopher Schindler',
#       'lineup_number': '26',
#       'lineup_position': '4'},
#      {'lineup_player': 'Tommy Elphick',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Danny Simpson',
#       'lineup_number': '17',
#       'lineup_position': '2'},
#      {'lineup_player': 'Kamil Grabara',
#       'lineup_number': '1',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Trevoh Chalobah | Juninho Bacuna',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Karlan Grant | Fraizer Campbell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Adama Diakhaby | Florent Hadergjonaj',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Juninho Bacuna',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Alex Pritchard',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Fraizer Campbell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Steve Mounie',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jon Gorenc-Stankovic',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ryan Schofield',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Florent Hadergjonaj',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Danny Cowley',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Huddersfield Town',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '2',
#   'match_awayteam_system': '4-2-3-1',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '2',
#   'match_hometeam_name': 'Blackburn Rovers',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '2',
#   'match_hometeam_system': '3-4-2-1',
#   'match_id': 456661,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '11:30',
#   'statistics': [{'type': 'shots on target', 'home': '3', 'away': '2'},
#    {'type': 'shots off target', 'home': '10', 'away': '10'},
#    {'type': 'possession (%)', 'home': '63', 'away': '37'},
#    {'type': 'corners', 'home': '5', 'away': '6'},
#    {'type': 'offsides', 'home': '1', 'away': '1'},
#    {'type': 'fouls', 'home': '18', 'away': '19'},
#    {'type': 'yellow cards', 'home': '1', 'away': '3'}]},
#  456662: {'cards': [{'time': "73'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'G.  George Byers'},
#    {'time': "77'",
#     'home_fault': 'A.  Aapo Halme',
#     'card': 'yellowcard',
#     'away_fault': ''}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "67'",
#     'home_scorer': '',
#     'score': '0 - 1',
#     'away_scorer': 'A.  Andre Ayew'},
#    {'time': "70'",
#     'home_scorer': 'A.  Alex Mowatt',
#     'score': '1 - 1',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Bradley Collins',
#       'lineup_number': '40',
#       'lineup_position': '1'},
#      {'lineup_player': 'Bambo Diaby',
#       'lineup_number': '5',
#       'lineup_position': '2'},
#      {'lineup_player': 'Aapo Halme',
#       'lineup_number': '24',
#       'lineup_position': '3'},
#      {'lineup_player': 'Toby Sibbick',
#       'lineup_number': '21',
#       'lineup_position': '4'},
#      {'lineup_player': 'Dimitri Cavare',
#       'lineup_number': '12',
#       'lineup_position': '5'},
#      {'lineup_player': 'Alex Mowatt',
#       'lineup_number': '27',
#       'lineup_position': '6'},
#      {'lineup_player': 'Kenneth Dougall',
#       'lineup_number': '4',
#       'lineup_position': '7'},
#      {'lineup_player': 'Jacob Brown',
#       'lineup_number': '7',
#       'lineup_position': '8'},
#      {'lineup_player': 'Cameron McGeehan',
#       'lineup_number': '8',
#       'lineup_position': '9'},
#      {'lineup_player': 'Cauley Woodrow',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': 'Conor Chaplin',
#       'lineup_number': '11',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Cameron McGeehan | Elliot Simoes',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Dimitri Cavare | Ben Williams',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Bambo Diaby | Mads Juel Andersen',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Williams',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mads Juel Andersen',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mike-Steven Baehre',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jack Walton',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Luke Thomas',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Clarke Odour',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Elliot Simoes',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': ' ',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Sam Surridge',
#       'lineup_number': '19',
#       'lineup_position': '11'},
#      {'lineup_player': 'Bersant Celina',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'George Byers',
#       'lineup_number': '28',
#       'lineup_position': '9'},
#      {'lineup_player': 'Andre Ayew',
#       'lineup_number': '22',
#       'lineup_position': '8'},
#      {'lineup_player': 'Matt Grimes',
#       'lineup_number': '8',
#       'lineup_position': '7'},
#      {'lineup_player': 'Thomas Carroll',
#       'lineup_number': '14',
#       'lineup_position': '6'},
#      {'lineup_player': 'Jake Bidwell',
#       'lineup_number': '24',
#       'lineup_position': '5'}],
#     'substitutes': [{'lineup_player': 'Joe Rodon | Ben Wilmot',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Sam Surridge | Borja Baston',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'George Byers | Jordan Garrick',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kristoffer Nordfeldt',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Borja Baston',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kristoffer Peterson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Wayne Routledge',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Wilmot',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Connor Roberts',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jordan Garrick',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Steve Cooper',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '0',
#   'match_awayteam_name': 'Swansea City',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '1',
#   'match_awayteam_system': '4-2-3-1',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '0',
#   'match_hometeam_name': 'Barnsley',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '1',
#   'match_hometeam_system': '3-4-1-2',
#   'match_id': 456662,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '14:00',
#   'statistics': [{'type': 'shots on target', 'home': '5', 'away': '8'},
#    {'type': 'shots off target', 'home': '14', 'away': '4'},
#    {'type': 'possession (%)', 'home': '40', 'away': '60'},
#    {'type': 'corners', 'home': '2', 'away': '5'},
#    {'type': 'offsides', 'home': '3', 'away': '3'},
#    {'type': 'fouls', 'home': '8', 'away': '5'},
#    {'type': 'yellow cards', 'home': '1', 'away': '1'}]},
#  456663: {'cards': [{'time': "23'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'S.  Shaun Hutchinson'},
#    {'time': "33'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'M.  Murray Wallace'},
#    {'time': "54'",
#     'home_fault': 'O.  Ollie Watkins',
#     'card': 'yellowcard',
#     'away_fault': ''},
#    {'time': "63'",
#     'home_fault': 'B.  Bryan Mbeumo',
#     'card': 'yellowcard',
#     'away_fault': ''},
#    {'time': "64'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'J.  Jayson Molumby'},
#    {'time': "90'",
#     'home_fault': 'J.  Julian Jeanvier',
#     'card': 'yellowcard',
#     'away_fault': 'J.  Jed Wallace'},
#    {'time': "90'",
#     'home_fault': 'B.  Ben Thompson',
#     'card': 'yellowcard',
#     'away_fault': 'J.  Jed Wallace'},
#    {'time': "90'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'M.  Mahlon Romeo'}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "45'",
#     'home_scorer': '',
#     'score': '0 - 1',
#     'away_scorer': 'T.  Tom Bradshaw'},
#    {'time': "55'",
#     'home_scorer': '',
#     'score': '0 - 2',
#     'away_scorer': 'J.  Jed Wallace'},
#    {'time': "84'",
#     'home_scorer': 'J.  Joshua Dasilva',
#     'score': '1 - 2',
#     'away_scorer': ''},
#    {'time': "88'",
#     'home_scorer': 'B.  Bryan Mbeumo',
#     'score': '2 - 2',
#     'away_scorer': ''},
#    {'time': "90'",
#     'home_scorer': 'O.  Ollie Watkins',
#     'score': '3 - 2',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'David Raya',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Henrik Dalsgaard',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'Pontus Jansson',
#       'lineup_number': '18',
#       'lineup_position': '3'},
#      {'lineup_player': 'Julian Jeanvier',
#       'lineup_number': '23',
#       'lineup_position': '4'},
#      {'lineup_player': 'Rico Henry',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Mathias Jensen',
#       'lineup_number': '8',
#       'lineup_position': '6'},
#      {'lineup_player': 'Christian Noergaard',
#       'lineup_number': '6',
#       'lineup_position': '7'},
#      {'lineup_player': 'Kamohelo Mokotjo',
#       'lineup_number': '12',
#       'lineup_position': '8'},
#      {'lineup_player': 'Ollie Watkins',
#       'lineup_number': '11',
#       'lineup_position': '9'},
#      {'lineup_player': 'Nikos Karelis',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': 'Said Benrahma',
#       'lineup_number': '10',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Nikos Karelis | Bryan Mbeumo',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Christian Noergaard | Joshua Dasilva',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Tom Bradshaw',
#       'lineup_number': '9',
#       'lineup_position': '11'},
#      {'lineup_player': 'Ben Thompson',
#       'lineup_number': '8',
#       'lineup_position': '10'},
#      {'lineup_player': 'Shane Ferguson',
#       'lineup_number': '11',
#       'lineup_position': '9'},
#      {'lineup_player': 'Shaun Williams',
#       'lineup_number': '6',
#       'lineup_position': '8'},
#      {'lineup_player': 'Jayson Molumby',
#       'lineup_number': '16',
#       'lineup_position': '7'},
#      {'lineup_player': 'Jed Wallace',
#       'lineup_number': '7',
#       'lineup_position': '6'},
#      {'lineup_player': 'Murray Wallace',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Jake Cooper',
#       'lineup_number': '5',
#       'lineup_position': '4'},
#      {'lineup_player': 'Shaun Hutchinson',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Mahlon Romeo',
#       'lineup_number': '12',
#       'lineup_position': '2'},
#      {'lineup_player': 'Bartosz Bialkowski',
#       'lineup_number': '33',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Jayson Molumby | Jon Dadi Boedvarsson',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Millwall',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '2',
#   'match_awayteam_system': '4-4-1-1',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '0',
#   'match_hometeam_name': 'Brentford',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '3',
#   'match_hometeam_system': '4-3-3',
#   'match_id': 456663,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '14:00',
#   'statistics': [{'type': 'shots on target', 'home': '10', 'away': '4'},
#    {'type': 'shots off target', 'home': '13', 'away': '4'},
#    {'type': 'possession (%)', 'home': '69', 'away': '31'},
#    {'type': 'corners', 'home': '8', 'away': '4'},
#    {'type': 'offsides', 'home': '1', 'away': '1'},
#    {'type': 'fouls', 'home': '13', 'away': '13'},
#    {'type': 'yellow cards', 'home': '3', 'away': '6'}]},
#  456664: {'cards': [{'time': "57'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'M.  Martyn Waghorn'},
#    {'time': "64'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'G.  Graeme Shinnie'},
#    {'time': "65'",
#     'home_fault': 'J.  Jake Forster-Caskey',
#     'card': 'yellowcard',
#     'away_fault': ''}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "6'",
#     'home_scorer': 'M.  Macauley Bonne',
#     'score': '1 - 0',
#     'away_scorer': ''},
#    {'time': "48'",
#     'home_scorer': 'M.  Mahamadou-Naby Sarr',
#     'score': '2 - 0',
#     'away_scorer': ''},
#    {'time': "67'",
#     'home_scorer': 'C.  Conor Gallagher',
#     'score': '3 - 0',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Dillon Phillips',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Chris Solly',
#       'lineup_number': '20',
#       'lineup_position': '2'},
#      {'lineup_player': 'Dillon Phillips',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Chris Solly',
#       'lineup_number': '20',
#       'lineup_position': '2'},
#      {'lineup_player': 'Tom Lockyer',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'Tom Lockyer',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'Darren Pratley',
#       'lineup_number': '15',
#       'lineup_position': '4'},
#      {'lineup_player': 'Darren Pratley',
#       'lineup_number': '15',
#       'lineup_position': '4'},
#      {'lineup_player': 'Mahamadou-Naby Sarr',
#       'lineup_number': '23',
#       'lineup_position': '5'},
#      {'lineup_player': 'Jake Forster-Caskey',
#       'lineup_number': '8',
#       'lineup_position': '6'},
#      {'lineup_player': 'Jonathan Leko',
#       'lineup_number': '14',
#       'lineup_position': '7'},
#      {'lineup_player': 'Josh Cullen',
#       'lineup_number': '24',
#       'lineup_position': '8'},
#      {'lineup_player': 'Mahamadou-Naby Sarr',
#       'lineup_number': '23',
#       'lineup_position': '5'},
#      {'lineup_player': 'Conor Gallagher',
#       'lineup_number': '11',
#       'lineup_position': '9'},
#      {'lineup_player': 'Jonathan Williams',
#       'lineup_number': '7',
#       'lineup_position': '10'},
#      {'lineup_player': 'Jake Forster-Caskey',
#       'lineup_number': '8',
#       'lineup_position': '6'},
#      {'lineup_player': 'Macauley Bonne',
#       'lineup_number': '17',
#       'lineup_position': '11'},
#      {'lineup_player': 'Jonathan Leko',
#       'lineup_number': '14',
#       'lineup_position': '7'},
#      {'lineup_player': 'Josh Cullen',
#       'lineup_number': '24',
#       'lineup_position': '8'},
#      {'lineup_player': 'Conor Gallagher',
#       'lineup_number': '11',
#       'lineup_position': '9'},
#      {'lineup_player': 'Jonathan Williams',
#       'lineup_number': '7',
#       'lineup_position': '10'},
#      {'lineup_player': 'Macauley Bonne',
#       'lineup_number': '17',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Jonathan Williams | Sam Field',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Macauley Bonne | Tomer Hemed',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jonathan Williams | Sam Field',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Conor Gallagher | Beram Kayal',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Macauley Bonne | Tomer Hemed',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Adedeji Oshilaja',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jason Pearce',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Conor Gallagher | Beram Kayal',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Amos', 'lineup_number': '', 'lineup_position': ''},
#      {'lineup_player': 'Beram Kayal',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Adedeji Oshilaja',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Tomer Hemed',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jason Pearce',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Amos', 'lineup_number': '', 'lineup_position': ''},
#      {'lineup_player': 'Beram Kayal',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Tomer Hemed',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Chris Martin',
#       'lineup_number': '19',
#       'lineup_position': '11'},
#      {'lineup_player': 'Tom Lawrence',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'Jamie Paterson',
#       'lineup_number': '7',
#       'lineup_position': '9'},
#      {'lineup_player': 'Martyn Waghorn',
#       'lineup_number': '9',
#       'lineup_position': '8'},
#      {'lineup_player': 'Chris Martin',
#       'lineup_number': '19',
#       'lineup_position': '11'},
#      {'lineup_player': 'Krystian Bielik',
#       'lineup_number': '5',
#       'lineup_position': '7'},
#      {'lineup_player': 'Tom Lawrence',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'Graeme Shinnie',
#       'lineup_number': '4',
#       'lineup_position': '6'},
#      {'lineup_player': 'Jamie Paterson',
#       'lineup_number': '7',
#       'lineup_position': '9'},
#      {'lineup_player': 'Scott Malone',
#       'lineup_number': '46',
#       'lineup_position': '5'},
#      {'lineup_player': 'Martyn Waghorn',
#       'lineup_number': '9',
#       'lineup_position': '8'},
#      {'lineup_player': 'Matthew Clarke',
#       'lineup_number': '16',
#       'lineup_position': '4'},
#      {'lineup_player': 'Krystian Bielik',
#       'lineup_number': '5',
#       'lineup_position': '7'},
#      {'lineup_player': 'Curtis Davies',
#       'lineup_number': '33',
#       'lineup_position': '3'},
#      {'lineup_player': 'Jayden Bogle',
#       'lineup_number': '37',
#       'lineup_position': '2'},
#      {'lineup_player': 'Kelle Roos',
#       'lineup_number': '21',
#       'lineup_position': '1'},
#      {'lineup_player': 'Graeme Shinnie',
#       'lineup_number': '4',
#       'lineup_position': '6'},
#      {'lineup_player': 'Scott Malone',
#       'lineup_number': '46',
#       'lineup_position': '5'},
#      {'lineup_player': 'Matthew Clarke',
#       'lineup_number': '16',
#       'lineup_position': '4'},
#      {'lineup_player': 'Curtis Davies',
#       'lineup_number': '33',
#       'lineup_position': '3'},
#      {'lineup_player': 'Jayden Bogle',
#       'lineup_number': '37',
#       'lineup_position': '2'},
#      {'lineup_player': 'Kelle Roos',
#       'lineup_number': '21',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Krystian Bielik | Duane Holmes',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Martyn Waghorn | Florian Jozefzoon',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Krystian Bielik | Duane Holmes',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jamie Paterson | Mason Bennett',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Martyn Waghorn | Florian Jozefzoon',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Andre Wisdom',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kieran Dowell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Florian Jozefzoon',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jamie Paterson | Mason Bennett',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Hamer',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Andre Wisdom',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mason Bennett',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kieran Dowell',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Florian Jozefzoon',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Hamer',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mason Bennett',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '0',
#   'match_awayteam_name': 'Derby County',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '0',
#   'match_awayteam_system': '4-2-3-1',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '1',
#   'match_hometeam_name': 'Charlton Athletic',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '3',
#   'match_hometeam_system': '5-4-1',
#   'match_id': 456664,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '16:00',
#   'statistics': [{'type': 'shots on target', 'home': '7', 'away': '2'},
#    {'type': 'shots off target', 'home': '3', 'away': '2'},
#    {'type': 'possession (%)', 'home': '38', 'away': '62'},
#    {'type': 'corners', 'home': '7', 'away': '5'},
#    {'type': 'offsides', 'home': '2', 'away': '3'},
#    {'type': 'fouls', 'home': '16', 'away': '13'},
#    {'type': 'yellow cards', 'home': '1', 'away': '2'}]},
#  456665: {'cards': [{'time': "90'",
#     'home_fault': 'J.  Josh Bowler',
#     'card': 'yellowcard',
#     'away_fault': ''}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "29'",
#     'home_scorer': 'J.  Jarrod Bowen',
#     'score': '1 - 0',
#     'away_scorer': ''},
#    {'time': "44'",
#     'home_scorer': '',
#     'score': '1 - 1',
#     'away_scorer': 'R.  Ryan Manning'},
#    {'time': "78'",
#     'home_scorer': '',
#     'score': '1 - 2',
#     'away_scorer': 'E.  Eberechi Eze'},
#    {'time': "88'",
#     'home_scorer': '',
#     'score': '1 - 3',
#     'away_scorer': 'E.  Eberechi Eze'},
#    {'time': "90'",
#     'home_scorer': 'J.  Josh Magennis',
#     'score': '2 - 3',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'George Long',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Eric Lichaj',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Reece Burke',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'Ryan Tafazolli',
#       'lineup_number': '3',
#       'lineup_position': '4'},
#      {'lineup_player': 'Callum Elder',
#       'lineup_number': '26',
#       'lineup_position': '5'},
#      {'lineup_player': 'Kevin Stewart',
#       'lineup_number': '6',
#       'lineup_position': '6'},
#      {'lineup_player': 'Jarrod Bowen',
#       'lineup_number': '20',
#       'lineup_position': '7'},
#      {'lineup_player': 'George Honeyman',
#       'lineup_number': '18',
#       'lineup_position': '8'},
#      {'lineup_player': 'Jackson Irvine',
#       'lineup_number': '36',
#       'lineup_position': '9'},
#      {'lineup_player': 'Kamil Grosicki',
#       'lineup_number': '11',
#       'lineup_position': '10'},
#      {'lineup_player': 'Tom Eaves',
#       'lineup_number': '9',
#       'lineup_position': '11'},
#      {'lineup_player': 'George Long',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Eric Lichaj',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Reece Burke',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'George Long',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Ryan Tafazolli',
#       'lineup_number': '3',
#       'lineup_position': '4'},
#      {'lineup_player': 'Callum Elder',
#       'lineup_number': '26',
#       'lineup_position': '5'},
#      {'lineup_player': 'Eric Lichaj',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Kevin Stewart',
#       'lineup_number': '6',
#       'lineup_position': '6'},
#      {'lineup_player': 'Reece Burke',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'Jarrod Bowen',
#       'lineup_number': '20',
#       'lineup_position': '7'},
#      {'lineup_player': 'George Honeyman',
#       'lineup_number': '18',
#       'lineup_position': '8'},
#      {'lineup_player': 'Ryan Tafazolli',
#       'lineup_number': '3',
#       'lineup_position': '4'},
#      {'lineup_player': 'Jackson Irvine',
#       'lineup_number': '36',
#       'lineup_position': '9'},
#      {'lineup_player': 'Callum Elder',
#       'lineup_number': '26',
#       'lineup_position': '5'},
#      {'lineup_player': 'Kevin Stewart',
#       'lineup_number': '6',
#       'lineup_position': '6'},
#      {'lineup_player': 'Kamil Grosicki',
#       'lineup_number': '11',
#       'lineup_position': '10'},
#      {'lineup_player': 'Jarrod Bowen',
#       'lineup_number': '20',
#       'lineup_position': '7'},
#      {'lineup_player': 'Tom Eaves',
#       'lineup_number': '9',
#       'lineup_position': '11'},
#      {'lineup_player': 'George Honeyman',
#       'lineup_number': '18',
#       'lineup_position': '8'},
#      {'lineup_player': 'Jackson Irvine',
#       'lineup_number': '36',
#       'lineup_position': '9'},
#      {'lineup_player': 'Kamil Grosicki',
#       'lineup_number': '11',
#       'lineup_position': '10'},
#      {'lineup_player': 'Tom Eaves',
#       'lineup_number': '9',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Tom Eaves | Josh Magennis',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Tom Eaves | Josh Magennis',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Tom Eaves | Josh Magennis',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Nahki Wells',
#       'lineup_number': '21',
#       'lineup_position': '11'},
#      {'lineup_player': 'Eberechi Eze',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'Ilias Chair',
#       'lineup_number': '19',
#       'lineup_position': '9'},
#      {'lineup_player': 'Bright Osayi-Samuel',
#       'lineup_number': '20',
#       'lineup_position': '8'},
#      {'lineup_player': 'Josh Scowen',
#       'lineup_number': '11',
#       'lineup_position': '7'},
#      {'lineup_player': 'Geoff Cameron',
#       'lineup_number': '5',
#       'lineup_position': '6'},
#      {'lineup_player': 'Ryan Manning',
#       'lineup_number': '14',
#       'lineup_position': '5'},
#      {'lineup_player': 'Yoann Barbet',
#       'lineup_number': '29',
#       'lineup_position': '4'},
#      {'lineup_player': 'Toni Leistner',
#       'lineup_number': '37',
#       'lineup_position': '3'},
#      {'lineup_player': 'Angel Rangel',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'Liam Kelly',
#       'lineup_number': '32',
#       'lineup_position': '1'},
#      {'lineup_player': 'Nahki Wells',
#       'lineup_number': '21',
#       'lineup_position': '11'},
#      {'lineup_player': 'Eberechi Eze',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'Ilias Chair',
#       'lineup_number': '19',
#       'lineup_position': '9'},
#      {'lineup_player': 'Bright Osayi-Samuel',
#       'lineup_number': '20',
#       'lineup_position': '8'},
#      {'lineup_player': 'Josh Scowen',
#       'lineup_number': '11',
#       'lineup_position': '7'},
#      {'lineup_player': 'Geoff Cameron',
#       'lineup_number': '5',
#       'lineup_position': '6'},
#      {'lineup_player': 'Ryan Manning',
#       'lineup_number': '14',
#       'lineup_position': '5'},
#      {'lineup_player': 'Nahki Wells',
#       'lineup_number': '21',
#       'lineup_position': '11'},
#      {'lineup_player': 'Eberechi Eze',
#       'lineup_number': '10',
#       'lineup_position': '10'},
#      {'lineup_player': 'Yoann Barbet',
#       'lineup_number': '29',
#       'lineup_position': '4'},
#      {'lineup_player': 'Toni Leistner',
#       'lineup_number': '37',
#       'lineup_position': '3'},
#      {'lineup_player': 'Ilias Chair',
#       'lineup_number': '19',
#       'lineup_position': '9'},
#      {'lineup_player': 'Angel Rangel',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'Liam Kelly',
#       'lineup_number': '32',
#       'lineup_position': '1'},
#      {'lineup_player': 'Bright Osayi-Samuel',
#       'lineup_number': '20',
#       'lineup_position': '8'},
#      {'lineup_player': 'Josh Scowen',
#       'lineup_number': '11',
#       'lineup_position': '7'},
#      {'lineup_player': 'Geoff Cameron',
#       'lineup_number': '5',
#       'lineup_position': '6'},
#      {'lineup_player': 'Ryan Manning',
#       'lineup_number': '14',
#       'lineup_position': '5'},
#      {'lineup_player': 'Yoann Barbet',
#       'lineup_number': '29',
#       'lineup_position': '4'},
#      {'lineup_player': 'Toni Leistner',
#       'lineup_number': '37',
#       'lineup_position': '3'},
#      {'lineup_player': 'Angel Rangel',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'Liam Kelly',
#       'lineup_number': '32',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Nahki Wells | Jordan Hugill',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Nahki Wells | Jordan Hugill',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Queens Park Rangers',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '3',
#   'match_awayteam_system': '4-2-3-1',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '1',
#   'match_hometeam_name': 'Hull City',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '2',
#   'match_hometeam_system': '4-1-4-1',
#   'match_id': 456665,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '14:00',
#   'statistics': [{'type': 'shots on target', 'home': '3', 'away': '8'},
#    {'type': 'shots off target', 'home': '8', 'away': '7'},
#    {'type': 'possession (%)', 'home': '40', 'away': '60'},
#    {'type': 'corners', 'home': '4', 'away': '8'},
#    {'type': 'offsides', 'home': '3', 'away': '2'},
#    {'type': 'fouls', 'home': '14', 'away': '10'},
#    {'type': 'yellow cards', 'home': '1', 'away': '0'}]},
#  456666: {'cards': [{'time': "21'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'L.  Lukas Jutkiewicz'},
#    {'time': "42'",
#     'home_fault': 'E.  Ezgjan Alioski',
#     'card': 'yellowcard',
#     'away_fault': ''},
#    {'time': "43'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'I.  Ivan Sunjic'},
#    {'time': "90'",
#     'home_fault': 'F.  Francisco Casilla',
#     'card': 'yellowcard',
#     'away_fault': ''}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "65'",
#     'home_scorer': 'K.  Kalvin Phillips',
#     'score': '1 - 0',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Francisco Casilla',
#       'lineup_number': '13',
#       'lineup_position': '1'},
#      {'lineup_player': 'Luke Ayling',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Ben White',
#       'lineup_number': '5',
#       'lineup_position': '3'},
#      {'lineup_player': 'Gaetano Berardi',
#       'lineup_number': '28',
#       'lineup_position': '4'},
#      {'lineup_player': 'Kalvin Phillips',
#       'lineup_number': '23',
#       'lineup_position': '5'},
#      {'lineup_player': 'Stuart Dallas',
#       'lineup_number': '15',
#       'lineup_position': '6'},
#      {'lineup_player': 'Ezgjan Alioski',
#       'lineup_number': '10',
#       'lineup_position': '7'},
#      {'lineup_player': 'Mateusz Klich',
#       'lineup_number': '43',
#       'lineup_position': '8'},
#      {'lineup_player': 'Helder Costa',
#       'lineup_number': '17',
#       'lineup_position': '9'},
#      {'lineup_player': 'Patrick Bamford',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': 'Jack Harrison',
#       'lineup_number': '22',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Patrick Bamford | Edward Nketiah',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mateusz Klich | Tyler Roberts',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Barry Douglas',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Tyler Roberts',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Edward Nketiah',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kamil Miazek',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Robbie Gotts',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Leif Davis',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jack Clarke',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Marcelo Bielsa',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Lukas Jutkiewicz',
#       'lineup_number': '10',
#       'lineup_position': '11'},
#      {'lineup_player': 'Alvaro Gimenez',
#       'lineup_number': '24',
#       'lineup_position': '10'},
#      {'lineup_player': 'Fran Villalba',
#       'lineup_number': '17',
#       'lineup_position': '9'},
#      {'lineup_player': 'Ivan Sunjic',
#       'lineup_number': '34',
#       'lineup_position': '8'},
#      {'lineup_player': 'Jude Bellingham',
#       'lineup_number': '22',
#       'lineup_position': '7'},
#      {'lineup_player': 'Daniel Crowley',
#       'lineup_number': '7',
#       'lineup_position': '6'},
#      {'lineup_player': 'Kristian Pedersen',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Harlee Dean',
#       'lineup_number': '12',
#       'lineup_position': '4'},
#      {'lineup_player': 'Marc Roberts',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Maxime Colin',
#       'lineup_number': '5',
#       'lineup_position': '2'},
#      {'lineup_player': 'Lee Camp',
#       'lineup_number': '1',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Wes Harding',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'David Stockdale',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jake Clarke-Salter',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jacques Maghoma',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Gary Gardner',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'David Davis',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Odin Bailey',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Josep Clotet',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '0',
#   'match_awayteam_name': 'Birmingham City',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '0',
#   'match_awayteam_system': '4-4-2',
#   'match_date': 1571443200.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '0',
#   'match_hometeam_name': 'Leeds United',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '1',
#   'match_hometeam_system': '3-4-3',
#   'match_id': 456666,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '14:00',
#   'statistics': [{'type': 'shots on target', 'home': '5', 'away': '4'},
#    {'type': 'shots off target', 'home': '10', 'away': '12'},
#    {'type': 'possession (%)', 'home': '59', 'away': '41'},
#    {'type': 'corners', 'home': '9', 'away': '2'},
# ...
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Sam Surridge',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Connor Roberts',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ben Cabango',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Danny Ward',
#       'lineup_number': '23',
#       'lineup_position': '11'},
#      {'lineup_player': 'Robert Glatzel',
#       'lineup_number': '9',
#       'lineup_position': '10'},
#      {'lineup_player': 'Gavin Whyte',
#       'lineup_number': '20',
#       'lineup_position': '9'},
#      {'lineup_player': 'Joe Ralls',
#       'lineup_number': '8',
#       'lineup_position': '8'},
#      {'lineup_player': 'Marlon Pack',
#       'lineup_number': '15',
#       'lineup_position': '7'},
#      {'lineup_player': 'Nathaniel Mendez-Laing',
#       'lineup_number': '19',
#       'lineup_position': '6'},
#      {'lineup_player': 'Joseph Bennett',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Aden Flint',
#       'lineup_number': '5',
#       'lineup_position': '4'},
#      {'lineup_player': 'Sean Morrison',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Lee Peltier',
#       'lineup_number': '2',
#       'lineup_position': '2'},
#      {'lineup_player': 'Neil Etheridge',
#       'lineup_number': '1',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Robert Glatzel | Omar Bogle',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Gavin Whyte | Josh Murphy',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Nathaniel Mendez-Laing | Callum Paterson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Will Vaulks',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Leandro Bacuna',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Josh Murphy',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Alex Smithies',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Callum Paterson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Curtis Nelson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Omar Bogle',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '0',
#   'match_awayteam_name': 'Cardiff City',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '0',
#   'match_awayteam_system': '4-4-2',
#   'match_date': 1572134400.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '1',
#   'match_hometeam_name': 'Swansea City',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '1',
#   'match_hometeam_system': '4-2-3-1',
#   'match_id': 459492,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '12:00',
#   'statistics': [{'type': 'shots on target', 'home': '5', 'away': '3'},
#    {'type': 'shots off target', 'home': '14', 'away': '5'},
#    {'type': 'possession (%)', 'home': '57', 'away': '43'},
#    {'type': 'corners', 'home': '9', 'away': '3'},
#    {'type': 'offsides', 'home': '2', 'away': '3'},
#    {'type': 'fouls', 'home': '12', 'away': '15'},
#    {'type': 'yellow cards', 'home': '0', 'away': '1'}]},
#  459493: {'cards': [{'time': "4'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'A.  Antonee Robinson'},
#    {'time': "63'",
#     'home_fault': 'N.  Nathan Baker',
#     'card': 'yellowcard',
#     'away_fault': ''},
#    {'time': "68'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'S.  Sam Morsy'}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "39'",
#     'home_scorer': 'A.  Andreas Weimann',
#     'score': '1 - 0',
#     'away_scorer': ''},
#    {'time': "44'",
#     'home_scorer': '',
#     'score': '1 - 1',
#     'away_scorer': 'C.  Cheyenne Dunkley'},
#    {'time': "53'",
#     'home_scorer': '',
#     'score': '1 - 2',
#     'away_scorer': 'C.  Cheyenne Dunkley'},
#    {'time': "86'",
#     'home_scorer': 'P.  Pedro Pereira',
#     'score': '2 - 2',
#     'away_scorer': ''}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Daniel Bentley',
#       'lineup_number': '1',
#       'lineup_position': '1'},
#      {'lineup_player': 'Taylor Moore',
#       'lineup_number': '23',
#       'lineup_position': '2'},
#      {'lineup_player': 'Ashley Williams',
#       'lineup_number': '29',
#       'lineup_position': '3'},
#      {'lineup_player': 'Nathan Baker',
#       'lineup_number': '6',
#       'lineup_position': '4'},
#      {'lineup_player': 'Pedro Pereira',
#       'lineup_number': '32',
#       'lineup_position': '5'},
#      {'lineup_player': 'Kasey Palmer',
#       'lineup_number': '45',
#       'lineup_position': '6'},
#      {'lineup_player': 'Josh Brownhill',
#       'lineup_number': '8',
#       'lineup_position': '7'},
#      {'lineup_player': "Callum O'Dowda",
#       'lineup_number': '11',
#       'lineup_position': '8'},
#      {'lineup_player': 'Tommy Rowe',
#       'lineup_number': '25',
#       'lineup_position': '9'},
#      {'lineup_player': 'Andreas Weimann',
#       'lineup_number': '14',
#       'lineup_position': '10'},
#      {'lineup_player': 'Rodri',
#       'lineup_number': '31',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Taylor Moore | Niclas Eliasson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Rodri | Han-Noah Massengo',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kasey Palmer | Sammie Szmodics',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Bailey Wright',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Marley Watkins',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Sammie Szmodics',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Antoine Semenyo',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Niclas Eliasson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Niki Maeenpaeae',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Han-Noah Massengo',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Lee Johnson',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Gavin Massey',
#       'lineup_number': '11',
#       'lineup_position': '11'},
#      {'lineup_player': 'Kieffer Moore',
#       'lineup_number': '19',
#       'lineup_position': '10'},
#      {'lineup_player': 'Jamal Lowe',
#       'lineup_number': '9',
#       'lineup_position': '9'},
#      {'lineup_player': 'Sam Morsy',
#       'lineup_number': '5',
#       'lineup_position': '8'},
#      {'lineup_player': 'Lewis Macleod',
#       'lineup_number': '4',
#       'lineup_position': '7'},
#      {'lineup_player': 'Joseph Williams',
#       'lineup_number': '20',
#       'lineup_position': '6'},
#      {'lineup_player': 'Antonee Robinson',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Cedric Kipre',
#       'lineup_number': '21',
#       'lineup_position': '4'},
#      {'lineup_player': 'Cheyenne Dunkley',
#       'lineup_number': '22',
#       'lineup_position': '3'},
#      {'lineup_player': 'Dujon Sterling',
#       'lineup_number': '15',
#       'lineup_position': '2'},
#      {'lineup_player': 'David Marshall',
#       'lineup_number': '1',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Gavin Massey | Michael Jacobs',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joseph Williams | Kal Naismith',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Nathan Byrne',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Anthony Pilkington',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joe Garner',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Michael Jacobs',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jamie Jones',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Kal Naismith',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joe Gelhardt',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Paul Cook',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Wigan Athletic',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '2',
#   'match_awayteam_system': '4-3-3',
#   'match_date': 1572134400.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '1',
#   'match_hometeam_name': 'Bristol City',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '2',
#   'match_hometeam_system': '3-5-2',
#   'match_id': 459493,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '14:30',
#   'statistics': [{'type': 'shots on target', 'home': '4', 'away': '7'},
#    {'type': 'shots off target', 'home': '5', 'away': '12'},
#    {'type': 'possession (%)', 'home': '55', 'away': '45'},
#    {'type': 'corners', 'home': '5', 'away': '10'},
#    {'type': 'offsides', 'home': '2', 'away': '1'},
#    {'type': 'fouls', 'home': '8', 'away': '15'},
#    {'type': 'yellow cards', 'home': '1', 'away': '2'}]},
#  459562: {'cards': [{'time': "46'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'C.  Christian Noergaard'},
#    {'time': "57'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'R.  Rico Henry'},
#    {'time': "90'",
#     'home_fault': '',
#     'card': 'yellowcard',
#     'away_fault': 'O.  Ollie Watkins'}],
#   'country_id': 169,
#   'country_name': 'England',
#   'goalscorer': [{'time': "23'",
#     'home_scorer': '',
#     'score': '0 - 1',
#     'away_scorer': 'O.  Ollie Watkins'},
#    {'time': "48'",
#     'home_scorer': 'G.  Grant Hall',
#     'score': '1 - 1',
#     'away_scorer': ''},
#    {'time': "60'",
#     'home_scorer': '',
#     'score': '1 - 2',
#     'away_scorer': 'S.  Said Benrahma'},
#    {'time': "90'",
#     'home_scorer': '',
#     'score': '1 - 3',
#     'away_scorer': 'O.  Ollie Watkins'}],
#   'league_id': 63,
#   'league_name': 'Championship',
#   'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Liam Kelly',
#       'lineup_number': '32',
#       'lineup_position': '1'},
#      {'lineup_player': 'Angel Rangel',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'Grant Hall',
#       'lineup_number': '4',
#       'lineup_position': '3'},
#      {'lineup_player': 'Toni Leistner',
#       'lineup_number': '37',
#       'lineup_position': '4'},
#      {'lineup_player': 'Ryan Manning',
#       'lineup_number': '14',
#       'lineup_position': '5'},
#      {'lineup_player': 'Geoff Cameron',
#       'lineup_number': '5',
#       'lineup_position': '6'},
#      {'lineup_player': 'Eberechi Eze',
#       'lineup_number': '10',
#       'lineup_position': '7'},
#      {'lineup_player': 'Josh Scowen',
#       'lineup_number': '11',
#       'lineup_position': '8'},
#      {'lineup_player': 'Bright Osayi-Samuel',
#       'lineup_number': '20',
#       'lineup_position': '9'},
#      {'lineup_player': 'Ilias Chair',
#       'lineup_number': '19',
#       'lineup_position': '10'},
#      {'lineup_player': 'Nahki Wells',
#       'lineup_number': '21',
#       'lineup_position': '11'}],
#     'substitutes': [{'lineup_player': 'Geoff Cameron | Jan Mlakar',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joe Lumley',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Todd Kane',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Lee Wallace',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Marc Pugh',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Luke Amos',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Dominic Ball',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jan Mlakar',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Mark Warburton',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []},
#    'away': {'starting_lineups': [{'lineup_player': 'Said Benrahma',
#       'lineup_number': '10',
#       'lineup_position': '11'},
#      {'lineup_player': 'Ollie Watkins',
#       'lineup_number': '11',
#       'lineup_position': '10'},
#      {'lineup_player': 'Bryan Mbeumo',
#       'lineup_number': '19',
#       'lineup_position': '9'},
#      {'lineup_player': 'Kamohelo Mokotjo',
#       'lineup_number': '12',
#       'lineup_position': '8'},
#      {'lineup_player': 'Christian Noergaard',
#       'lineup_number': '6',
#       'lineup_position': '7'},
#      {'lineup_player': 'Joshua Dasilva',
#       'lineup_number': '14',
#       'lineup_position': '6'},
#      {'lineup_player': 'Rico Henry',
#       'lineup_number': '3',
#       'lineup_position': '5'},
#      {'lineup_player': 'Julian Jeanvier',
#       'lineup_number': '23',
#       'lineup_position': '4'},
#      {'lineup_player': 'Pontus Jansson',
#       'lineup_number': '18',
#       'lineup_position': '3'},
#      {'lineup_player': 'Henrik Dalsgaard',
#       'lineup_number': '22',
#       'lineup_position': '2'},
#      {'lineup_player': 'David Raya',
#       'lineup_number': '1',
#       'lineup_position': '1'}],
#     'substitutes': [{'lineup_player': 'Bryan Mbeumo | Joel Valencia',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joshua Dasilva | Mathias Jensen',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Dominic Thompson',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Ethan Pinnock',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mathias Jensen',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Joel Valencia',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Luke Daniels',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Jan Zamburek',
#       'lineup_number': '',
#       'lineup_position': ''},
#      {'lineup_player': 'Mads Rasmussen',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'coach': [{'lineup_player': 'Thomas Frank',
#       'lineup_number': '',
#       'lineup_position': ''}],
#     'substitutions': []}},
#   'match_awayteam_extra_score': '',
#   'match_awayteam_halftime_score': '1',
#   'match_awayteam_name': 'Brentford',
#   'match_awayteam_penalty_score': '',
#   'match_awayteam_score': '3',
#   'match_awayteam_system': '4-3-3',
#   'match_date': 1572220800.0,
#   'match_hometeam_extra_score': '',
#   'match_hometeam_halftime_score': '0',
#   'match_hometeam_name': 'Queens Park Rangers',
#   'match_hometeam_penalty_score': '',
#   'match_hometeam_score': '1',
#   'match_hometeam_system': '4-2-3-1',
#   'match_id': 459562,
#   'match_live': '0',
#   'match_status': 'FT',
#   'match_time': '19:45',
#   'statistics': [{'type': 'shots on target', 'home': '6', 'away': '9'},
#    {'type': 'shots off target', 'home': '2', 'away': '3'},
#    {'type': 'possession (%)', 'home': '52', 'away': '48'},
#    {'type': 'corners', 'home': '3', 'away': '6'},
#    {'type': 'offsides', 'home': '4', 'away': '3'},
#    {'type': 'fouls', 'home': '11', 'away': '15'},
#    {'type': 'yellow cards', 'home': '0', 'away': '3'}]}}

# %%
db_con.get_events(match_id='455326')
# Out:
# {}

# %%
get_match(455326)
# Out:
# {'cards': [{'time': "38'",
#    'home_fault': '',
#    'card': 'yellowcard',
#    'away_fault': 'S.  Sam Hutchinson'},
#   {'time': "64'",
#    'home_fault': '',
#    'card': 'yellowcard',
#    'away_fault': 'L.  Liam Palmer'},
#   {'time': "90'",
#    'home_fault': '',
#    'card': 'yellowcard',
#    'away_fault': 'M.  Morgan Fox'}],
#  'country_id': 169,
#  'country_name': 'England',
#  'goalscorer': [{'time': "19'",
#    'home_scorer': '',
#    'score': '0 - 1',
#    'away_scorer': 'J.  Julian Boerner'},
#   {'time': "87'",
#    'home_scorer': 'L.  Lee Tomlin',
#    'score': '1 - 1',
#    'away_scorer': ''}],
#  'league_id': 63,
#  'league_name': 'Championship',
#  'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Neil Etheridge',
#      'lineup_number': '1',
#      'lineup_position': '1'},
#     {'lineup_player': 'Lee Peltier',
#      'lineup_number': '2',
#      'lineup_position': '2'},
#     {'lineup_player': 'Sean Morrison',
#      'lineup_number': '4',
#      'lineup_position': '3'},
#     {'lineup_player': 'Aden Flint',
#      'lineup_number': '5',
#      'lineup_position': '4'},
#     {'lineup_player': 'Joseph Bennett',
#      'lineup_number': '3',
#      'lineup_position': '5'},
#     {'lineup_player': 'Leandro Bacuna',
#      'lineup_number': '7',
#      'lineup_position': '6'},
#     {'lineup_player': 'Marlon Pack',
#      'lineup_number': '15',
#      'lineup_position': '7'},
#     {'lineup_player': 'Joe Ralls',
#      'lineup_number': '8',
#      'lineup_position': '8'},
#     {'lineup_player': 'Nathaniel Mendez-Laing',
#      'lineup_number': '19',
#      'lineup_position': '9'},
#     {'lineup_player': 'Robert Glatzel',
#      'lineup_number': '9',
#      'lineup_position': '10'},
#     {'lineup_player': 'Josh Murphy',
#      'lineup_number': '11',
#      'lineup_position': '11'}],
#    'substitutes': [{'lineup_player': 'Leandro Bacuna | Danny Ward',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Nathaniel Mendez-Laing | Gavin Whyte',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Robert Glatzel | Lee Tomlin',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Alex Smithies',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Callum Paterson',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Curtis Nelson',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Lee Tomlin',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Gavin Whyte',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Danny Ward',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Junior Hoilett',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Neil Warnock',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'substitutions': []},
#   'away': {'starting_lineups': [{'lineup_player': 'Steven Fletcher',
#      'lineup_number': '9',
#      'lineup_position': '11'},
#     {'lineup_player': 'Kadeem Harris',
#      'lineup_number': '7',
#      'lineup_position': '10'},
#     {'lineup_player': 'Barry Bannan',
#      'lineup_number': '10',
#      'lineup_position': '9'},
#     {'lineup_player': 'Massimo Luongo',
#      'lineup_number': '21',
#      'lineup_position': '8'},
#     {'lineup_player': 'Adam Reach',
#      'lineup_number': '20',
#      'lineup_position': '7'},
#     {'lineup_player': 'Sam Hutchinson',
#      'lineup_number': '23',
#      'lineup_position': '6'},
#     {'lineup_player': 'Morgan Fox',
#      'lineup_number': '3',
#      'lineup_position': '5'},
#     {'lineup_player': 'Julian Boerner',
#      'lineup_number': '13',
#      'lineup_position': '4'},
#     {'lineup_player': 'Dominic Iorfa',
#      'lineup_number': '27',
#      'lineup_position': '3'},
#     {'lineup_player': 'Liam Palmer',
#      'lineup_number': '2',
#      'lineup_position': '2'},
#     {'lineup_player': 'Cameron Dawson',
#      'lineup_number': '25',
#      'lineup_position': '1'}],
#    'substitutes': [{'lineup_player': 'Barry Bannan | Atdhe Nuhiu',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Kadeem Harris | Jacob Murphy',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Kieran Lee',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Joey Pelupessy',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Jordan Thorniley',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Jacob Murphy',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Atdhe Nuhiu',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Moses Odubajo',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Fernando Martin Forestieri',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Garry Monk',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'substitutions': []}},
#  'match_awayteam_extra_score': '',
#  'match_awayteam_halftime_score': '1',
#  'match_awayteam_name': 'Sheffield Wednesday',
#  'match_awayteam_penalty_score': '',
#  'match_awayteam_score': '1',
#  'match_awayteam_system': '4-1-4-1',
#  'match_date': 1571356800.0,
#  'match_hometeam_extra_score': '',
#  'match_hometeam_halftime_score': '0',
#  'match_hometeam_name': 'Cardiff City',
#  'match_hometeam_penalty_score': '',
#  'match_hometeam_score': '1',
#  'match_hometeam_system': '4-3-3',
#  'match_id': 455326,
#  'match_live': '0',
#  'match_status': 'FT',
#  'match_time': '18:45',
#  'statistics': [{'type': 'shots on target', 'home': '4', 'away': '5'},
#   {'type': 'shots off target', 'home': '10', 'away': '7'},
#   {'type': 'possession (%)', 'home': '48', 'away': '52'},
#   {'type': 'corners', 'home': '4', 'away': '4'},
#   {'type': 'offsides', 'home': '1', 'away': '0'},
#   {'type': 'fouls', 'home': '11', 'away': '22'},
#   {'type': 'yellow cards', 'home': '0', 'away': '3'}]}

# %%
db_con.events_db
# Out:
#                                                       cards  country_id  \
# match_id
# 455326    [{'time': '38'', 'home_fault': '', 'card': 'ye...         169
# 455342    [{'time': '33'', 'home_fault': '', 'card': 'ye...         173
# 455343    [{'time': '12'', 'home_fault': '', 'card': 'ye...         173
# 455344    [{'time': '22'', 'home_fault': 'L.  Lorenzo Ra...         173
# 455345    [{'time': '32'', 'home_fault': 'Kiki', 'card':...         173
# 455346    [{'time': '56'', 'home_fault': 'B.  Benjamin S...         173
# 455347    [{'time': '64'', 'home_fault': 'P.  Pierre Gib...         173
# 455348    [{'time': '20'', 'home_fault': '', 'card': 'ye...         173
# 455349    [{'time': '35'', 'home_fault': '', 'card': 'ye...         173
# 456661    [{'time': '45'', 'home_fault': 'L.  Lewis Trav...         169
# 456662    [{'time': '73'', 'home_fault': '', 'card': 'ye...         169
# 456663    [{'time': '23'', 'home_fault': '', 'card': 'ye...         169
# 456664    [{'time': '57'', 'home_fault': '', 'card': 'ye...         169
# 456665    [{'time': '90'', 'home_fault': 'J.  Josh Bowle...         169
# 456666    [{'time': '21'', 'home_fault': '', 'card': 'ye...         169
# 456667    [{'time': '51'', 'home_fault': 'R.  Ryan Tunni...         169
# 456668    [{'time': '25'', 'home_fault': '', 'card': 'ye...         169
# 456669    [{'time': '8'', 'home_fault': 'J.  Jordan Obit...         169
# 456670    [{'time': '26'', 'home_fault': '', 'card': 'ye...         169
# 457133    [{'time': '28'', 'home_fault': '', 'card': 'ye...         173
# 456724    [{'time': '41'', 'home_fault': 'L.  Lewis Macl...         169
# 456797    [{'time': '50'', 'home_fault': '', 'card': 'ye...         173
# 457469    [{'time': '55'', 'home_fault': 'H.  Harlee Dea...         169
# 457470    [{'time': '65'', 'home_fault': '', 'card': 'ye...         169
# 457471    [{'time': '86'', 'home_fault': 'D.  Darnell Fi...         169
# 457472    [{'time': '56'', 'home_fault': '', 'card': 'ye...         169
# 457473    [{'time': '36'', 'home_fault': 'M.  Massimo Lu...         169
# 457474    [{'time': '71'', 'home_fault': 'C.  Connor Rob...         169
# 457475    [{'time': '22'', 'home_fault': '', 'card': 'ye...         169
# 457708    [{'time': '14'', 'home_fault': '', 'card': 'ye...         169
# ...                                                     ...         ...
# 462236                                                   []         169
# 462363                                                   []         173
# 462364                                                   []         173
# 462365                                                   []         173
# 462366                                                   []         173
# 462559                                                   []         169
# 463030                                                   []         169
# 463037                                                   []         173
# 464563                                                   []         173
# 464564                                                   []         173
# 464565                                                   []         173
# 464566                                                   []         173
# 464567                                                   []         173
# 464568                                                   []         173
# 464569                                                   []         173
# 464570                                                   []         173
# 464678                                                   []         169
# 464679                                                   []         169
# 464680                                                   []         169
# 464681                                                   []         169
# 464682                                                   []         169
# 464683                                                   []         169
# 464684                                                   []         169
# 464685                                                   []         169
# 464686                                                   []         169
# 464687                                                   []         169
# 464688                                                   []         169
# 465058                                                   []         173
# 465118                                                   []         169
# 465369                                                   []         173
#
#          country_name                                         goalscorer  \
# match_id
# 455326        England  [{'time': '19'', 'home_scorer': '', 'score': '...
# 455342         France                                                 []
# 455343         France                                                 []
# 455344         France  [{'time': '76'', 'home_scorer': '', 'score': '...
# 455345         France  [{'time': '7'', 'home_scorer': 'I.  Ihsan Sack...
# 455346         France                                                 []
# 455347         France                                                 []
# 455348         France  [{'time': '13'', 'home_scorer': '', 'score': '...
# 455349         France                                                 []
# 456661        England  [{'time': '13'', 'home_scorer': '', 'score': '...
# 456662        England  [{'time': '67'', 'home_scorer': '', 'score': '...
# 456663        England  [{'time': '45'', 'home_scorer': '', 'score': '...
# 456664        England  [{'time': '6'', 'home_scorer': 'M.  Macauley B...
# 456665        England  [{'time': '29'', 'home_scorer': 'J.  Jarrod Bo...
# 456666        England  [{'time': '65'', 'home_scorer': 'K.  Kalvin Ph...
# 456667        England  [{'time': '56'', 'home_scorer': 'P.  Pelly Rud...
# 456668        England  [{'time': '82'', 'home_scorer': '', 'score': '...
# 456669        England  [{'time': '90'', 'home_scorer': 'M.  Matt Miaz...
# 456670        England  [{'time': '16'', 'home_scorer': 'T.  Tyrese Ca...
# 457133         France  [{'time': '1'', 'home_scorer': '', 'score': '0...
# 456724        England  [{'time': '35'', 'home_scorer': 'J.  Jamal Low...
# 456797         France                                                 []
# 457469        England  [{'time': '31'', 'home_scorer': 'M.  Maxime Co...
# 457470        England  [{'time': '12'', 'home_scorer': '', 'score': '...
# 457471        England  [{'time': '74'', 'home_scorer': 'T.  Tom Barkh...
# 457472        England  [{'time': '29'', 'home_scorer': 'N.  Nahki Wel...
# 457473        England  [{'time': '43'', 'home_scorer': 'M.  Massimo L...
# 457474        England  [{'time': '30'', 'home_scorer': '', 'score': '...
# 457475        England  [{'time': '18'', 'home_scorer': '', 'score': '...
# 457708        England  [{'time': '65'', 'home_scorer': '', 'score': '...
# ...               ...                                                ...
# 462236        England                                                 []
# 462363         France                                                 []
# 462364         France                                                 []
# 462365         France                                                 []
# 462366         France                                                 []
# 462559        England                                                 []
# 463030        England                                                 []
# 463037         France                                                 []
# 464563         France                                                 []
# 464564         France                                                 []
# 464565         France                                                 []
# 464566         France                                                 []
# 464567         France                                                 []
# 464568         France                                                 []
# 464569         France                                                 []
# 464570         France                                                 []
# 464678        England                                                 []
# 464679        England                                                 []
# 464680        England                                                 []
# 464681        England                                                 []
# 464682        England                                                 []
# 464683        England                                                 []
# 464684        England                                                 []
# 464685        England                                                 []
# 464686        England                                                 []
# 464687        England                                                 []
# 464688        England                                                 []
# 465058         France                                                 []
# 465118        England                                                 []
# 465369         France                                                 []
#
#           league_id   league_name  \
# match_id
# 455326           63  Championship
# 455342          128       Ligue 2
# 455343          128       Ligue 2
# 455344          128       Ligue 2
# 455345          128       Ligue 2
# 455346          128       Ligue 2
# 455347          128       Ligue 2
# 455348          128       Ligue 2
# 455349          128       Ligue 2
# 456661           63  Championship
# 456662           63  Championship
# 456663           63  Championship
# 456664           63  Championship
# 456665           63  Championship
# 456666           63  Championship
# 456667           63  Championship
# 456668           63  Championship
# 456669           63  Championship
# 456670           63  Championship
# 457133          128       Ligue 2
# 456724           63  Championship
# 456797          128       Ligue 2
# 457469           63  Championship
# 457470           63  Championship
# 457471           63  Championship
# 457472           63  Championship
# 457473           63  Championship
# 457474           63  Championship
# 457475           63  Championship
# 457708           63  Championship
# ...             ...           ...
# 462236           63  Championship
# 462363          128       Ligue 2
# 462364          128       Ligue 2
# 462365          128       Ligue 2
# 462366          128       Ligue 2
# 462559           63  Championship
# 463030           63  Championship
# 463037          128       Ligue 2
# 464563          128       Ligue 2
# 464564          128       Ligue 2
# 464565          128       Ligue 2
# 464566          128       Ligue 2
# 464567          128       Ligue 2
# 464568          128       Ligue 2
# 464569          128       Ligue 2
# 464570          128       Ligue 2
# 464678           63  Championship
# 464679           63  Championship
# 464680           63  Championship
# 464681           63  Championship
# 464682           63  Championship
# 464683           63  Championship
# 464684           63  Championship
# 464685           63  Championship
# 464686           63  Championship
# 464687           63  Championship
# 464688           63  Championship
# 465058          128       Ligue 2
# 465118           63  Championship
# 465369          128       Ligue 2
#
#                                                      lineup  \
# match_id
# 455326    {'home': {'starting_lineups': [{'lineup_player...
# 455342    {'home': {'starting_lineups': [{'lineup_player...
# 455343    {'home': {'starting_lineups': [{'lineup_player...
# 455344    {'home': {'starting_lineups': [{'lineup_player...
# 455345    {'home': {'starting_lineups': [{'lineup_player...
# 455346    {'home': {'starting_lineups': [{'lineup_player...
# 455347    {'home': {'starting_lineups': [{'lineup_player...
# 455348    {'home': {'starting_lineups': [{'lineup_player...
# 455349    {'home': {'starting_lineups': [], 'substitutes...
# 456661    {'home': {'starting_lineups': [{'lineup_player...
# 456662    {'home': {'starting_lineups': [{'lineup_player...
# 456663    {'home': {'starting_lineups': [{'lineup_player...
# 456664    {'home': {'starting_lineups': [{'lineup_player...
# 456665    {'home': {'starting_lineups': [{'lineup_player...
# 456666    {'home': {'starting_lineups': [{'lineup_player...
# 456667    {'home': {'starting_lineups': [{'lineup_player...
# 456668    {'home': {'starting_lineups': [{'lineup_player...
# 456669    {'home': {'starting_lineups': [{'lineup_player...
# 456670    {'home': {'starting_lineups': [{'lineup_player...
# 457133    {'home': {'starting_lineups': [{'lineup_player...
# 456724    {'home': {'starting_lineups': [{'lineup_player...
# 456797    {'home': {'starting_lineups': [{'lineup_player...
# 457469    {'home': {'starting_lineups': [], 'substitutes...
# 457470    {'home': {'starting_lineups': [], 'substitutes...
# 457471    {'home': {'starting_lineups': [], 'substitutes...
# 457472    {'home': {'starting_lineups': [{'lineup_player...
# 457473    {'home': {'starting_lineups': [{'lineup_player...
# 457474    {'home': {'starting_lineups': [], 'substitutes...
# 457475    {'home': {'starting_lineups': [{'lineup_player...
# 457708    {'home': {'starting_lineups': [{'lineup_player...
# ...                                                     ...
# 462236    {'home': {'starting_lineups': [], 'substitutes...
# 462363    {'home': {'starting_lineups': [], 'substitutes...
# 462364    {'home': {'starting_lineups': [], 'substitutes...
# 462365    {'home': {'starting_lineups': [], 'substitutes...
# 462366    {'home': {'starting_lineups': [], 'substitutes...
# 462559    {'home': {'starting_lineups': [], 'substitutes...
# 463030    {'home': {'starting_lineups': [], 'substitutes...
# 463037    {'home': {'starting_lineups': [], 'substitutes...
# 464563    {'home': {'starting_lineups': [], 'substitutes...
# 464564    {'home': {'starting_lineups': [], 'substitutes...
# 464565    {'home': {'starting_lineups': [], 'substitutes...
# 464566    {'home': {'starting_lineups': [], 'substitutes...
# 464567    {'home': {'starting_lineups': [], 'substitutes...
# 464568    {'home': {'starting_lineups': [], 'substitutes...
# 464569    {'home': {'starting_lineups': [], 'substitutes...
# 464570    {'home': {'starting_lineups': [], 'substitutes...
# 464678    {'home': {'starting_lineups': [], 'substitutes...
# 464679    {'home': {'starting_lineups': [], 'substitutes...
# 464680    {'home': {'starting_lineups': [], 'substitutes...
# 464681    {'home': {'starting_lineups': [], 'substitutes...
# 464682    {'home': {'starting_lineups': [], 'substitutes...
# 464683    {'home': {'starting_lineups': [], 'substitutes...
# 464684    {'home': {'starting_lineups': [], 'substitutes...
# 464685    {'home': {'starting_lineups': [], 'substitutes...
# 464686    {'home': {'starting_lineups': [], 'substitutes...
# 464687    {'home': {'starting_lineups': [], 'substitutes...
# 464688    {'home': {'starting_lineups': [], 'substitutes...
# 465058    {'home': {'starting_lineups': [], 'substitutes...
# 465118    {'home': {'starting_lineups': [], 'substitutes...
# 465369    {'home': {'starting_lineups': [], 'substitutes...
#
#          match_awayteam_extra_score match_awayteam_halftime_score  \
# match_id
# 455326                                                          1
# 455342                                                          0
# 455343                                                          0
# 455344                                                          0
# 455345                                                          1
# 455346                                                          0
# 455347                                                          0
# 455348                                                          1
# 455349                                                          0
# 456661                                                          1
# 456662                                                          0
# 456663                                                          1
# 456664                                                          0
# 456665                                                          1
# 456666                                                          0
# 456667                                                          0
# 456668                                                          0
# 456669                                                          0
# 456670                                                          0
# 457133                                                          2
# 456724                                                          0
# 456797                                                          0
# 457469                                                          0
# 457470                                                          1
# 457471                                                          0
# 457472                                                          1
# 457473                                                          0
# 457474                                                          2
# 457475                                                          2
# 457708                                                          0
# ...                             ...                           ...
# 462236
# 462363
# 462364
# 462365
# 462366
# 462559
# 463030
# 463037
# 464563
# 464564
# 464565
# 464566
# 464567
# 464568
# 464569
# 464570
# 464678
# 464679
# 464680
# 464681
# 464682
# 464683
# 464684
# 464685
# 464686
# 464687
# 464688
# 465058
# 465118
# 465369
#
#            match_awayteam_name  ... match_hometeam_halftime_score  \
# match_id                        ...
# 455326     Sheffield Wednesday  ...                             0
# 455342                   Nancy  ...                             0
# 455343                Guingamp  ...                             0
# 455344                   Rodez  ...                             0
# 455345                 Le Mans  ...                             1
# 455346                 Sochaux  ...                             0
# 455347                 Orleans  ...                             0
# 455348                Paris FC  ...                             0
# 455349            Valenciennes  ...                             0
# 456661       Huddersfield Town  ...                             2
# 456662            Swansea City  ...                             0
# 456663                Millwall  ...                             0
# 456664            Derby County  ...                             1
# 456665     Queens Park Rangers  ...                             1
# 456666         Birmingham City  ...                             0
# 456667            Bristol City  ...                             0
# 456668    West Bromwich Albion  ...                             0
# 456669       Preston North End  ...                             0
# 456670                  Fulham  ...                             1
# 457133                 Lorient  ...                             1
# 456724       Nottingham Forest  ...                             1
# 456797                 Auxerre  ...                             0
# 457469        Blackburn Rovers  ...                             1
# 457470            Cardiff City  ...                             1
# 457471            Leeds United  ...                             0
# 457472                 Reading  ...                             1
# 457473              Stoke City  ...                             1
# 457474               Brentford  ...                             0
# 457475                Barnsley  ...                             0
# 457708       Charlton Athletic  ...                             0
# ...                        ...  ...                           ...
# 462236                Millwall  ...
# 462363                 Sochaux  ...
# 462364                 Le Mans  ...
# 462365                Paris FC  ...
# 462366                 Lorient  ...
# 462559       Preston North End  ...
# 463030    West Bromwich Albion  ...
# 463037                   Nancy  ...
# 464563                    Caen  ...
# 464564                  Troyes  ...
# 464565           Clermont Foot  ...
# 464566                   Niort  ...
# 464567                Le Havre  ...
# 464568                Grenoble  ...
# 464569                Paris FC  ...
# 464570             Chateauroux  ...
# 464678            Derby County  ...
# 464679              Stoke City  ...
# 464680                  Fulham  ...
# 464681    West Bromwich Albion  ...
# 464682        Blackburn Rovers  ...
# 464683       Charlton Athletic  ...
# 464684       Huddersfield Town  ...
# 464685           Middlesbrough  ...
# 464686              Luton Town  ...
# 464687            Swansea City  ...
# 464688               Brentford  ...
# 465058              AC Ajaccio  ...
# 465118            Bristol City  ...
# 465369                    Lens  ...
#
#            match_hometeam_name match_hometeam_penalty_score  \
# match_id
# 455326            Cardiff City
# 455342              AC Ajaccio
# 455343                   Niort
# 455344           Clermont Foot
# 455345                  Troyes
# 455346                 Chambly
# 455347                Grenoble
# 455348             Chateauroux
# 455349                    Caen
# 456661        Blackburn Rovers
# 456662                Barnsley
# 456663               Brentford
# 456664       Charlton Athletic
# 456665               Hull City
# 456666            Leeds United
# 456667              Luton Town
# 456668           Middlesbrough
# 456669                 Reading
# 456670              Stoke City
# 457133                Le Havre
# 456724          Wigan Athletic
# 456797                    Lens
# 457469         Birmingham City
# 457470                Millwall
# 457471       Preston North End
# 457472     Queens Park Rangers
# 457473     Sheffield Wednesday
# 457474            Swansea City
# 457475    West Bromwich Albion
# 457708            Bristol City
# ...                        ...                          ...
# 462236                 Reading
# 462363                   Niort
# 462364           Clermont Foot
# 462365                Grenoble
# 462366                    Lens
# 462559       Charlton Athletic
# 463030              Stoke City
# 463037                Le Havre
# 464563                 Auxerre
# 464564                   Nancy
# 464565                 Chambly
# 464566                 Lorient
# 464567                 Sochaux
# 464568                 Le Mans
# 464569                 Orleans
# 464570            Valenciennes
# 464678       Nottingham Forest
# 464679                Barnsley
# 464680         Birmingham City
# 464681               Hull City
# 464682            Leeds United
# 464683                Millwall
# 464684       Preston North End
# 464685     Queens Park Rangers
# 464686                 Reading
# 464687     Sheffield Wednesday
# 464688          Wigan Athletic
# 465058                Guingamp
# 465118            Cardiff City
# 465369                   Rodez
#
#          match_hometeam_score match_hometeam_system match_id match_live  \
# match_id
# 455326                      1                 4-3-3   455326          0
# 455342                      0                 4-4-2   455342          0
# 455343                      0                 5-4-1   455343          0
# 455344                      0               4-2-3-1   455344          0
# 455345                      2               4-2-3-1   455345          0
# 455346                      0                 4-3-3   455346          0
# 455347                      0               4-2-3-1   455347          0
# 455348                      0                 4-3-3   455348          0
# 455349                      0               4-2-3-1   455349          0
# 456661                      2               3-4-2-1   456661          0
# 456662                      1               3-4-1-2   456662          0
# 456663                      3                 4-3-3   456663          0
# 456664                      3                 5-4-1   456664          0
# 456665                      2               4-1-4-1   456665          0
# 456666                      1                 3-4-3   456666          0
# 456667                      3             4-1-2-1-2   456667          0
# 456668                      0               3-5-1-1   456668          0
# 456669                      1                 3-5-2   456669          0
# 456670                      2               4-3-1-2   456670          0
# 457133                      2                 4-4-2   457133          0
# 456724                      1               4-2-3-1   456724          0
# 456797                      0                 3-4-3   456797          0
# 457469                      1                 4-4-2   457469          0
# 457470                      2                 4-4-2   457470          0
# 457471                      1               4-2-3-1   457471          0
# 457472                      2                 5-3-2   457472          0
# 457473                      1               4-1-4-1   457473          0
# 457474                      0               4-2-3-1   457474          0
# 457475                      2               4-2-3-1   457475          0
# 457708                      2                 4-4-2   457708          0
# ...                       ...                   ...      ...        ...
# 462236                                                462236          0
# 462363                                                462363          0
# 462364                                                462364          0
# 462365                                                462365          0
# 462366                                                462366          0
# 462559                                                462559          0
# 463030                                                463030          0
# 463037                                                463037          0
# 464563                                                464563          0
# 464564                                                464564          0
# 464565                                                464565          0
# 464566                                                464566          0
# 464567                                                464567          0
# 464568                                                464568          0
# 464569                                                464569          0
# 464570                                                464570          0
# 464678                                                464678          0
# 464679                                                464679          0
# 464680                                                464680          0
# 464681                                                464681          0
# 464682                                                464682          0
# 464683                                                464683          0
# 464684                                                464684          0
# 464685                                                464685          0
# 464686                                                464686          0
# 464687                                                464687          0
# 464688                                                464688          0
# 465058                                                465058          0
# 465118                                                465118          0
# 465369                                                465369          0
#
#          match_status match_time  \
# match_id
# 455326             FT      18:45
# 455342             FT      18:00
# 455343             FT      18:00
# 455344             FT      18:00
# 455345             FT      18:00
# 455346             FT      18:00
# 455347             FT      18:00
# 455348             FT      18:00
# 455349             FT      18:00
# 456661             FT      11:30
# 456662             FT      14:00
# 456663             FT      14:00
# 456664             FT      16:00
# 456665             FT      14:00
# 456666             FT      14:00
# 456667             FT      16:00
# 456668             FT      14:00
# 456669             FT      16:00
# 456670             FT      14:00
# 457133             FT      15:00
# 456724             FT      13:00
# 456797             FT      18:45
# 457469             FT      20:45
# 457470             FT      18:45
# 457471             FT      20:45
# 457472             FT      20:45
# 457473             FT      20:45
# 457474             FT      20:45
# 457475             FT      21:00
# 457708             FT      18:45
# ...               ...        ...
# 462236                     15:00
# 462363                     14:00
# 462364                     14:00
# 462365                     14:00
# 462366                     14:00
# 462559                     12:00
# 463030                     20:00
# 463037                     19:45
# 464563                     19:00
# 464564                     19:00
# 464565                     19:00
# 464566                     19:00
# 464567                     19:00
# 464568                     19:00
# 464569                     19:00
# 464570                     19:00
# 464678                     12:30
# 464679                     15:00
# 464680                     15:00
# 464681                     15:00
# 464682                     15:00
# 464683                     15:00
# 464684                     15:00
# 464685                     15:00
# 464686                     15:00
# 464687                     15:00
# 464688                     15:00
# 465058                     13:45
# 465118                     12:00
# 465369                     19:45
#
#                                                  statistics
# match_id
# 455326    [{'type': 'shots on target', 'home': '4', 'awa...
# 455342    [{'type': 'shots on target', 'home': '1', 'awa...
# 455343    [{'type': 'shots on target', 'home': '1', 'awa...
# 455344    [{'type': 'shots on target', 'home': '7', 'awa...
# 455345    [{'type': 'shots on target', 'home': '6', 'awa...
# 455346    [{'type': 'shots on target', 'home': '3', 'awa...
# 455347    [{'type': 'shots on target', 'home': '2', 'awa...
# 455348    [{'type': 'shots on target', 'home': '4', 'awa...
# 455349    [{'type': 'shots on target', 'home': '1', 'awa...
# 456661    [{'type': 'shots on target', 'home': '3', 'awa...
# 456662    [{'type': 'shots on target', 'home': '5', 'awa...
# 456663    [{'type': 'shots on target', 'home': '10', 'aw...
# 456664    [{'type': 'shots on target', 'home': '7', 'awa...
# 456665    [{'type': 'shots on target', 'home': '3', 'awa...
# 456666    [{'type': 'shots on target', 'home': '5', 'awa...
# 456667    [{'type': 'shots on target', 'home': '5', 'awa...
# 456668    [{'type': 'shots on target', 'home': '7', 'awa...
# 456669    [{'type': 'shots on target', 'home': '6', 'awa...
# 456670    [{'type': 'shots on target', 'home': '5', 'awa...
# 457133    [{'type': 'shots on target', 'home': '5', 'awa...
# 456724    [{'type': 'shots on target', 'home': '6', 'awa...
# 456797    [{'type': 'shots on target', 'home': '2', 'awa...
# 457469    [{'type': 'shots on target', 'home': '6', 'awa...
# 457470    [{'type': 'shots on target', 'home': '5', 'awa...
# 457471    [{'type': 'shots on target', 'home': '2', 'awa...
# 457472    [{'type': 'shots on target', 'home': '6', 'awa...
# 457473    [{'type': 'shots on target', 'home': '4', 'awa...
# 457474    [{'type': 'shots on target', 'home': '5', 'awa...
# 457475    [{'type': 'shots on target', 'home': '3', 'awa...
# 457708    [{'type': 'shots on target', 'home': '8', 'awa...
# ...                                                     ...
# 462236                                                   []
# 462363                                                   []
# 462364                                                   []
# 462365                                                   []
# 462366                                                   []
# 462559                                                   []
# 463030                                                   []
# 463037                                                   []
# 464563                                                   []
# 464564                                                   []
# 464565                                                   []
# 464566                                                   []
# 464567                                                   []
# 464568                                                   []
# 464569                                                   []
# 464570                                                   []
# 464678                                                   []
# 464679                                                   []
# 464680                                                   []
# 464681                                                   []
# 464682                                                   []
# 464683                                                   []
# 464684                                                   []
# 464685                                                   []
# 464686                                                   []
# 464687                                                   []
# 464688                                                   []
# 465058                                                   []
# 465118                                                   []
# 465369                                                   []
#
# [100 rows x 25 columns]

# %%
db_con.events_db.index.astype('int64')
# Out:
# Int64Index([455326, 455342, 455343, 455344, 455345, 455346, 455347, 455348,
#             455349, 456661, 456662, 456663, 456664, 456665, 456666, 456667,
#             456668, 456669, 456670, 457133, 456724, 456797, 457469, 457470,
#             457471, 457472, 457473, 457474, 457475, 457708, 457709, 457710,
#             457711, 457712, 458302, 458303, 458304, 458305, 458306, 458307,
#             458308, 458309, 459243, 459244, 459245, 459246, 459247, 459248,
#             459249, 459250, 459251, 460121, 459492, 459493, 459562, 459566,
#             461997, 462014, 462015, 462016, 462017, 462018, 462228, 462229,
#             462230, 462231, 462232, 462233, 462234, 462235, 462236, 462363,
#             462364, 462365, 462366, 462559, 463030, 463037, 464563, 464564,
#             464565, 464566, 464567, 464568, 464569, 464570, 464678, 464679,
#             464680, 464681, 464682, 464683, 464684, 464685, 464686, 464687,
#             464688, 465058, 465118, 465369],
#            dtype='int64', name='match_id')

# %%
db_con.events_db['match_id'].astype('int64') == 455326

# %%
db_con.events_db['match_id'] = db_con.events_db['match_id'].astype('int64')

# %%
db_con.events_db['match_id'] == '455326'
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# match_id
# 455326    False
# 455342    False
# 455343    False
# 455344    False
# 455345    False
# 455346    False
# 455347    False
# 455348    False
# 455349    False
# 456661    False
# 456662    False
# 456663    False
# 456664    False
# 456665    False
# 456666    False
# 456667    False
# 456668    False
# 456669    False
# 456670    False
# 457133    False
# 456724    False
# 456797    False
# 457469    False
# 457470    False
# 457471    False
# 457472    False
# 457473    False
# 457474    False
# 457475    False
# 457708    False
#           ...
# 462236    False
# 462363    False
# 462364    False
# 462365    False
# 462366    False
# 462559    False
# 463030    False
# 463037    False
# 464563    False
# 464564    False
# 464565    False
# 464566    False
# 464567    False
# 464568    False
# 464569    False
# 464570    False
# 464678    False
# 464679    False
# 464680    False
# 464681    False
# 464682    False
# 464683    False
# 464684    False
# 464685    False
# 464686    False
# 464687    False
# 464688    False
# 465058    False
# 465118    False
# 465369    False
# Name: match_id, Length: 100, dtype: bool
