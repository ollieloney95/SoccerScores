# %%
import pandas as pd
import requests
import threading
from datetime import datetime, timedelta
import numpy as np
import ast

from flask import config

class DatabaseConnection:
    # this should connect to a q server to check the database for things
    def __init__(self):
        self.lock = threading.Lock()
        self.leagues_db = pd.DataFrame()
        self.events_db = pd.DataFrame()
        self.league_db_standings = {}
        self.setup_from_disk()
        self.last_refresh_times = {}
        self.refresh_events()
        self.update_leagues_db_from_fetch()
        self.refresh_all_leagues_from_fetch()

    #----------- disk io ----------------------------------------------------------------------------------------

    def write_db_to_disk(self, path, db):
        """
        write pandas df to a csv
        """
        logging.info('writing db to fisk at {}'.format(path))
        try:
            with self.lock:
                db.to_csv(path)
            return True
        except Exception as e:
            logging.error('error in write_db_to_disk {}'.format(e))
            return False

    def setup_from_disk(self):
        self.setup_leagues_from_disk()
        self.setup_events_db_from_disk()
        for league_id in self.leagues_db.league_id:
            self.setup_league_standings_db_from_disk(league_id)

    def setup_leagues_from_disk(self):
        """
        retrieves league db from disk via path in config
        """
        logging.info('getting league_db from disk')
        try:
            with self.lock:
                df = pd.read_csv(config.path_leagues_db)
            self.leagues_db = df
            logging.info('set up leagues_db from disk')
            return True
        except Exception as e:
            logging.error('error in get_league_db_from_disk {}'.format(e))
            return False

    def setup_events_db_from_disk(self):
        """
        retrieves events db from disk via path in config
        """
        logging.info('getting league_db from disk')
        try:
            with self.lock:
                df = pd.read_csv(config.path_events_db).set_index('match_id', drop=False)
            df = df.astype({'country_id': 'int32',
                            'league_id':'int32'})
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
            self.events_db = df
            return True
        except Exception as e:
            logging.error('error in setup_leagues_from_disk {}'.format(e))
            return False

    def setup_league_standings_db_from_disk(self, league_id):
        """
        retrieves league standings db from disk via path stem in config plus league_id
        """
        logging.info('setting up league_db for id {} from disk'.format(league_id))
        path = config.path_league_standings_stem + str(league_id)
        try:
            with self.lock:
                df = pd.read_csv(path)
            self.league_db_standings[league_id] = df
            logging.info('set up league_db for id {} from disk'.format(league_id))
            return True
        except Exception as e:
            logging.error('error in get_league_standings_db_from_disk {}'.format(e))
            return False

    #----------- disk io ---------------------------------------------------------------------------------------
    #----------- fetches----------------------------------------------------------------------------------------

    def refresh_all_leagues_from_fetch(self):
        if self.leagues_db.empty:
            raise Exception('leagues_db is empty so something went wrong !')
        for league_id in self.leagues_db.league_id:
            self.update_league_db_standings_from_fetch(league_id)

    def update_leagues_db_from_fetch(self):
        """
        using an api call sets up the leagues_db
        """
        logging.info('updating  leagues_db from fetch')
        path = config.apifootball_host + '/?action=get_leagues&APIkey=' + config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            self.leagues_db = df
            self.write_db_to_disk(config.path_leagues_db, df)
            self.update_last_refresh_times(0)
            return True
        except Exception as e:
            logging.error('error in update_leagues_db_from_fetch {}'.format(e))
            return False

    def update_events_from_fetch(self, date_from, date_to):
        """
        retrieves events from fetch by date and updates the events_db by match_id
        """
        date_from = self.date_to_string(date_from)
        date_to = self.date_to_string(date_to)
        path = config.apifootball_host + '/?action=get_events&from=' + date_from + '&to=' + date_to + '&APIkey=' + config.apifootball_key
        try:
            logging.info('fetch for {}'.format(path))
            response = requests.get(path)
            df = pd.DataFrame(response.json()).set_index('match_id', drop=False)
            df = df.astype({'country_id': 'int32',
                            'league_id':'int32'})
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]

            if self.events_db.empty:
                logging.info('events_db is empty so setting from fetch')
                self.events_db = df
            else:
                logging.info('events_db updating {} with new table {}'.format(len(self.events_db), len(df)))
                self.events_db.update(df, join='left', overwrite=True)
            self.write_db_to_disk(config.path_events_db, df)
            self.update_last_refresh_times(1)
            return True
        except Exception as e:
            logging.error('error in update_events_from_fetch {}'.format(e))
            return False

    def update_league_db_standings_from_fetch(self, league_id):
        """
        using an api call to set up the league_db_standings
        """
        logging.info('setting up league_db_standings from fetch for id {}'.format(league_id))
        path = config.apifootball_host + '/?action=get_standings&league_id=' + str(
            league_id) + '&APIkey=' + config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            self.league_db_standings[league_id] = df
            logging.info('changed league_db_standings from the fetch for {}'.format(league_id))
            self.write_db_to_disk(config.path_league_standings_stem + str(league_id), df)
            self.update_last_refresh_times(league_id)
            return True
        except Exception as e:
            logging.error('error in update_league_db_standings_from_fetch {}'.format(e))
            return False

    #----------- fetches----------------------------------------------------------------------------------------

    def get_events(self, league_id=None, date_from=None, date_to=None, match_id=None):
        df = self.events_db.copy()
        trues = np.array([True]*len(df))

        match_id_filter = df.index == int(match_id) if match_id else trues
        league_id_filter = df['league_id'] == int(league_id) if league_id else trues
        date_from_filter = df['match_date'] > date_from.replace(hour=0, minute=0, second=0) if date_from else trues
        date_to_filter = df['match_date'] < date_to.replace(hour=23, minute=59, second=0) if date_to else trues

        # format the dataframe correctly 
        df = df.replace(np.nan, '', regex=True)
        df = df.loc[match_id_filter & league_id_filter & date_from_filter & date_to_filter]
        df['match_date'] = [d.timestamp() for d in df['match_date']]
        df['lineup'] = [ast.literal_eval(d) for d in df['lineup']]
        df['cards'] = [ast.literal_eval(d) for d in df['cards']]
        df['goalscorer'] = [ast.literal_eval(d) for d in df['goalscorer']]
        df['statistics'] = [ast.literal_eval(d) for d in df['statistics']]

        return df.to_dict('index')


    def refresh_events(self):
        if not self.is_data_fresh(1):
            logging.info('in refresh_events data not fresh')
            date_from = datetime.now() - timedelta(days=14)
            date_to = datetime.now() + timedelta(days=14)
            self.update_events_from_fetch(date_from, date_to)
            logging.info('refreshed events')
        else:
            logging.info('in refresh_events data is fresh')

    def update_last_refresh_times(self, id):
        self.last_refresh_times[id] = datetime.now()

    def is_data_fresh(self, id):
        if not id in self.last_refresh_times:
            return False
        time_since_update_mins = (datetime.now() - self.last_refresh_times[id]).seconds / 60
        if time_since_update_mins > config.refresh_time_mins:
            return False
        return True

    def date_to_string(self, date):
        yyyy = str(date.year)
        mm = str(date.month)
        dd = str(date.day)
        if len(mm) == 1:
            mm = '0' + mm
        if len(dd) == 1:
            dd = '0' + dd
        return yyyy + '-' + mm + '-' + dd

    def df_to_strings(self, df):
        for col in df.columns:
            df[col] = df[col].astype(str)
        return df

    def get_league_db(self):
        if not self.is_data_fresh(0):
            logging.info('in get_league_db data not fresh')
            self.update_leagues_db_from_fetch()
        else:
            logging.info('in get_league_db data is fresh')
        return self.leagues_db

    def get_league_db_standings(self, league_id):
        if not self.is_data_fresh(league_id):
            logging.info('in get_league_db_standings data not fresh')
            self.update_league_db_standings_from_fetch(league_id)
        else:
            logging.info('in get_league_db_standings data is fresh')
        logging.info('keys of league_db_standings are {} and league id {} is in ? {}'.format(self.league_db_standings.keys(), league_id, league_id in self.league_db_standings.keys()))
        if league_id in self.league_db_standings.keys():
            return self.league_db_standings[league_id]
        return pd.DataFrame()

    def get_leagues(self):
        """
        returns the league and country info in a dictionary form
        """
        logging.info('inside get_leagues')
        df = self.df_to_strings(self.get_league_db())
        leagues_dict = {}
        cids = list(set(df['country_id']))
        df = df.set_index('country_id')
        for cid in cids:
            if sum(df.index == cid) > 1:
                league_names = list(df.loc[cid]['league_name'])
                league_ids = list(df.loc[cid]['league_id'])
                country_name = list(df.loc[cid]['country_name'])[0]
            else:
                league_names = [df.loc[cid]['league_name']]
                league_ids = [df.loc[cid]['league_id']]
                country_name = df.loc[cid]['country_name']
            leagues_dict[cid] = {
                'country_name': country_name,
                'leagues': {
                    'league_ids': league_ids,
                    'country_name': country_name,
                    'league_names': league_names
                }
            }
        return leagues_dict


#@app.route('/')
def check_server():
    return "connected to middle layer server"


#@app.route('/get_leagues_db/', methods=['GET'])
def get_league_standings():
    logging.info("get_league_standings")
    df = db_con.get_league_db()
    return jsonify(df.to_dict('index'))


#@app.route('/get_sidebar_info/', methods=['GET'])
def get_sidebar_info():
    logging.info("get_sidebar_info")
    logging.info('db_con.get_leagues() {}'.format(db_con.get_leagues()))
    return jsonify(db_con.get_leagues())


#@app.route('/get_league_standings_db/<league_id>', methods=['GET'])
def get_league_standings_db(league_id):
    league_id=int(league_id)
    logging.info("get_league_standings_db for {}".format(league_id))

    df = db_con.get_league_db_standings(league_id)
    if df.empty:
        return jsonify('league_id not recognised')
    return jsonify(df.to_dict('index'))


#@app.route('/get_fixtures/<league_id>', methods=['GET'])
def get_fixtures(league_id):
    date_from = datetime.now()
    date_to = datetime.now() + timedelta(days=14)
    return jsonify(db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_results/<league_id>', methods=['GET'])
def get_results(league_id):
    date_from = datetime.now() - timedelta(days=14)
    date_to = datetime.now()
    return db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to)
    return jsonify(db_con.get_events(league_id=league_id, date_from=date_from, date_to=date_to))


#@app.route('/get_match/<match_id>', methods=['GET'])
def get_match(match_id):
    match_info = db_con.get_events(match_id=match_id)[int(match_id)]
    #match_info['lineup'] = ast.literal_eval(match_info['lineup'])
    #match_info['cards'] = ast.literal_eval(match_info['cards'])
    #match_info['goalscorer'] = ast.literal_eval(match_info['goalscorer'])
    #match_info['statistics'] = ast.literal_eval(match_info['statistics'])
    return match_info
    return jsonify(match_info)

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

global db_con
db_con = DatabaseConnection()  # or whatever you need to do
# Out:
# INFO:root:getting league_db from disk
# INFO:root:set up leagues_db from disk
# INFO:root:getting league_db from disk
# INFO:root:setting up league_db for id 63 from disk
# INFO:root:set up league_db for id 63 from disk
# INFO:root:setting up league_db for id 128 from disk
# INFO:root:set up league_db for id 128 from disk
# INFO:root:in refresh_events data not fresh
# INFO:root:fetch for https://apifootball.com/api/?action=get_events&from=2019-09-29&to=2019-10-27&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_events&from=2019-09-29&to=2019-10-27&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:events_db updating 89 with new table 89
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/events_db.csv
# INFO:root:refreshed events
# INFO:root:updating  leagues_db from fetch
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_leagues&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 180
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/leagues_db.csv
# INFO:root:setting up league_db_standings from fetch for id 63
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=63&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 63
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_63
# INFO:root:setting up league_db_standings from fetch for id 128
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=128&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 128
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_128

# %%
get_match(448197)
# Out:
# {'match_id': 448197,
#  'cards': [],
#  'country_id': 169,
#  'country_name': 'England',
#  'goalscorer': [{'time': "1'",
#    'home_scorer': 'C.  Cauley Woodrow',
#    'score': '1 - 0',
#    'away_scorer': ''},
#   {'time': "35'",
#    'home_scorer': '',
#    'score': '1 - 1',
#    'away_scorer': 'O.  Ollie Watkins'},
#   {'time': "46'",
#    'home_scorer': '',
#    'score': '1 - 2',
#    'away_scorer': 'O.  Ollie Watkins'},
#   {'time': "68'",
#    'home_scorer': '',
#    'score': '1 - 3',
#    'away_scorer': 'O.  Ollie Watkins'}],
#  'league_id': 63,
#  'league_name': 'Championship',
#  'lineup': {'home': {'starting_lineups': [{'lineup_player': 'Bradley Collins',
#      'lineup_number': '40',
#      'lineup_position': '1'},
#     {'lineup_player': 'Toby Sibbick',
#      'lineup_number': '21',
#      'lineup_position': '2'},
#     {'lineup_player': 'Aapo Halme',
#      'lineup_number': '24',
#      'lineup_position': '3'},
#     {'lineup_player': 'Mads Juel Andersen',
#      'lineup_number': '6',
#      'lineup_position': '4'},
#     {'lineup_player': 'Jordan Williams',
#      'lineup_number': '2',
#      'lineup_position': '5'},
#     {'lineup_player': 'Dimitri Cavare',
#      'lineup_number': '12',
#      'lineup_position': '6'},
#     {'lineup_player': 'Alex Mowatt',
#      'lineup_number': '27',
#      'lineup_position': '7'},
#     {'lineup_player': 'Jacob Brown',
#      'lineup_number': '7',
#      'lineup_position': '8'},
#     {'lineup_player': 'Conor Chaplin',
#      'lineup_number': '11',
#      'lineup_position': '9'},
#     {'lineup_player': 'Luke Thomas',
#      'lineup_number': '16',
#      'lineup_position': '10'},
#     {'lineup_player': 'Cauley Woodrow',
#      'lineup_number': '9',
#      'lineup_position': '11'}],
#    'substitutes': [{'lineup_player': 'Conor Chaplin | Patrick Schmidt',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Luke Thomas | Mallik Wilks',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Dimitri Cavare | Mamadou Khady Thiam',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Jack Walton',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Jordan Green',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Patrick Schmidt',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Callum Styles',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Daniel Pinillos',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Mamadou Khady Thiam',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Mallik Wilks',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Daniel Stendel',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'substitutions': []},
#   'away': {'starting_lineups': [{'lineup_player': 'Said Benrahma',
#      'lineup_number': '10',
#      'lineup_position': '11'},
#     {'lineup_player': 'Ollie Watkins',
#      'lineup_number': '11',
#      'lineup_position': '10'},
#     {'lineup_player': 'Sergi Canos',
#      'lineup_number': '7',
#      'lineup_position': '9'},
#     {'lineup_player': 'Mathias Jensen',
#      'lineup_number': '8',
#      'lineup_position': '8'},
#     {'lineup_player': 'Christian Noergaard',
#      'lineup_number': '6',
#      'lineup_position': '7'},
#     {'lineup_player': 'Kamohelo Mokotjo',
#      'lineup_number': '12',
#      'lineup_position': '6'},
#     {'lineup_player': 'Rico Henry',
#      'lineup_number': '3',
#      'lineup_position': '5'},
#     {'lineup_player': 'Julian Jeanvier',
#      'lineup_number': '23',
#      'lineup_position': '4'},
#     {'lineup_player': 'Pontus Jansson',
#      'lineup_number': '18',
#      'lineup_position': '3'},
#     {'lineup_player': 'Henrik Dalsgaard',
#      'lineup_number': '22',
#      'lineup_position': '2'},
#     {'lineup_player': 'David Raya',
#      'lineup_number': '1',
#      'lineup_position': '1'}],
#    'substitutes': [{'lineup_player': 'Sergi Canos | Ethan Pinnock',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Mathias Jensen | Joshua Dasilva',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Ollie Watkins | Nikos Karelis',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Ethan Pinnock',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Nikos Karelis',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Joshua Dasilva',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Bryan Mbeumo',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Josh Clarke',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Luke Daniels',
#      'lineup_number': '',
#      'lineup_position': ''},
#     {'lineup_player': 'Jan Zamburek',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'coach': [{'lineup_player': 'Thomas Frank',
#      'lineup_number': '',
#      'lineup_position': ''}],
#    'substitutions': []}},
#  'match_awayteam_extra_score': '',
#  'match_awayteam_halftime_score': 1.0,
#  'match_awayteam_name': 'Brentford',
#  'match_awayteam_penalty_score': '',
#  'match_awayteam_score': 3.0,
#  'match_awayteam_system': '4-3-3',
#  'match_date': 1569715200.0,
#  'match_hometeam_extra_score': '',
#  'match_hometeam_halftime_score': 1.0,
#  'match_hometeam_name': 'Barnsley',
#  'match_hometeam_penalty_score': '',
#  'match_hometeam_score': 1.0,
#  'match_hometeam_system': '4-2-3-1',
#  'match_id.1': 448197,
#  'match_live': 0,
#  'match_status': 'FT',
#  'match_time': '14:30',
#  'statistics': [{'type': 'shots on target', 'home': '3', 'away': '5'},
#   {'type': 'shots off target', 'home': '7', 'away': '8'},
#   {'type': 'possession (%)', 'home': '48', 'away': '52'},
#   {'type': 'corners', 'home': '8', 'away': '3'},
#   {'type': 'offsides', 'home': '6', 'away': '6'},
#   {'type': 'fouls', 'home': '11', 'away': '8'}]}

# %%
db_con.events_db
# Out:
#           match_id                                              cards  \
# match_id
# 448197      448197                                                 []
# 448387      448387  [{'time': "10'", 'away_fault': '', 'home_fault...
# 448469      448469  [{'time': "22'", 'away_fault': '', 'home_fault...
# 448470      448470  [{'time': "43'", 'away_fault': 'S.  Sam Hutchi...
# 448471      448471  [{'time': "18'", 'away_fault': '', 'home_fault...
# 448472      448472  [{'time': "65'", 'away_fault': 'B.  Ben Pearso...
# 448473      448473                                                 []
# 448474      448474  [{'time': "5'", 'away_fault': '', 'home_fault'...
# 448475      448475  [{'time': "65'", 'away_fault': 'D.  Danny Simp...
# 448974      448974  [{'time': "74'", 'away_fault': '', 'home_fault...
# 448975      448975  [{'time': "81'", 'away_fault': 'J.  Jack Hunt'...
# 448976      448976  [{'time': "84'", 'away_fault': 'R.  Ryan Manni...
# 448977      448977  [{'time': "50'", 'away_fault': '', 'home_fault...
# 448978      448978  [{'time': "75'", 'away_fault': 'J.  Jayson Mol...
# 450684      450684  [{'time': "54'", 'away_fault': 'P.  Patrick Mc...
# 450694      450694  [{'time': "14'", 'away_fault': '', 'home_fault...
# 450695      450695  [{'time': "34'", 'away_fault': 'D.  David Doul...
# 450696      450696  [{'time': "36'", 'away_fault': '', 'home_fault...
# 450697      450697  [{'time': "16'", 'away_fault': '', 'home_fault...
# 450698      450698  [{'time': "30'", 'away_fault': 'T.  Thibault J...
# 450699      450699  [{'time': "43'", 'away_fault': 'I.  Ihsan Sack...
# 450700      450700  [{'time': "46'", 'away_fault': '', 'home_fault...
# 450701      450701  [{'time': "29'", 'away_fault': '', 'home_fault...
# 450837      450837  [{'time': "8'", 'away_fault': '', 'home_fault'...
# 450838      450838  [{'time': "18'", 'away_fault': '', 'home_fault...
# 450839      450839  [{'time': "76'", 'away_fault': '', 'home_fault...
# 450840      450840  [{'time': "32'", 'away_fault': '', 'home_fault...
# 450841      450841  [{'time': "14'", 'away_fault': 'G.  Gaetano Be...
# 450842      450842  [{'time': "35'", 'away_fault': 'S.  Sergi Cano...
# 450843      450843  [{'time': "27'", 'away_fault': 'C.  Cameron Mc...
# ...            ...                                                ...
# 457470      457470                                                 []
# 457471      457471                                                 []
# 457472      457472                                                 []
# 457473      457473                                                 []
# 457474      457474                                                 []
# 457475      457475                                                 []
# 457708      457708                                                 []
# 457709      457709                                                 []
# 457710      457710                                                 []
# 457711      457711                                                 []
# 457712      457712                                                 []
# 458302      458302                                                 []
# 458303      458303                                                 []
# 458304      458304                                                 []
# 458305      458305                                                 []
# 458306      458306                                                 []
# 458307      458307                                                 []
# 458308      458308                                                 []
# 458309      458309                                                 []
# 459243      459243                                                 []
# 459244      459244                                                 []
# 459245      459245                                                 []
# 459246      459246                                                 []
# 459247      459247                                                 []
# 459248      459248                                                 []
# 459249      459249                                                 []
# 459250      459250                                                 []
# 459251      459251                                                 []
# 459492      459492                                                 []
# 459493      459493                                                 []
#
#           country_id country_name  \
# match_id
# 448197           169      England
# 448387           173       France
# 448469           169      England
# 448470           169      England
# 448471           169      England
# 448472           169      England
# 448473           169      England
# 448474           169      England
# 448475           169      England
# 448974           169      England
# 448975           169      England
# 448976           169      England
# 448977           169      England
# 448978           169      England
# 450684           169      England
# 450694           173       France
# 450695           173       France
# 450696           173       France
# 450697           173       France
# 450698           173       France
# 450699           173       France
# 450700           173       France
# 450701           173       France
# 450837           169      England
# 450838           169      England
# 450839           169      England
# 450840           169      England
# 450841           169      England
# 450842           169      England
# 450843           169      England
# ...              ...          ...
# 457470           169      England
# 457471           169      England
# 457472           169      England
# 457473           169      England
# 457474           169      England
# 457475           169      England
# 457708           169      England
# 457709           169      England
# 457710           169      England
# 457711           169      England
# 457712           169      England
# 458302           173       France
# 458303           173       France
# 458304           173       France
# 458305           173       France
# 458306           173       France
# 458307           173       France
# 458308           173       France
# 458309           173       France
# 459243           169      England
# 459244           169      England
# 459245           169      England
# 459246           169      England
# 459247           169      England
# 459248           169      England
# 459249           169      England
# 459250           169      England
# 459251           169      England
# 459492           169      England
# 459493           169      England
#
#                                                  goalscorer  league_id  \
# match_id
# 448197    [{'time': "1'", 'home_scorer': 'C.  Cauley Woo...         63
# 448387    [{'time': "45'", 'home_scorer': 'F.  Frantzdy ...        128
# 448469    [{'time': "63'", 'home_scorer': 'A.  Adam Arms...         63
# 448470    [{'time': "72'", 'home_scorer': 'T.  Tom Eaves...         63
# 448471    [{'time': "38'", 'home_scorer': 'E.  Ezgjan Al...         63
# 448472    [{'time': "40'", 'home_scorer': '', 'score': '...         63
# 448473    [{'time': "76'", 'home_scorer': 'A.  Anthony P...         63
# 448474    [{'time': "13'", 'home_scorer': '', 'score': '...         63
# 448475    [{'time': "82'", 'home_scorer': '', 'score': '...         63
# 448974    [{'time': "13'", 'home_scorer': 'A.  Aapo Halm...         63
# 448975    [{'time': "64'", 'home_scorer': 'J.  Joshua Da...         63
# 448976    [{'time': "11'", 'home_scorer': 'S.  Sean Morr...         63
# 448977    [{'time': "2'", 'home_scorer': 'J.  Jonathan L...         63
# 448978    [{'time': "60'", 'home_scorer': '', 'score': '...         63
# 450684    [{'time': "33'", 'home_scorer': 'F.  Fran Vill...         63
# 450694    [{'time': "41'", 'home_scorer': '', 'score': '...        128
# 450695    [{'time': "12'", 'home_scorer': 'B.  Bryan Pel...        128
# 450696                                                   []        128
# 450697    [{'time': "6'", 'home_scorer': 'A.  Abdoulaye ...        128
# 450698    [{'time': "80'", 'home_scorer': 'V.  Vincent C...        128
# 450699    [{'time': "5'", 'home_scorer': 'Y.  Yoann Touz...        128
# 450700    [{'time': "60'", 'home_scorer': 'P.  Prince On...        128
# 450701    [{'time': "39'", 'home_scorer': '', 'score': '...        128
# 450837    [{'time': "41'", 'home_scorer': '', 'score': '...         63
# 450838    [{'time': "12'", 'home_scorer': 'F.  Famara Di...         63
# 450839    [{'time': "11'", 'home_scorer': 'M.  Matthew P...         63
# 450840    [{'time': "68'", 'home_scorer': 'K.  Karlan Gr...         63
# 450841    [{'time': "16'", 'home_scorer': 'J.  Jed Walla...         63
# 450842    [{'time': "56'", 'home_scorer': 'B.  Ben Watso...         63
# 450843    [{'time': "31'", 'home_scorer': 'D.  Daniel Jo...         63
# ...                                                     ...        ...
# 457470                                                   []         63
# 457471                                                   []         63
# 457472                                                   []         63
# 457473                                                   []         63
# 457474                                                   []         63
# 457475                                                   []         63
# 457708                                                   []         63
# 457709                                                   []         63
# 457710                                                   []         63
# 457711                                                   []         63
# 457712                                                   []         63
# 458302                                                   []        128
# 458303                                                   []        128
# 458304                                                   []        128
# 458305                                                   []        128
# 458306                                                   []        128
# 458307                                                   []        128
# 458308                                                   []        128
# 458309                                                   []        128
# 459243                                                   []         63
# 459244                                                   []         63
# 459245                                                   []         63
# 459246                                                   []         63
# 459247                                                   []         63
# 459248                                                   []         63
# 459249                                                   []         63
# 459250                                                   []         63
# 459251                                                   []         63
# 459492                                                   []         63
# 459493                                                   []         63
#
#            league_name                                             lineup  \
# match_id
# 448197    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448387         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 448469    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448470    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448471    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448472    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448473    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448474    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448475    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448974    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448975    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448976    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448977    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 448978    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450684    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450694         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450695         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450696         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450697         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450698         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450699         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450700         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450701         Ligue 2  {'away': {'substitutes': [{'lineup_position': ...
# 450837    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450838    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450839    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 450840    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450841    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450842    Championship  {'away': {'substitutes': [{'lineup_position': ...
# 450843    Championship  {'away': {'substitutes': [{'lineup_position': ...
# ...                ...                                                ...
# 457470    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457471    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457472    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457473    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457474    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457475    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457708    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457709    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457710    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457711    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 457712    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 458302         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458303         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458304         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458305         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458306         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458307         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458308         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 458309         Ligue 2  {'away': {'substitutes': [], 'substitutions': ...
# 459243    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459244    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459245    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459246    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459247    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459248    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459249    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459250    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459251    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459492    Championship  {'away': {'substitutes': [], 'substitutions': ...
# 459493    Championship  {'away': {'substitutes': [], 'substitutions': ...
#
#           match_awayteam_extra_score  match_awayteam_halftime_score  ...  \
# match_id                                                             ...
# 448197                           NaN                            1.0  ...
# 448387                           NaN                            0.0  ...
# 448469                           NaN                            0.0  ...
# 448470                           NaN                            0.0  ...
# 448471                           NaN                            0.0  ...
# 448472                           NaN                            1.0  ...
# 448473                           NaN                            0.0  ...
# 448474                           NaN                            3.0  ...
# 448475                           NaN                            0.0  ...
# 448974                           NaN                            2.0  ...
# 448975                           NaN                            0.0  ...
# 448976                           NaN                            0.0  ...
# 448977                           NaN                            1.0  ...
# 448978                           NaN                            0.0  ...
# 450684                           NaN                            0.0  ...
# 450694                           NaN                            1.0  ...
# 450695                           NaN                            1.0  ...
# 450696                           NaN                            0.0  ...
# 450697                           NaN                            0.0  ...
# 450698                           NaN                            0.0  ...
# 450699                           NaN                            0.0  ...
# 450700                           NaN                            0.0  ...
# 450701                           NaN                            1.0  ...
# 450837                           NaN                            1.0  ...
# 450838                           NaN                            0.0  ...
# 450839                           NaN                            0.0  ...
# 450840                           NaN                            0.0  ...
# 450841                           NaN                            0.0  ...
# 450842                           NaN                            0.0  ...
# 450843                           NaN                            1.0  ...
# ...                              ...                            ...  ...
# 457470                           NaN                            NaN  ...
# 457471                           NaN                            NaN  ...
# 457472                           NaN                            NaN  ...
# 457473                           NaN                            NaN  ...
# 457474                           NaN                            NaN  ...
# 457475                           NaN                            NaN  ...
# 457708                           NaN                            NaN  ...
# 457709                           NaN                            NaN  ...
# 457710                           NaN                            NaN  ...
# 457711                           NaN                            NaN  ...
# 457712                           NaN                            NaN  ...
# 458302                           NaN                            NaN  ...
# 458303                           NaN                            NaN  ...
# 458304                           NaN                            NaN  ...
# 458305                           NaN                            NaN  ...
# 458306                           NaN                            NaN  ...
# 458307                           NaN                            NaN  ...
# 458308                           NaN                            NaN  ...
# 458309                           NaN                            NaN  ...
# 459243                           NaN                            NaN  ...
# 459244                           NaN                            NaN  ...
# 459245                           NaN                            NaN  ...
# 459246                           NaN                            NaN  ...
# 459247                           NaN                            NaN  ...
# 459248                           NaN                            NaN  ...
# 459249                           NaN                            NaN  ...
# 459250                           NaN                            NaN  ...
# 459251                           NaN                            NaN  ...
# 459492                           NaN                            NaN  ...
# 459493                           NaN                            NaN  ...
#
#          match_hometeam_halftime_score   match_hometeam_name  \
# match_id
# 448197                             1.0              Barnsley
# 448387                             1.0              Guingamp
# 448469                             0.0      Blackburn Rovers
# 448470                             0.0             Hull City
# 448471                             1.0          Leeds United
# 448472                             1.0         Middlesbrough
# 448473                             0.0        Wigan Athletic
# 448474                             0.0               Reading
# 448475                             0.0            Stoke City
# 448974                             1.0              Barnsley
# 448975                             0.0             Brentford
# 448976                             2.0          Cardiff City
# 448977                             1.0     Charlton Athletic
# 448978                             0.0            Luton Town
# 450684                             1.0       Birmingham City
# 450694                             0.0                 Nancy
# 450695                             2.0              Guingamp
# 450696                             0.0               Lorient
# 450697                             1.0               Sochaux
# 450698                             0.0               Le Mans
# 450699                             1.0              Paris FC
# 450700                             0.0                  Caen
# 450701                             0.0          Valenciennes
# 450837                             0.0                Fulham
# 450838                             1.0          Bristol City
# 450839                             1.0          Derby County
# 450840                             0.0     Huddersfield Town
# 450841                             2.0              Millwall
# 450842                             0.0     Nottingham Forest
# 450843                             1.0     Preston North End
# ...                                ...                   ...
# 457470                             NaN              Millwall
# 457471                             NaN     Preston North End
# 457472                             NaN   Queens Park Rangers
# 457473                             NaN   Sheffield Wednesday
# 457474                             NaN          Swansea City
# 457475                             NaN  West Bromwich Albion
# 457708                             NaN          Bristol City
# 457709                             NaN          Derby County
# 457710                             NaN                Fulham
# 457711                             NaN     Huddersfield Town
# 457712                             NaN     Nottingham Forest
# 458302                             NaN               Auxerre
# 458303                             NaN                 Nancy
# 458304                             NaN              Guingamp
# 458305                             NaN               Sochaux
# 458306                             NaN               Le Mans
# 458307                             NaN              Paris FC
# 458308                             NaN                 Rodez
# 458309                             NaN               Orleans
# 459243                             NaN   Sheffield Wednesday
# 459244                             NaN       Birmingham City
# 459245                             NaN     Huddersfield Town
# 459246                             NaN             Hull City
# 459247                             NaN         Middlesbrough
# 459248                             NaN              Millwall
# 459249                             NaN     Nottingham Forest
# 459250                             NaN     Preston North End
# 459251                             NaN  West Bromwich Albion
# 459492                             NaN          Swansea City
# 459493                             NaN          Bristol City
#
#           match_hometeam_penalty_score match_hometeam_score  \
# match_id
# 448197                             NaN                  1.0
# 448387                             NaN                  3.0
# 448469                             NaN                  1.0
# 448470                             NaN                  1.0
# 448471                             NaN                  1.0
# 448472                             NaN                  1.0
# 448473                             NaN                  1.0
# 448474                             NaN                  1.0
# 448475                             NaN                  0.0
# 448974                             NaN                  2.0
# 448975                             NaN                  1.0
# 448976                             NaN                  3.0
# 448977                             NaN                  1.0
# 448978                             NaN                  1.0
# 450684                             NaN                  2.0
# 450694                             NaN                  2.0
# 450695                             NaN                  4.0
# 450696                             NaN                  0.0
# 450697                             NaN                  4.0
# 450698                             NaN                  1.0
# 450699                             NaN                  1.0
# 450700                             NaN                  1.0
# 450701                             NaN                  0.0
# 450837                             NaN                  2.0
# 450838                             NaN                  1.0
# 450839                             NaN                  2.0
# 450840                             NaN                  3.0
# 450841                             NaN                  2.0
# 450842                             NaN                  1.0
# 450843                             NaN                  5.0
# ...                                ...                  ...
# 457470                             NaN                  NaN
# 457471                             NaN                  NaN
# 457472                             NaN                  NaN
# 457473                             NaN                  NaN
# 457474                             NaN                  NaN
# 457475                             NaN                  NaN
# 457708                             NaN                  NaN
# 457709                             NaN                  NaN
# 457710                             NaN                  NaN
# 457711                             NaN                  NaN
# 457712                             NaN                  NaN
# 458302                             NaN                  NaN
# 458303                             NaN                  NaN
# 458304                             NaN                  NaN
# 458305                             NaN                  NaN
# 458306                             NaN                  NaN
# 458307                             NaN                  NaN
# 458308                             NaN                  NaN
# 458309                             NaN                  NaN
# 459243                             NaN                  NaN
# 459244                             NaN                  NaN
# 459245                             NaN                  NaN
# 459246                             NaN                  NaN
# 459247                             NaN                  NaN
# 459248                             NaN                  NaN
# 459249                             NaN                  NaN
# 459250                             NaN                  NaN
# 459251                             NaN                  NaN
# 459492                             NaN                  NaN
# 459493                             NaN                  NaN
#
#          match_hometeam_system  match_id.1  match_live match_status  \
# match_id
# 448197                 4-2-3-1      448197           0           FT
# 448387                 4-2-3-1      448387           0           FT
# 448469                   4-4-2      448469           0           FT
# 448470                 4-1-4-1      448470           0           FT
# 448471                 4-1-4-1      448471           0           FT
# 448472                   4-3-3      448472           0           FT
# 448473                 4-2-3-1      448473           0           FT
# 448474                   4-3-3      448474           0           FT
# 448475               4-1-2-1-2      448475           0           FT
# 448974                 4-2-3-1      448974           0           FT
# 448975                   4-3-3      448975           0           FT
# 448976                 4-2-3-1      448976           0           FT
# 448977                 4-2-3-1      448977           0           FT
# 448978                 4-3-1-2      448978           0           FT
# 450684                   4-4-2      450684           0           FT
# 450694                   4-4-2      450694           0           FT
# 450695                   4-4-2      450695           0           FT
# 450696                 4-2-3-1      450696           0           FT
# 450697                 4-1-4-1      450697           0           FT
# 450698                   4-4-2      450698           0           FT
# 450699                 4-2-3-1      450699           0           FT
# 450700                 4-2-3-1      450700           0           FT
# 450701                 4-2-3-1      450701           0           FT
# 450837                   4-3-3      450837           0           FT
# 450838                   4-4-2      450838           0           FT
# 450839                 4-2-3-1      450839           0           FT
# 450840                 4-2-3-1      450840           0           FT
# 450841                 4-4-1-1      450841           0           FT
# 450842                 4-2-3-1      450842           0           FT
# 450843                 4-2-3-1      450843           0           FT
# ...                        ...         ...         ...          ...
# 457470                     NaN      457470           0          NaN
# 457471                     NaN      457471           0          NaN
# 457472                     NaN      457472           0          NaN
# 457473                     NaN      457473           0          NaN
# 457474                     NaN      457474           0          NaN
# 457475                     NaN      457475           0          NaN
# 457708                     NaN      457708           0          NaN
# 457709                     NaN      457709           0          NaN
# 457710                     NaN      457710           0          NaN
# 457711                     NaN      457711           0          NaN
# 457712                     NaN      457712           0          NaN
# 458302                     NaN      458302           0          NaN
# 458303                     NaN      458303           0          NaN
# 458304                     NaN      458304           0          NaN
# 458305                     NaN      458305           0          NaN
# 458306                     NaN      458306           0          NaN
# 458307                     NaN      458307           0          NaN
# 458308                     NaN      458308           0          NaN
# 458309                     NaN      458309           0          NaN
# 459243                     NaN      459243           0          NaN
# 459244                     NaN      459244           0          NaN
# 459245                     NaN      459245           0          NaN
# 459246                     NaN      459246           0          NaN
# 459247                     NaN      459247           0          NaN
# 459248                     NaN      459248           0          NaN
# 459249                     NaN      459249           0          NaN
# 459250                     NaN      459250           0          NaN
# 459251                     NaN      459251           0          NaN
# 459492                     NaN      459492           0          NaN
# 459493                     NaN      459493           0          NaN
#
#           match_time                                         statistics
# match_id
# 448197         14:30  [{'away': '5', 'type': 'shots on target', 'hom...
# 448387         20:45  [{'away': '2', 'type': 'shots on target', 'hom...
# 448469         20:45  [{'away': '4', 'type': 'shots on target', 'hom...
# 448470         20:45  [{'away': '3', 'type': 'shots on target', 'hom...
# 448471         18:45  [{'away': '4', 'type': 'shots on target', 'hom...
# 448472         18:45  [{'away': '1', 'type': 'shots on target', 'hom...
# 448473         18:45  [{'away': '0', 'type': 'shots on target', 'hom...
# 448474         19:00  [{'away': '7', 'type': 'shots on target', 'hom...
# 448475         21:00  [{'away': '1', 'type': 'shots on target', 'hom...
# 448974         20:45  [{'away': '6', 'type': 'shots on target', 'hom...
# 448975         18:45  [{'away': '3', 'type': 'shots on target', 'hom...
# 448976         18:45  [{'away': '4', 'type': 'shots on target', 'hom...
# 448977         20:45  [{'away': '4', 'type': 'shots on target', 'hom...
# 448978         20:45  [{'away': '4', 'type': 'shots on target', 'hom...
# 450684         20:45  [{'away': '3', 'type': 'shots on target', 'hom...
# 450694         18:00  [{'away': '1', 'type': 'shots on target', 'hom...
# 450695         20:00  [{'away': '2', 'type': 'shots on target', 'hom...
# 450696         18:00  [{'away': '4', 'type': 'shots on target', 'hom...
# 450697         18:00  [{'away': '4', 'type': 'shots on target', 'hom...
# 450698         20:00  [{'away': '1', 'type': 'shots on target', 'hom...
# 450699         18:00  [{'away': '2', 'type': 'shots on target', 'hom...
# 450700         18:00  [{'away': '5', 'type': 'shots on target', 'hom...
# 450701         18:00  [{'away': '5', 'type': 'shots on target', 'hom...
# 450837         11:30  [{'away': '5', 'type': 'shots on target', 'hom...
# 450838         14:00  [{'away': '3', 'type': 'shots on target', 'hom...
# 450839         14:00  [{'away': '1', 'type': 'shots on target', 'hom...
# 450840         14:00  [{'away': '4', 'type': 'shots on target', 'hom...
# 450841         14:00  [{'away': '1', 'type': 'shots on target', 'hom...
# 450842         14:00  [{'away': '3', 'type': 'shots on target', 'hom...
# 450843         14:00  [{'away': '1', 'type': 'shots on target', 'hom...
# ...              ...                                                ...
# 457470         18:45                                                 []
# 457471         18:45                                                 []
# 457472         18:45                                                 []
# 457473         18:45                                                 []
# 457474         18:45                                                 []
# 457475         19:00                                                 []
# 457708         18:45                                                 []
# 457709         18:45                                                 []
# 457710         18:45                                                 []
# 457711         18:45                                                 []
# 457712         18:45                                                 []
# 458302         18:00                                                 []
# 458303         18:00                                                 []
# 458304         18:00                                                 []
# 458305         18:00                                                 []
# 458306         18:00                                                 []
# 458307         18:00                                                 []
# 458308         18:00                                                 []
# 458309         18:00                                                 []
# 459243         11:30                                                 []
# 459244         14:00                                                 []
# 459245         14:00                                                 []
# 459246         14:00                                                 []
# 459247         14:00                                                 []
# 459248         14:00                                                 []
# 459249         14:00                                                 []
# 459250         14:00                                                 []
# 459251         14:00                                                 []
# 459492         12:00                                                 []
# 459493         13:30                                                 []
#
# [89 rows x 26 columns]
