# %%
df = db_con.events_db
df
# Out:
#          cards  country_id country_name goalscorer  league_id   league_name  \
# match_id
# 432785      []         169      England         []         63  Championship
# 432798      []         173       France         []        128       Ligue 2
# 432799      []         173       France         []        128       Ligue 2
# 432800      []         173       France         []        128       Ligue 2
# 432801      []         173       France         []        128       Ligue 2
# 432802      []         173       France         []        128       Ligue 2
# 432803      []         173       France         []        128       Ligue 2
# 432804      []         173       France         []        128       Ligue 2
# 432805      []         173       France         []        128       Ligue 2
# 433015      []         169      England         []         63  Championship
# 433016      []         169      England         []         63  Championship
# 433017      []         169      England         []         63  Championship
# 433018      []         169      England         []         63  Championship
# 433019      []         169      England         []         63  Championship
# 433020      []         169      England         []         63  Championship
# 433021      []         169      England         []         63  Championship
# 433022      []         169      England         []         63  Championship
# 433023      []         169      England         []         63  Championship
# 433024      []         169      England         []         63  Championship
# 433126      []         173       France         []        128       Ligue 2
# 433194      []         169      England         []         63  Championship
# 433476      []         173       France         []        128       Ligue 2
# 433607      []         169      England         []         63  Championship
# 433608      []         169      England         []         63  Championship
# 433609      []         169      England         []         63  Championship
# 433610      []         169      England         []         63  Championship
# 433611      []         169      England         []         63  Championship
# 433785      []         169      England         []         63  Championship
# 433786      []         169      England         []         63  Championship
# 433787      []         169      England         []         63  Championship
# 433788      []         169      England         []         63  Championship
# 433789      []         169      England         []         63  Championship
# 433790      []         169      England         []         63  Championship
# 433791      []         169      England         []         63  Championship
#
#                                                      lineup  \
# match_id
# 432785    {'home': {'starting_lineups': [], 'substitutes...
# 432798    {'home': {'starting_lineups': [], 'substitutes...
# 432799    {'home': {'starting_lineups': [], 'substitutes...
# 432800    {'home': {'starting_lineups': [], 'substitutes...
# 432801    {'home': {'starting_lineups': [], 'substitutes...
# 432802    {'home': {'starting_lineups': [], 'substitutes...
# 432803    {'home': {'starting_lineups': [], 'substitutes...
# 432804    {'home': {'starting_lineups': [], 'substitutes...
# 432805    {'home': {'starting_lineups': [], 'substitutes...
# 433015    {'home': {'starting_lineups': [], 'substitutes...
# 433016    {'home': {'starting_lineups': [], 'substitutes...
# 433017    {'home': {'starting_lineups': [], 'substitutes...
# 433018    {'home': {'starting_lineups': [], 'substitutes...
# 433019    {'home': {'starting_lineups': [], 'substitutes...
# 433020    {'home': {'starting_lineups': [], 'substitutes...
# 433021    {'home': {'starting_lineups': [], 'substitutes...
# 433022    {'home': {'starting_lineups': [], 'substitutes...
# 433023    {'home': {'starting_lineups': [], 'substitutes...
# 433024    {'home': {'starting_lineups': [], 'substitutes...
# 433126    {'home': {'starting_lineups': [], 'substitutes...
# 433194    {'home': {'starting_lineups': [], 'substitutes...
# 433476    {'home': {'starting_lineups': [], 'substitutes...
# 433607    {'home': {'starting_lineups': [], 'substitutes...
# 433608    {'home': {'starting_lineups': [], 'substitutes...
# 433609    {'home': {'starting_lineups': [], 'substitutes...
# 433610    {'home': {'starting_lineups': [], 'substitutes...
# 433611    {'home': {'starting_lineups': [], 'substitutes...
# 433785    {'home': {'starting_lineups': [], 'substitutes...
# 433786    {'home': {'starting_lineups': [], 'substitutes...
# 433787    {'home': {'starting_lineups': [], 'substitutes...
# 433788    {'home': {'starting_lineups': [], 'substitutes...
# 433789    {'home': {'starting_lineups': [], 'substitutes...
# 433790    {'home': {'starting_lineups': [], 'substitutes...
# 433791    {'home': {'starting_lineups': [], 'substitutes...
#
#          match_awayteam_extra_score match_awayteam_halftime_score  \
# match_id
# 432785
# 432798
# 432799
# 432800
# 432801
# 432802
# 432803
# 432804
# 432805
# 433015
# 433016
# 433017
# 433018
# 433019
# 433020
# 433021
# 433022
# 433023
# 433024
# 433126
# 433194
# 433476
# 433607
# 433608
# 433609
# 433610
# 433611
# 433785
# 433786
# 433787
# 433788
# 433789
# 433790
# 433791
#
#            match_awayteam_name  ... match_hometeam_extra_score  \
# match_id                        ...
# 432785                  Fulham  ...
# 432798                 Le Mans  ...
# 432799                 Sochaux  ...
# 432800                  Troyes  ...
# 432801              AC Ajaccio  ...
# 432802                   Niort  ...
# 432803                 Chambly  ...
# 432804           Clermont Foot  ...
# 432805                   Rodez  ...
# 433015       Charlton Athletic  ...
# 433016           Middlesbrough  ...
# 433017               Hull City  ...
# 433018     Queens Park Rangers  ...
# 433019    West Bromwich Albion  ...
# 433020     Sheffield Wednesday  ...
# 433021         Birmingham City  ...
# 433022            Derby County  ...
# 433023       Preston North End  ...
# 433024            Leeds United  ...
# 433126                Le Havre  ...
# 433194            Cardiff City  ...
# 433476                Guingamp  ...
# 433607                Barnsley  ...
# 433608            Bristol City  ...
# 433609        Blackburn Rovers  ...
# 433610          Wigan Athletic  ...
# 433611              Luton Town  ...
# 433785       Huddersfield Town  ...
# 433786       Nottingham Forest  ...
# 433787                Millwall  ...
# 433788               Brentford  ...
# 433789              Stoke City  ...
# 433790            Swansea City  ...
# 433791                 Reading  ...
#
#          match_hometeam_halftime_score   match_hometeam_name  \
# match_id
# 432785                                     Huddersfield Town
# 432798                                                 Nancy
# 432799                                               Lorient
# 432800                                              Grenoble
# 432801                                           Chateauroux
# 432802                                              Paris FC
# 432803                                                  Caen
# 432804                                               Orleans
# 432805                                          Valenciennes
# 433015                                              Barnsley
# 433016                                      Blackburn Rovers
# 433017                                             Brentford
# 433018                                          Bristol City
# 433019                                            Luton Town
# 433020                                              Millwall
# 433021                                     Nottingham Forest
# 433022                                            Stoke City
# 433023                                          Swansea City
# 433024                                        Wigan Athletic
# 433126                                                  Lens
# 433194                                               Reading
# 433476                                               Auxerre
# 433607                                       Birmingham City
# 433608                                          Derby County
# 433609                                             Hull City
# 433610                                         Middlesbrough
# 433611                                   Sheffield Wednesday
# 433785                                          Cardiff City
# 433786                                     Charlton Athletic
# 433787                                                Fulham
# 433788                                          Leeds United
# 433789                                     Preston North End
# 433790                                   Queens Park Rangers
# 433791                                  West Bromwich Albion
#
#          match_hometeam_penalty_score match_hometeam_score  \
# match_id
# 432785
# 432798
# 432799
# 432800
# 432801
# 432802
# 432803
# 432804
# 432805
# 433015
# 433016
# 433017
# 433018
# 433019
# 433020
# 433021
# 433022
# 433023
# 433024
# 433126
# 433194
# 433476
# 433607
# 433608
# 433609
# 433610
# 433611
# 433785
# 433786
# 433787
# 433788
# 433789
# 433790
# 433791
#
#          match_hometeam_system match_live match_status  \
# match_id
# 432785                                  0
# 432798                                  0
# 432799                                  0
# 432800                                  0
# 432801                                  0
# 432802                                  0
# 432803                                  0
# 432804                                  0
# 432805                                  0
# 433015                                  0
# 433016                                  0
# 433017                                  0
# 433018                                  0
# 433019                                  0
# 433020                                  0
# 433021                                  0
# 433022                                  0
# 433023                                  0
# 433024                                  0
# 433126                                  0
# 433194                                  0
# 433476                                  0
# 433607                                  0
# 433608                                  0
# 433609                                  0
# 433610                                  0
# 433611                                  0
# 433785                                  0
# 433786                                  0
# 433787                                  0
# 433788                                  0
# 433789                                  0
# 433790                                  0
# 433791                                  0
#
#                                  match_time statistics
# match_id
# 432785    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 432798     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432799     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432800     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432801     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432802     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432803     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432804     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 432805     (1900, 1, 1, 18, 0, 0, 0, 1, -1)         []
# 433015     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433016     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433017     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433018     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433019     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433020     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433021     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433022     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433023     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433024     (1900, 1, 1, 14, 0, 0, 0, 1, -1)         []
# 433126     (1900, 1, 1, 13, 0, 0, 0, 1, -1)         []
# 433194     (1900, 1, 1, 11, 0, 0, 0, 1, -1)         []
# 433476    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433607    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433608    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433609    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433610    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433611    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433785    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433786    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433787    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433788    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433789    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433790    (1900, 1, 1, 18, 45, 0, 0, 1, -1)         []
# 433791     (1900, 1, 1, 19, 0, 0, 0, 1, -1)         []
#
# [34 rows x 24 columns]

# %%
db_con.update_events_from_fetch(datetime(2019,1,1), datetime(2020,12,31))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_events&from=2019-01-01&to=2020-12-31&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/events_db.csv
# True

# %%
import pandas as pd
import requests
import threading
from datetime import datetime, timedelta
from flask import config
import time

class DatabaseConnection:
    # this should connect to a q server to check the database for things
    def __init__(self):
        self.lock = threading.Lock()
        self.leagues_db = pd.DataFrame()
        self.events_db = pd.DataFrame()
        self.league_db_standings = {}
        self.setup_from_disk()
        self.last_refresh_times = {}
        self.refresh_events()
        self.update_leagues_db_from_fetch()
        self.refresh_all_leagues_from_fetch()

#----------- disk io ----------------------------------------------------------------------------------------
    
    def write_db_to_disk(self, path, db):
        """
        write pandas df to a csv
        """
        logging.info('writing db to fisk at {}'.format(path))
        try:
            with self.lock:
                db.to_csv(path)
            return True
        except Exception as e:
            logging.error('error in write_db_to_disk {}'.format(e))
            return False
        
    def setup_from_disk(self):
        self.setup_leagues_from_disk()
        self.setup_events_db_from_disk()
        for league_id in self.leagues_db.league_id:
            self.setup_league_standings_db_from_disk(league_id)

    def setup_leagues_from_disk(self):
        """
        retrieves league db from disk via path in config
        """
        logging.info('getting league_db from disk')
        try:
            with self.lock:
                df = pd.read_csv(config.path_leagues_db)
            self.leagues_db = df
            logging.info('set up leagues_db from disk')
            return True
        except Exception as e:
            logging.error('error in get_league_db_from_disk {}'.format(e))
            return False
    
    def setup_events_db_from_disk(self):
        """
        retrieves events db from disk via path in config
        """
        logging.info('getting league_db from disk')
        try:
            with self.lock:
                df = pd.read_csv(config.path_events_db).set_index('match_id')
            df = df.astype({'country_id': 'int32', 
                       'league_id':'int32'})
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
            df['match_time'] = [time.strptime(t, '%H:%M') for t in df['match_time']]
            self.events_db = df
            return True
        except Exception as e:
            logging.error('error in setup_leagues_from_disk {}'.format(e))
            return False

    def setup_league_standings_db_from_disk(self, league_id):
        """
        retrieves league standings db from disk via path stem in config plus league_id
        """
        logging.info('setting up league_db for id {} from disk'.format(league_id))
        path = config.path_league_standings_stem + str(league_id)
        try:
            with self.lock:
                df = pd.read_csv(path)
            self.league_db_standings[league_id] = df
            logging.info('set up league_db for id {} from disk'.format(league_id))
            return True
        except Exception as e:
            logging.error('error in get_league_standings_db_from_disk {}'.format(e))
            return False

#----------- disk io ---------------------------------------------------------------------------------------        
#----------- fetches----------------------------------------------------------------------------------------
        
    def refresh_all_leagues_from_fetch(self):
        if self.leagues_db.empty:
            raise Exception('leagues_db is empty so something went wrong !')
        for league_id in self.leagues_db.league_id:
            self.update_league_db_standings_from_fetch(league_id)

    def update_leagues_db_from_fetch(self):
        """
        using an api call sets up the leagues_db
        """
        logging.info('updating  leagues_db from fetch')
        path = config.apifootball_host + '/?action=get_leagues&APIkey=' + config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            self.leagues_db = df
            self.write_db_to_disk(config.path_leagues_db, df)
            self.update_last_refresh_times(0)
            return True
        except Exception as e:
            logging.error('error in update_leagues_db_from_fetch {}'.format(e))
            return False
        
    def update_events_from_fetch(self, date_from, date_to):
        """
        retrieves events from fetch by date and updates the events_db by match_id
        """
        date_from = self.date_to_string(date_from)
        date_to = self.date_to_string(date_to)
        path = config.apifootball_host + '/?action=get_events&from=' + date_from + '&to=' + date_to + '&APIkey=' + config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json()).set_index('match_id')
            df = df.astype({'country_id': 'int32', 
                       'league_id':'int32'})
            df['match_date'] = [datetime.strptime(d, '%Y-%m-%d') for d in df['match_date']]
            df['match_time'] = [time.strptime(t, '%H:%M') for t in df['match_time']]
            if self.events_db.empty:
                self.events_db = df
            else:
                self.events_db.update(df, join='left', overwrite=True)
            self.write_db_to_disk(config.path_events_db, df)
            self.update_last_refresh_times(1)
            return True
        except Exception as e:
            logging.error('error in update_events_from_fetch {}'.format(e))
            return False

    def update_league_db_standings_from_fetch(self, league_id):
        """
        using an api call to set up the league_db_standings
        """
        logging.info('setting up league_db_standings from fetch for id {}'.format(league_id))
        path = config.apifootball_host + '/?action=get_standings&league_id=' + str(
            league_id) + '&APIkey=' + config.apifootball_key
        try:
            response = requests.get(path)
            df = pd.DataFrame(response.json())
            self.league_db_standings[league_id] = df
            logging.info('changed league_db_standings from the fetch for {}'.format(league_id))
            self.write_db_to_disk(config.path_league_standings_stem + str(league_id), df)
            self.update_last_refresh_times(league_id)
            return True
        except Exception as e:
            logging.error('error in update_league_db_standings_from_fetch {}'.format(e))
            return False

#----------- fetches----------------------------------------------------------------------------------------

    def get_raw_fixtures(self, league_id, date_from, date_to):
        df = self.events_db.copy()
        return df.loc[
            (df['league_id'] == 63) & 
            (df['match_date'] > date_from.replace(hour=0, minute=0, second=0)) &
            (df['match_date'] < date_to.replace(hour=23, minute=59, second=0))
        ]

    def present_fixtures(self, league_id, date_from, date_to):
        fixtures = []
        fixtures_raw = self.get_raw_fixtures(league_id, date_from, date_to)
        for row in fixtures_raw.itertuples():
            fixtures.append({
                'match_id':row.Index,
                'match_date':row.match_date.timestamp(),
                'match_time':row.match_time,
                'home_team':row.match_hometeam_name,
                'away_team':row.match_awayteam_name
            })
        return fixtures

    def refresh_events(self):
        if not self.is_data_fresh(1):
            logging.info('in refresh_events data not fresh')
            date_from = datetime.now()
            date_to = datetime.now() + timedelta(days=10)
            self.update_events_from_fetch(date_from, date_to)
            logging.info('refreshed events')
        else:
            logging.info('in refresh_events data is fresh')

    def update_last_refresh_times(self, id):
        self.last_refresh_times[id] = datetime.now()

    def is_data_fresh(self, id):
        if not id in self.last_refresh_times:
            return False
        time_since_update_mins = (datetime.now() - self.last_refresh_times[id]).seconds / 60
        if time_since_update_mins > config.refresh_time_mins:
            return False
        return True
    
    def date_to_string(self, date):
        yyyy = str(date.year)
        mm = str(date.month)
        dd = str(date.day)
        if len(mm) == 1:
            mm = '0' + mm
        if len(dd) == 1:
            dd = '0' + dd
        return yyyy + '-' + mm + '-' + dd 

    def df_to_strings(self, df):
        for col in df.columns:
            df[col] = df[col].astype(str)
        return df

    def get_league_db(self):
        if not self.is_data_fresh(0):
            logging.info('in get_league_db data not fresh')
            self.update_leagues_db_from_fetch()
        else:
            logging.info('in get_league_db data is fresh')
        return self.leagues_db

    def get_league_db_standings(self, league_id):
        if not self.is_data_fresh(league_id):
            logging.info('in get_league_db_standings data not fresh')
            self.update_league_db_standings_from_fetch(league_id)
        else:
            logging.info('in get_league_db_standings data is fresh')
        logging.info('keys of league_db_standings are {} and league id {} is in ? {}'.format(self.league_db_standings.keys(), league_id, league_id in self.league_db_standings.keys()))
        if league_id in self.league_db_standings.keys():
            return self.league_db_standings[league_id]
        return pd.DataFrame()

    def get_leagues(self):
        """
        returns the league and country info in a dictionary form
        """
        logging.info('inside get_leagues')
        df = self.df_to_strings(self.get_league_db())
        leagues_dict = {}
        cids = list(set(df['country_id']))
        df = df.set_index('country_id')
        for cid in cids:
            if sum(df.index == cid) > 1:
                league_names = list(df.loc[cid]['league_name'])
                league_ids = list(df.loc[cid]['league_id'])
                country_name = list(df.loc[cid]['country_name'])[0]
            else:
                league_names = [df.loc[cid]['league_name']]
                league_ids = [df.loc[cid]['league_id']]
                country_name = df.loc[cid]['country_name']
            leagues_dict[cid] = {
                'country_name': country_name,
                'leagues': {
                    'league_ids': league_ids,
                    'country_name': country_name,
                    'league_names': league_names
                }
            }
        return leagues_dict

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

global db_con
db_con = DatabaseConnection()  # or whatever you need to do
# Out:
# INFO:root:getting league_db from disk
# INFO:root:set up leagues_db from disk
# INFO:root:getting league_db from disk
# ERROR:root:error in setup_leagues_from_disk time data 'FT' does not match format '%H:%M'
# INFO:root:setting up league_db for id 63 from disk
# INFO:root:set up league_db for id 63 from disk
# INFO:root:setting up league_db for id 128 from disk
# INFO:root:set up league_db for id 128 from disk
# INFO:root:in refresh_events data not fresh
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_events&from=2019-08-11&to=2019-08-21&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/events_db.csv
# INFO:root:refreshed events
# INFO:root:updating  leagues_db from fetch
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_leagues&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 180
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/leagues_db.csv
# INFO:root:setting up league_db_standings from fetch for id 63
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=63&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 63
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_63
# INFO:root:setting up league_db_standings from fetch for id 128
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# DEBUG:urllib3.connectionpool:https://apifootball.com:443 "GET /api/?action=get_standings&league_id=128&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f HTTP/1.1" 200 None
# INFO:root:changed league_db_standings from the fetch for 128
# INFO:root:writing db to fisk at /Users/ollieloney/SoccerScores/databases/league_standings_128

# %%
def get_league_standings():
    logging.info("get_league_standings")
    df = db_con.get_league_db()
    return (df.to_dict('index'))


def get_sidebar_info():
    logging.info("get_sidebar_info")
    logging.info('db_con.get_leagues() {}'.format(db_con.get_leagues()))
    return (db_con.get_leagues())


def get_league_standings_db(league_id):
    logging.info("get_league_standings_db for {}".format(league_id))

    df = db_con.get_league_db_standings(league_id)
    if df.empty:
        return ('league_id not recognised')
    return (df.to_dict('index'))

# %%
get_league_standings_db('63')
# Out:
# INFO:root:get_league_standings_db for 63
# INFO:root:in get_league_db_standings data not fresh
# INFO:root:setting up league_db_standings from fetch for id 63
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): apifootball.com:443
# ERROR:root:error in update_league_db_standings_from_fetch HTTPSConnectionPool(host='apifootball.com', port=443): Max retries exceeded with url: /api/?action=get_standings&league_id=63&APIkey=9fe5c8415f9eda3d0abd11d51578518d6a7c48d172f82abed46bf5bd9fe2479f (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x103587390>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# INFO:root:keys of league_db_standings are dict_keys([63, 128]) and league id 63 is in ? False
# 'league_id not recognised'
